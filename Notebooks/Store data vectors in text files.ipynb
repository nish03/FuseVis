# %%
#Import packages
import time
import torch.nn as nn
import torch
from torch.utils.data import Dataset, DataLoader
import torchvision.datasets as datasets
import numpy as np
from torchvision import transforms
from torch.autograd import Variable
from PIL import Image
import torchvision.transforms.functional as TF
from torchvision.models.vgg import vgg19
import torch.nn as nn
import torch.nn.functional as F
import torch
from skimage import img_as_ubyte
import torch.nn as nn
import torch.utils.data as Data
import torchvision      # dataset
import matplotlib.pyplot as plt
import scipy
import numpy as np
import argparse
import glob
import imageio
from skimage import color
import numpy
import natsort
import scipy
from pytorch_msssim import ssim, ms_ssim, SSIM, MS_SSIM
import pprint
from scipy.ndimage import correlate
from scipy.ndimage.filters import gaussian_gradient_magnitude
import torchvision.datasets as dset
import torch.utils.data as data
import os
import os.path
from tkinter import *
import tkinter as tk
import tkinter.font as tkFont
from PIL import ImageTk, Image
import pylab
import cv2
import h5py
from mpl_toolkits.axes_grid1 import make_axes_locatable
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
MRI_image       = imageio.imread('C:/Users/horan/Desktop/FuseVis/MRI/MRI.gif')
PET_image       = imageio.imread('C:/Users/horan/Desktop/FuseVis/PET/3.png')

Fused_FunFuseAn = imageio.imread('C:/Users/horan/Desktop/FuseVis/Fused/FunFuseAn/Fused.png')
Fused_FusionGAN = imageio.imread('C:/Users/horan/Desktop/FuseVis/Fused/FusionGAN/Fused.png')
Fused_FusionDN  = imageio.imread('C:/Users/horan/Desktop/FuseVis/Fused/FusionDN/Fused.png')
Fused_MaskNet   = imageio.imread('C:/Users/horan/Desktop/FuseVis/Fused/MaskNet/Fused.png')
Fused_DeepFuse   = imageio.imread('C:/Users/horan/Desktop/FuseVis/Fused/DeepFuse/Fused.png')
Fused_DeepPedestrian   = imageio.imread('C:/Users/horan/Desktop/FuseVis/Fused/DeepPedestrian/Fused.png')
Fused_VIFNet = imageio.imread('C:/Users/horan/Desktop/FuseVis/Fused/VIFNet/Fused.png')

#funfusean
hf = h5py.File('C:/Users/horan/Desktop/FuseVis/Guidance images/FunFuseAn/H5 Files/Jacobian_MRI.h5', 'r')
guide_fused_mri_1 =  np.array(hf.get('MRI_dataset'))
hf.close()
hf = h5py.File('C:/Users/horan/Desktop/FuseVis/Guidance images/FunFuseAn/H5 Files/Jacobian_PET.h5', 'r')
guide_fused_pet_1 =  np.array(hf.get('PET_dataset'))
hf.close()
Guidance_MRI_FunFuseAn = guide_fused_mri_1
Guidance_PET_FunFuseAn = guide_fused_pet_1

#fusionGAN
hf = h5py.File('C:/Users/horan/Desktop/FuseVis/Guidance images/FusionGAN/H5 Files/Jacobian_MRI.h5', 'r')
guide_fused_mri_2 =  np.array(hf.get('Jacob_MRI_dataset'))
hf.close()
hf = h5py.File('C:/Users/horan/Desktop/FuseVis/Guidance images/FusionGAN/H5 Files/Jacobian_PET.h5', 'r')
guide_fused_pet_2 =  np.array(hf.get('Jacob_PET_dataset'))
hf.close()
Guidance_MRI_FusionGAN = guide_fused_mri_2
Guidance_PET_FusionGAN = guide_fused_pet_2

#fusiondn
hf = h5py.File('C:/Users/horan/Desktop/FuseVis/Guidance images/FusionDN/H5 Files/Jacobian_MRI.h5', 'r')
guide_fused_mri_3 =  np.array(hf.get('Jacob_MRI_dataset'))
hf.close()
hf = h5py.File('C:/Users/horan/Desktop/FuseVis/Guidance images/FusionDN/H5 Files/Jacobian_PET.h5', 'r')
guide_fused_pet_3 =  np.array(hf.get('Jacob_PET_dataset'))
hf.close()
Guidance_MRI_FusionDN = guide_fused_mri_3
Guidance_PET_FusionDN = guide_fused_pet_3

#Masknet
hf = h5py.File('C:/Users/horan/Desktop/FuseVis/Guidance images/MaskNet/H5 Files/Jacobian_MRI.h5', 'r')
guide_fused_mri_4 =  np.array(hf.get('Jacob_MRI_dataset'))
hf.close()
hf = h5py.File('C:/Users/horan/Desktop/FuseVis/Guidance images/MaskNet/H5 Files/Jacobian_PET.h5', 'r')
guide_fused_pet_4 =  np.array(hf.get('Jacob_PET_dataset'))
hf.close()
Guidance_MRI_MaskNet = guide_fused_mri_4
Guidance_PET_MaskNet = guide_fused_pet_4

#DeepFuse
hf = h5py.File('C:/Users/horan/Desktop/FuseVis/Guidance images/DeepFuse/H5 Files/Jacobian_MRI.h5', 'r')
guide_fused_mri_5 =  np.array(hf.get('Jacob_MRI_dataset'))
hf.close()
hf = h5py.File('C:/Users/horan/Desktop/FuseVis/Guidance images/DeepFuse/H5 Files/Jacobian_PET.h5', 'r')
guide_fused_pet_5 =  np.array(hf.get('Jacob_PET_dataset'))
hf.close()
Guidance_MRI_DeepFuse = guide_fused_mri_5
Guidance_PET_DeepFuse = guide_fused_pet_5

#DeepPedestrian
hf = h5py.File('C:/Users/horan/Desktop/FuseVis/Guidance images/DeepPedestrian/H5 Files/Jacobian_MRI.h5', 'r')
guide_fused_mri_6 =  np.array(hf.get('Jacob_MRI_dataset'))
hf.close()
hf = h5py.File('C:/Users/horan/Desktop/FuseVis/Guidance images/DeepPedestrian/H5 Files/Jacobian_PET.h5', 'r')
guide_fused_pet_6 =  np.array(hf.get('Jacob_PET_dataset'))
hf.close()
Guidance_MRI_DeepPedestrian = guide_fused_mri_6
Guidance_PET_DeepPedestrian = guide_fused_pet_6

#VIFNet
hf = h5py.File('C:/Users/horan/Desktop/FuseVis/Guidance images/VIFNet/H5 Files/Jacobian_MRI.h5', 'r')
guide_fused_mri_7 =  np.array(hf.get('Jacob_MRI_dataset'))
hf.close()
hf = h5py.File('C:/Users/horan/Desktop/FuseVis/Guidance images/VIFNet/H5 Files/Jacobian_PET.h5', 'r')
guide_fused_pet_7 =  np.array(hf.get('Jacob_PET_dataset'))
hf.close()
Guidance_MRI_VIFNet = guide_fused_mri_7
Guidance_PET_VIFNet = guide_fused_pet_7

# %%
count = 0 
f= open("FunFuseAn.txt","w+")
f.write("7\n")
f.write("X: Pixel Coordinate for row\n")
f.write("Y: Pixel Coordinate for column\n")
f.write("MRI: MRI pixel intensities at (X,Y)\n")
f.write("PET: PET pixel intensities at (X,Y)\n")
f.write("Fused: Fused pixel intensities at (X,Y)\n")
f.write("Guidance MRI: Per fused pixel gradient wrt MRI\n")
f.write("Guidance PET: Per fused pixel gradient wrt PET\n")
MRI_image = (MRI_image - np.min(MRI_image)) / (np.max(MRI_image) - np.min(MRI_image))
PET_image = (PET_image - np.min(PET_image)) / (np.max(PET_image) - np.min(PET_image))
Fused_FunFuseAn = (Fused_FunFuseAn - np.min(Fused_FunFuseAn)) / (np.max(Fused_FunFuseAn) - np.min(Fused_FunFuseAn))
for i in range(256):
    for j in range(256):
        f.write('{:<10d} {:<10d} {:.10f} {:.10f} {:.10f} {:.10f} {:.10f}\n'.format(i,j, MRI_image[i,j], PET_image[i,j], Fused_FunFuseAn[i,j], Guidance_MRI_FunFuseAn[i,j], Guidance_PET_FunFuseAn[i,j]))
f.close()

# %%
count = 0 
f= open("FusionGAN.txt","w+")
f.write("7\n")
f.write("X: Pixel Coordinate for row\n")
f.write("Y: Pixel Coordinate for column\n")
f.write("MRI: MRI pixel intensities at (X,Y)\n")
f.write("PET: PET pixel intensities at (X,Y)\n")
f.write("Fused: Fused pixel intensities at (X,Y)\n")
f.write("Guidance MRI: Per fused pixel gradient wrt MRI\n")
f.write("Guidance PET: Per fused pixel gradient wrt PET\n")
#MRI_image = (MRI_image - np.min(MRI_image)) / (np.max(MRI_image) - np.min(MRI_image))
#PET_image = (PET_image - np.min(PET_image)) / (np.max(PET_image) - np.min(PET_image))
Fused_FusionGAN = (Fused_FusionGAN - np.min(Fused_FusionGAN)) / (np.max(Fused_FusionGAN) - np.min(Fused_FusionGAN))
for i in range(256):
    for j in range(256):
        f.write('{:<10d} {:<10d} {:.10f} {:.10f} {:.10f} {:.10f} {:.10f}\n'.format(i,j, MRI_image[i,j], PET_image[i,j], Fused_FusionGAN[i,j], Guidance_MRI_FusionGAN[i,j], Guidance_PET_FusionGAN[i,j]))
f.close()

# %%
count = 0 
f= open("FusionDN.txt","w+")
f.write("7\n")
f.write("X: Pixel Coordinate for row\n")
f.write("Y: Pixel Coordinate for column\n")
f.write("MRI: MRI pixel intensities at (X,Y)\n")
f.write("PET: PET pixel intensities at (X,Y)\n")
f.write("Fused: Fused pixel intensities at (X,Y)\n")
f.write("Guidance MRI: Per fused pixel gradient wrt MRI\n")
f.write("Guidance PET: Per fused pixel gradient wrt PET\n")
#MRI_image = (MRI_image - np.min(MRI_image)) / (np.max(MRI_image) - np.min(MRI_image))
#PET_image = (PET_image - np.min(PET_image)) / (np.max(PET_image) - np.min(PET_image))
Fused_FusionDN = (Fused_FusionDN - np.min(Fused_FusionDN)) / (np.max(Fused_FusionDN) - np.min(Fused_FusionDN))
for i in range(256):
    for j in range(256):
        f.write('{:<10d} {:<10d} {:.10f} {:.10f} {:.10f} {:.10f} {:.10f}\n'.format(i,j, MRI_image[i,j], PET_image[i,j], Fused_FusionDN[i,j], Guidance_MRI_FusionDN[i,j], Guidance_PET_FusionDN[i,j]))
f.close()

# %%
count = 0 
f= open("MaskNet.txt","w+")
f.write("7\n")
f.write("X: Pixel Coordinate for row\n")
f.write("Y: Pixel Coordinate for column\n")
f.write("MRI: MRI pixel intensities at (X,Y)\n")
f.write("PET: PET pixel intensities at (X,Y)\n")
f.write("Fused: Fused pixel intensities at (X,Y)\n")
f.write("Guidance MRI: Per fused pixel gradient wrt MRI\n")
f.write("Guidance PET: Per fused pixel gradient wrt PET\n")
#MRI_image = (MRI_image - np.min(MRI_image)) / (np.max(MRI_image) - np.min(MRI_image))
#PET_image = (PET_image - np.min(PET_image)) / (np.max(PET_image) - np.min(PET_image))
Fused_MaskNet = (Fused_MaskNet - np.min(Fused_MaskNet)) / (np.max(Fused_MaskNet) - np.min(Fused_MaskNet))
for i in range(256):
    for j in range(256):
        f.write('{:<10d} {:<10d} {:.10f} {:.10f} {:.10f} {:.10f} {:.10f}\n'.format(i,j, MRI_image[i,j], PET_image[i,j], Fused_MaskNet[i,j], Guidance_MRI_MaskNet[i,j], Guidance_PET_MaskNet[i,j]))
f.close()

# %%
count = 0 
f= open("DeepFuse.txt","w+")
f.write("7\n")
f.write("X: Pixel Coordinate for row\n")
f.write("Y: Pixel Coordinate for column\n")
f.write("MRI: MRI pixel intensities at (X,Y)\n")
f.write("PET: PET pixel intensities at (X,Y)\n")
f.write("Fused: Fused pixel intensities at (X,Y)\n")
f.write("Guidance MRI: Per fused pixel gradient wrt MRI\n")
f.write("Guidance PET: Per fused pixel gradient wrt PET\n")
#MRI_image = (MRI_image - np.min(MRI_image)) / (np.max(MRI_image) - np.min(MRI_image))
#PET_image = (PET_image - np.min(PET_image)) / (np.max(PET_image) - np.min(PET_image))
Fused_DeepFuse = (Fused_DeepFuse - np.min(Fused_DeepFuse)) / (np.max(Fused_DeepFuse) - np.min(Fused_DeepFuse))
for i in range(256):
    for j in range(256):
        f.write('{:<10d} {:<10d} {:.10f} {:.10f} {:.10f} {:.10f} {:.10f}\n'.format(i,j, MRI_image[i,j], PET_image[i,j], Fused_DeepFuse[i,j], Guidance_MRI_DeepFuse[i,j], Guidance_PET_DeepFuse[i,j]))
f.close()

# %%
count = 0 
f= open("DeepPedestrian.txt","w+")
f.write("7\n")
f.write("X: Pixel Coordinate for row\n")
f.write("Y: Pixel Coordinate for column\n")
f.write("MRI: MRI pixel intensities at (X,Y)\n")
f.write("PET: PET pixel intensities at (X,Y)\n")
f.write("Fused: Fused pixel intensities at (X,Y)\n")
f.write("Guidance MRI: Per fused pixel gradient wrt MRI\n")
f.write("Guidance PET: Per fused pixel gradient wrt PET\n")
#MRI_image = (MRI_image - np.min(MRI_image)) / (np.max(MRI_image) - np.min(MRI_image))
#PET_image = (PET_image - np.min(PET_image)) / (np.max(PET_image) - np.min(PET_image))
Fused_DeepPedestrian = (Fused_DeepPedestrian - np.min(Fused_DeepPedestrian)) / (np.max(Fused_DeepPedestrian) - np.min(Fused_DeepPedestrian))
for i in range(256):
    for j in range(256):
        f.write('{:<10d} {:<10d} {:.10f} {:.10f} {:.10f} {:.10f} {:.10f}\n'.format(i,j, MRI_image[i,j], PET_image[i,j], Fused_DeepPedestrian[i,j], Guidance_MRI_DeepPedestrian[i,j], Guidance_PET_DeepPedestrian[i,j]))
f.close()

# %%
count = 0 
f= open("VIFNet.txt","w+")
f.write("7\n")
f.write("X: Pixel Coordinate for row\n")
f.write("Y: Pixel Coordinate for column\n")
f.write("MRI: MRI pixel intensities at (X,Y)\n")
f.write("PET: PET pixel intensities at (X,Y)\n")
f.write("Fused: Fused pixel intensities at (X,Y)\n")
f.write("Guidance MRI: Per fused pixel gradient wrt MRI\n")
f.write("Guidance PET: Per fused pixel gradient wrt PET\n")
#MRI_image = (MRI_image - np.min(MRI_image)) / (np.max(MRI_image) - np.min(MRI_image))
#PET_image = (PET_image - np.min(PET_image)) / (np.max(PET_image) - np.min(PET_image))
Fused_VIFNet = (Fused_VIFNet - np.min(Fused_VIFNet)) / (np.max(Fused_VIFNet) - np.min(Fused_VIFNet))
for i in range(256):
    for j in range(256):
        f.write('{:<10d} {:<10d} {:.10f} {:.10f} {:.10f} {:.10f} {:.10f}\n'.format(i,j, MRI_image[i,j], PET_image[i,j], Fused_VIFNet[i,j], Guidance_MRI_VIFNet[i,j], Guidance_PET_VIFNet[i,j]))
f.close()
