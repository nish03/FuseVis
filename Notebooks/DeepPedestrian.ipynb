# %% [markdown]
# # This is the pytorch implementation of the deep learning model proposed in the paper 'Deep Visible and Thermal Image Fusion for Enhanced pedestrian visibility'

# %%
#Import packages
import time
import torch.nn as nn
import torch
from torch.utils.data import Dataset, DataLoader
import torchvision.datasets as datasets
import numpy as np
from torchvision import transforms
from torch.autograd import Variable
from PIL import Image
import torchvision.transforms.functional as TF
from torchvision.models.vgg import vgg19
import torch.nn as nn
import torch.nn.functional as F
import torch
from skimage import img_as_ubyte
import torch.nn as nn
import torch.utils.data as Data
import torchvision      # dataset
import matplotlib.pyplot as plt
import scipy
import numpy as np
import argparse
import glob
import imageio
from skimage import color
import numpy
import natsort
import scipy
from pytorch_msssim import ssim, ms_ssim, SSIM, MS_SSIM
import pprint
from scipy.ndimage import correlate
from scipy.ndimage.filters import gaussian_gradient_magnitude
import torchvision.datasets as dset
import torch.utils.data as data
import os
import os.path
from tkinter import *
import tkinter as tk
import tkinter.font as tkFont
from PIL import ImageTk, Image
import pylab
import cv2
import h5py
from mpl_toolkits.axes_grid1 import make_axes_locatable
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(torch.cuda.get_device_properties(0).total_memory)
# Out:
# 11811160064

# %%
import multiprocessing

multiprocessing.cpu_count()
# Out:
# 12

# %%
#define the hyperparameters
image_length = 256
image_width  = 256
mr_channels  = 1
gray_channels = 1
pet_channels = 4    
rgb_channels = 3     
batch_size   = 1
EPOCH = 100
learning_rate = 0.002

# %%
#load the train mri data
filenames = os.listdir('C:/Users/horan/Desktop/FuseVis/Training/MRI')
dataset = os.path.join(os.getcwd(), 'C:/Users/horan/Desktop/FuseVis/Training/MRI')
data = glob.glob(os.path.join(dataset, "*.gif"))
data = natsort.natsorted(data,reverse=False)
train_mri = np.zeros((len(data), image_width,image_length))
for i in range(len(data)):
    train_mri[i,:,:] =(imageio.imread(data[i]))
    train_mri[i,:,:] =(train_mri[i,:,:] - np.min(train_mri[i,:,:])) / (np.max(train_mri[i,:,:]) - np.min(train_mri[i,:,:]))
    train_mri[i,:,:] = np.float32(train_mri[i,:,:])

# %%
#expand dimension to add the channel
train_mri = np.expand_dims(train_mri,axis=1)

# %%
#verify the shape matches the pytorch standard
train_mri.shape
# Out:
# (272, 1, 256, 256)

# %%
#convert the MRI training data to pytorch tensor
train_mri_tensor = torch.from_numpy(train_mri).float()
train_mri_tensor.shape
# Out:
# torch.Size([272, 1, 256, 256])

# %%
#load the train pet data
filenames = os.listdir('C:/Users/horan/Desktop/FuseVis/Training/PET')
dataset = os.path.join(os.getcwd(), 'C:/Users/horan/Desktop/FuseVis/Training/PET')
data = glob.glob(os.path.join(dataset, "*.gif"))
data = natsort.natsorted(data,reverse=False)
train_other = np.zeros((len(data),image_width,image_length,pet_channels),dtype=float)
train_pet = np.zeros((len(data),image_width,image_length),dtype=float)
for i in range(len(data)):
    train_other[i,:,:,:] =(imageio.imread(data[i]))
    train_pet[i,:,:] = 0.2989 * train_other[i,:,:,0] + 0.5870 *  train_other[i,:,:,1]  + 0.1140 * train_other[i,:,:,2]
    train_pet[i,:,:] =(train_pet[i,:,:] - np.min(train_pet[i,:,:])) / (np.max(train_pet[i,:,:]) - np.min(train_pet[i,:,:]))

# %%
#expand the dimension to add the channel
train_pet = np.expand_dims(train_pet,axis=1)

# %%
#verify the shape matches the pytorch standard
train_pet.shape
# Out:
# (272, 1, 256, 256)

# %%
#convert the PET training data to pytorch tensor
train_pet_tensor = torch.from_numpy(train_pet).float()
train_pet_tensor.shape
# Out:
# torch.Size([272, 1, 256, 256])

# %%
#define the fusion network
#define the network
class DeepPedestrian(nn.Module):
    def  __init__(self):
        super(DeepPedestrian, self).__init__()
        #####layer 1#####
        self.conv1 = nn.Sequential(                             #input shape  (,2,256,256)
                         nn.Conv2d(in_channels=2, out_channels=48, kernel_size=3, stride=1, padding=1),
                         nn.ReLU(),
                         nn.Conv2d(in_channels = 48, out_channels = 48, kernel_size  = 3, stride= 1, padding = 1),
                         nn.ReLU(),
                         nn.Conv2d(in_channels = 48, out_channels = 48, kernel_size  = 3, stride= 1, padding = 1),
                         nn.ReLU(),
                         nn.Conv2d(in_channels = 48, out_channels = 48, kernel_size  = 3, stride= 1, padding = 1)
                         )                                     #output shape (,48,256,256)   
        #####layer 2#####
        self.conv2 = nn.Sequential(                            #input shape  (,48,256,256)
                         nn.ReLU(),
                         nn.Conv2d(in_channels=48, out_channels=48, kernel_size=3, stride=1, padding=1),
                         nn.ReLU(),
                         nn.Conv2d(in_channels = 48, out_channels = 48, kernel_size  = 3, stride= 1, padding = 1),
                         nn.ReLU(),
                         nn.Conv2d(in_channels = 48, out_channels = 48, kernel_size  = 3, stride= 1, padding = 1),
                         nn.ReLU(),
                         nn.Conv2d(in_channels = 48, out_channels = 48, kernel_size  = 3, stride= 1, padding = 1)
                         )                                     #output shape (,48,256,256)   
        #####layer 3#####
        self.conv3 = nn.Sequential(                            #input shape  (,48,256,256)
                         nn.ReLU(), 
                         nn.Conv2d(in_channels = 48, out_channels = 48, kernel_size=3, stride=1, padding=1),
                         nn.ReLU(),
                         nn.Conv2d(in_channels = 48, out_channels = 48, kernel_size  = 3, stride= 1, padding = 1),
                         nn.ReLU(),
                         nn.Conv2d(in_channels = 48, out_channels = 48, kernel_size  = 3, stride= 1, padding = 1),
                         nn.ReLU(),
                         nn.Conv2d(in_channels = 48, out_channels = 48, kernel_size  = 3, stride= 1, padding = 1)
                         )                                     #output shape (,48,256,256)     
        #####layer 4#####
        self.conv4 = nn.Sequential(                            #input shape  (,48,256,256)
                         nn.ReLU(), 
                         nn.Conv2d(in_channels = 48, out_channels = 48, kernel_size=3, stride=1, padding=1),
                         nn.ReLU(),
                         nn.Conv2d(in_channels = 48, out_channels = 48, kernel_size  = 3, stride= 1, padding = 1),
                         nn.ReLU(),
                         nn.Conv2d(in_channels = 48, out_channels = 48, kernel_size  = 3, stride= 1, padding = 1),
                         nn.ReLU(),
                         nn.Conv2d(in_channels = 48, out_channels = 48, kernel_size  = 3, stride= 1, padding = 1)
                         )                                      #output shape (,48,256,256)  
        #####layer 5#####
        self.conv5 = nn.Sequential(                             #input shape (, 48, 256, 256)
                          nn.ReLU(),
                          nn.Conv2d(in_channels  = 48,  out_channels = 1, kernel_size  = 3, stride = 1, padding = 1)) 
                                                                #output shape (,1, 256, 256)
        
    def forward(self, x, y):
        #layer 1
        x1 = self.conv1(torch.cat((x,y),dim=1))
        #layer 2
        x2 = self.conv2(x1)
        #residual layer
        x3 = x1+x2
        #layer 3
        x4 = self.conv3(x3)
        #layer 4
        x5 = self.conv4(x4)
        #residual layer
        x6 = x4 + x5
        #layer 5
        fused = self.conv5(x6)
        return fused
        #execute the network

cnn = DeepPedestrian().to(device)
cnn = cnn.float()
print(cnn)
# Out:
# DeepPedestrian(
#   (conv1): Sequential(
#     (0): Conv2d(2, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU()
#     (6): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (conv2): Sequential(
#     (0): ReLU()
#     (1): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (2): ReLU()
#     (3): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU()
#     (5): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU()
#     (7): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (conv3): Sequential(
#     (0): ReLU()
#     (1): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (2): ReLU()
#     (3): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU()
#     (5): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU()
#     (7): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (conv4): Sequential(
#     (0): ReLU()
#     (1): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (2): ReLU()
#     (3): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU()
#     (5): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU()
#     (7): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (conv5): Sequential(
#     (0): ReLU()
#     (1): Conv2d(48, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
# )

# %%
#define the optimizers and loss functions 
optimizer = torch.optim.Adam(cnn.parameters(), lr=learning_rate)   # optimize all cnn parameters
l2_loss   = nn.MSELoss() #MSEloss

# %%
# perform the training
counter = 0
start_time = time.time()
lamda = 0.8
ep_mri_ssim_loss = []
ep_pet_ssim_loss = []
ep_total_l2_loss = []
for epoch in range(EPOCH):
    mri_ssim_Loss = []
    pet_ssim_Loss = []
    l2_Loss       = []
    #run batch images
    batch_idxs = 272 // batch_size
    for idx in range(0, batch_idxs):
        b_x = train_mri_tensor[idx*batch_size : (idx+1)*batch_size,:,:,:].to(device)
        b_y = train_pet_tensor[idx*batch_size : (idx+1)*batch_size,:,:,:].to(device)
        counter += 1
        output = cnn(b_x, b_y)             # cnn output
        ssim_loss_mri = 1 - ssim(output, b_x,data_range=1)
        ssim_loss_pet = 1 - ssim(output, b_y,data_range=1)
        ssim_total = ssim_loss_mri + ssim_loss_pet
        l2_total = l2_loss(output,b_x) + l2_loss(output,b_y)
        loss_total = lamda*ssim_total + (1-lamda)*l2_total 
        optimizer.zero_grad()              # clear gradients for this training step
        loss_total.backward()              # backpropagation, compute gradients
        optimizer.step()                   # apply gradients
        
        mri_ssim_Loss.append(ssim_loss_mri.item())
        pet_ssim_Loss.append(ssim_loss_pet.item())
        l2_Loss.append(l2_total.item())
        
        if counter % 100 == 0:
            print("Epoch: [%2d],step: [%2d], mri_ssim_loss: [%.8f], pet_ssim_loss: [%.8f],  total_ssim_loss: [%.8f], total_l2_loss: [%.8f], total_loss: [%.8f]" 
                   %(epoch, counter, ssim_loss_mri, ssim_loss_pet, ssim_total, l2_total, loss_total))
    
    av_mri_ssim_loss = np.average(mri_ssim_Loss)
    ep_mri_ssim_loss.append(av_mri_ssim_loss)
    
    av_pet_ssim_loss = np.average(pet_ssim_Loss)
    ep_pet_ssim_loss.append(av_pet_ssim_loss)
    
    av_total_l2_loss = np.average(l2_Loss)
    ep_total_l2_loss.append(av_total_l2_loss)
    
    if(epoch == EPOCH -1):
        #Save a checkpoint
        torch.save(cnn, 'C:/Users/horan/Desktop/FuseVis/.ipynb_checkpoints/DeepPedestrian/checkpoint.pth')
# Out:
# Epoch: [ 0],step: [100], mri_ssim_loss: [0.27498055], pet_ssim_loss: [0.05964434],  total_ssim_loss: [0.33462489], total_l2_loss: [0.02706867], total_loss: [0.27311367]
# Epoch: [ 0],step: [200], mri_ssim_loss: [0.44140923], pet_ssim_loss: [0.16461217],  total_ssim_loss: [0.60602140], total_l2_loss: [0.04328252], total_loss: [0.49347362]
# Epoch: [ 1],step: [300], mri_ssim_loss: [0.17709357], pet_ssim_loss: [0.26688582],  total_ssim_loss: [0.44397938], total_l2_loss: [0.01219955], total_loss: [0.35762343]
# Epoch: [ 1],step: [400], mri_ssim_loss: [0.14388502], pet_ssim_loss: [0.09936184],  total_ssim_loss: [0.24324685], total_l2_loss: [0.01854259], total_loss: [0.19830599]
# Epoch: [ 1],step: [500], mri_ssim_loss: [0.57011259], pet_ssim_loss: [0.22295058],  total_ssim_loss: [0.79306316], total_l2_loss: [0.02270441], total_loss: [0.63899142]
# Epoch: [ 2],step: [600], mri_ssim_loss: [0.31607038], pet_ssim_loss: [0.24056756],  total_ssim_loss: [0.55663794], total_l2_loss: [0.03183571], total_loss: [0.45167750]
# Epoch: [ 2],step: [700], mri_ssim_loss: [0.30712724], pet_ssim_loss: [0.10186201],  total_ssim_loss: [0.40898925], total_l2_loss: [0.02739155], total_loss: [0.33266973]
# Epoch: [ 2],step: [800], mri_ssim_loss: [0.20812130], pet_ssim_loss: [0.11670107],  total_ssim_loss: [0.32482237], total_l2_loss: [0.01656011], total_loss: [0.26316991]
# Epoch: [ 3],step: [900], mri_ssim_loss: [0.17350060], pet_ssim_loss: [0.15944713],  total_ssim_loss: [0.33294773], total_l2_loss: [0.02730496], total_loss: [0.27181917]
# Epoch: [ 3],step: [1000], mri_ssim_loss: [0.37433273], pet_ssim_loss: [0.09943372],  total_ssim_loss: [0.47376645], total_l2_loss: [0.03046610], total_loss: [0.38510638]
# Epoch: [ 4],step: [1100], mri_ssim_loss: [0.22022641], pet_ssim_loss: [0.12436628],  total_ssim_loss: [0.34459269], total_l2_loss: [0.01784992], total_loss: [0.27924415]
# Epoch: [ 4],step: [1200], mri_ssim_loss: [0.15856063], pet_ssim_loss: [0.10494238],  total_ssim_loss: [0.26350302], total_l2_loss: [0.01675240], total_loss: [0.21415290]
# Epoch: [ 4],step: [1300], mri_ssim_loss: [0.29678923], pet_ssim_loss: [0.08069873],  total_ssim_loss: [0.37748796], total_l2_loss: [0.02058689], total_loss: [0.30610773]
# Epoch: [ 5],step: [1400], mri_ssim_loss: [0.33739156], pet_ssim_loss: [0.26415890],  total_ssim_loss: [0.60155046], total_l2_loss: [0.01986256], total_loss: [0.48521286]
# Epoch: [ 5],step: [1500], mri_ssim_loss: [0.11925650], pet_ssim_loss: [0.05386358],  total_ssim_loss: [0.17312008], total_l2_loss: [0.02151717], total_loss: [0.14279951]
# Epoch: [ 5],step: [1600], mri_ssim_loss: [0.28741074], pet_ssim_loss: [0.12857735],  total_ssim_loss: [0.41598809], total_l2_loss: [0.01859505], total_loss: [0.33650947]
# Epoch: [ 6],step: [1700], mri_ssim_loss: [0.29525882], pet_ssim_loss: [0.22667843],  total_ssim_loss: [0.52193725], total_l2_loss: [0.04137903], total_loss: [0.42582563]
# Epoch: [ 6],step: [1800], mri_ssim_loss: [0.24378467], pet_ssim_loss: [0.15488702],  total_ssim_loss: [0.39867169], total_l2_loss: [0.02223921], total_loss: [0.32338521]
# Epoch: [ 6],step: [1900], mri_ssim_loss: [0.26051950], pet_ssim_loss: [0.12296599],  total_ssim_loss: [0.38348550], total_l2_loss: [0.01850800], total_loss: [0.31049001]
# Epoch: [ 7],step: [2000], mri_ssim_loss: [0.16589123], pet_ssim_loss: [0.12632465],  total_ssim_loss: [0.29221588], total_l2_loss: [0.02057059], total_loss: [0.23788683]
# Epoch: [ 7],step: [2100], mri_ssim_loss: [0.40079504], pet_ssim_loss: [0.17202723],  total_ssim_loss: [0.57282227], total_l2_loss: [0.03549747], total_loss: [0.46535730]
# Epoch: [ 8],step: [2200], mri_ssim_loss: [0.22416562], pet_ssim_loss: [0.23760611],  total_ssim_loss: [0.46177173], total_l2_loss: [0.01595510], total_loss: [0.37260842]
# Epoch: [ 8],step: [2300], mri_ssim_loss: [0.13667619], pet_ssim_loss: [0.11009359],  total_ssim_loss: [0.24676979], total_l2_loss: [0.01859540], total_loss: [0.20113491]
# Epoch: [ 8],step: [2400], mri_ssim_loss: [0.48111135], pet_ssim_loss: [0.25315130],  total_ssim_loss: [0.73426265], total_l2_loss: [0.03340371], total_loss: [0.59409088]
# Epoch: [ 9],step: [2500], mri_ssim_loss: [0.27306098], pet_ssim_loss: [0.18324769],  total_ssim_loss: [0.45630866], total_l2_loss: [0.01705400], total_loss: [0.36845773]
# Epoch: [ 9],step: [2600], mri_ssim_loss: [0.19960815], pet_ssim_loss: [0.06805569],  total_ssim_loss: [0.26766384], total_l2_loss: [0.01628424], total_loss: [0.21738791]
# Epoch: [ 9],step: [2700], mri_ssim_loss: [0.21054071], pet_ssim_loss: [0.15356821],  total_ssim_loss: [0.36410892], total_l2_loss: [0.02770050], total_loss: [0.29682726]
# Epoch: [10],step: [2800], mri_ssim_loss: [0.17480826], pet_ssim_loss: [0.15212238],  total_ssim_loss: [0.32693064], total_l2_loss: [0.03309081], total_loss: [0.26816270]
# Epoch: [10],step: [2900], mri_ssim_loss: [0.39514297], pet_ssim_loss: [0.08257711],  total_ssim_loss: [0.47772008], total_l2_loss: [0.03998987], total_loss: [0.39017403]
# Epoch: [11],step: [3000], mri_ssim_loss: [0.21327680], pet_ssim_loss: [0.16596389],  total_ssim_loss: [0.37924069], total_l2_loss: [0.01065081], total_loss: [0.30552271]
# Epoch: [11],step: [3100], mri_ssim_loss: [0.14043361], pet_ssim_loss: [0.12339967],  total_ssim_loss: [0.26383328], total_l2_loss: [0.01705149], total_loss: [0.21447693]
# Epoch: [11],step: [3200], mri_ssim_loss: [0.27853614], pet_ssim_loss: [0.14256191],  total_ssim_loss: [0.42109805], total_l2_loss: [0.01523965], total_loss: [0.33992639]
# Epoch: [12],step: [3300], mri_ssim_loss: [0.32163024], pet_ssim_loss: [0.30042577],  total_ssim_loss: [0.62205601], total_l2_loss: [0.01945036], total_loss: [0.50153488]
# Epoch: [12],step: [3400], mri_ssim_loss: [0.12340319], pet_ssim_loss: [0.08548552],  total_ssim_loss: [0.20888871], total_l2_loss: [0.02072126], total_loss: [0.17125522]
# Epoch: [12],step: [3500], mri_ssim_loss: [0.30183029], pet_ssim_loss: [0.13928562],  total_ssim_loss: [0.44111592], total_l2_loss: [0.01894468], total_loss: [0.35668167]
# Epoch: [13],step: [3600], mri_ssim_loss: [0.26895720], pet_ssim_loss: [0.30646145],  total_ssim_loss: [0.57541865], total_l2_loss: [0.04786786], total_loss: [0.46990851]
# Epoch: [13],step: [3700], mri_ssim_loss: [0.23995709], pet_ssim_loss: [0.14573747],  total_ssim_loss: [0.38569456], total_l2_loss: [0.01419171], total_loss: [0.31139401]
# Epoch: [13],step: [3800], mri_ssim_loss: [0.31766200], pet_ssim_loss: [0.16659272],  total_ssim_loss: [0.48425472], total_l2_loss: [0.03638334], total_loss: [0.39468044]
# Epoch: [14],step: [3900], mri_ssim_loss: [0.16403365], pet_ssim_loss: [0.14354217],  total_ssim_loss: [0.30757582], total_l2_loss: [0.02324541], total_loss: [0.25070974]
# Epoch: [14],step: [4000], mri_ssim_loss: [0.26057243], pet_ssim_loss: [0.12767923],  total_ssim_loss: [0.38825166], total_l2_loss: [0.01439329], total_loss: [0.31347999]
# Epoch: [15],step: [4100], mri_ssim_loss: [0.25440979], pet_ssim_loss: [0.27279335],  total_ssim_loss: [0.52720314], total_l2_loss: [0.02269636], total_loss: [0.42630181]
# Epoch: [15],step: [4200], mri_ssim_loss: [0.13673323], pet_ssim_loss: [0.10483670],  total_ssim_loss: [0.24156994], total_l2_loss: [0.01712084], total_loss: [0.19668011]
# Epoch: [15],step: [4300], mri_ssim_loss: [0.47393185], pet_ssim_loss: [0.23526454],  total_ssim_loss: [0.70919639], total_l2_loss: [0.01666120], total_loss: [0.57068938]
# Epoch: [16],step: [4400], mri_ssim_loss: [0.31953377], pet_ssim_loss: [0.22811139],  total_ssim_loss: [0.54764515], total_l2_loss: [0.01874837], total_loss: [0.44186580]
# Epoch: [16],step: [4500], mri_ssim_loss: [0.25776088], pet_ssim_loss: [0.14834541],  total_ssim_loss: [0.40610629], total_l2_loss: [0.01563825], total_loss: [0.32801268]
# Epoch: [16],step: [4600], mri_ssim_loss: [0.21346301], pet_ssim_loss: [0.17615193],  total_ssim_loss: [0.38961494], total_l2_loss: [0.03013589], total_loss: [0.31771916]
# Epoch: [17],step: [4700], mri_ssim_loss: [0.23790503], pet_ssim_loss: [0.20595431],  total_ssim_loss: [0.44385934], total_l2_loss: [0.03631408], total_loss: [0.36235031]
# Epoch: [17],step: [4800], mri_ssim_loss: [0.22977638], pet_ssim_loss: [0.12286663],  total_ssim_loss: [0.35264301], total_l2_loss: [0.02063569], total_loss: [0.28624156]
# Epoch: [18],step: [4900], mri_ssim_loss: [0.26338094], pet_ssim_loss: [0.14307803],  total_ssim_loss: [0.40645897], total_l2_loss: [0.02591901], total_loss: [0.33035100]
# Epoch: [18],step: [5000], mri_ssim_loss: [0.13779563], pet_ssim_loss: [0.12900865],  total_ssim_loss: [0.26680428], total_l2_loss: [0.01900638], total_loss: [0.21724470]
# Epoch: [18],step: [5100], mri_ssim_loss: [0.33305222], pet_ssim_loss: [0.18995070],  total_ssim_loss: [0.52300292], total_l2_loss: [0.02445446], total_loss: [0.42329323]
# Epoch: [19],step: [5200], mri_ssim_loss: [0.32784885], pet_ssim_loss: [0.25029474],  total_ssim_loss: [0.57814360], total_l2_loss: [0.03481737], total_loss: [0.46947834]
# Epoch: [19],step: [5300], mri_ssim_loss: [0.11849105], pet_ssim_loss: [0.10591251],  total_ssim_loss: [0.22440356], total_l2_loss: [0.02064234], total_loss: [0.18365133]
# Epoch: [19],step: [5400], mri_ssim_loss: [0.34174645], pet_ssim_loss: [0.12833643],  total_ssim_loss: [0.47008288], total_l2_loss: [0.03861758], total_loss: [0.38378981]
# Epoch: [20],step: [5500], mri_ssim_loss: [0.28634417], pet_ssim_loss: [0.28520131],  total_ssim_loss: [0.57154548], total_l2_loss: [0.04635767], total_loss: [0.46650791]
# Epoch: [20],step: [5600], mri_ssim_loss: [0.24744105], pet_ssim_loss: [0.14737427],  total_ssim_loss: [0.39481533], total_l2_loss: [0.01428138], total_loss: [0.31870854]
# Epoch: [20],step: [5700], mri_ssim_loss: [0.12250215], pet_ssim_loss: [0.03667015],  total_ssim_loss: [0.15917230], total_l2_loss: [0.00770969], total_loss: [0.12887979]
# Epoch: [21],step: [5800], mri_ssim_loss: [0.16997999], pet_ssim_loss: [0.14920521],  total_ssim_loss: [0.31918520], total_l2_loss: [0.02608109], total_loss: [0.26056439]
# Epoch: [21],step: [5900], mri_ssim_loss: [0.31320798], pet_ssim_loss: [0.14179134],  total_ssim_loss: [0.45499933], total_l2_loss: [0.02888709], total_loss: [0.36977687]
# Epoch: [22],step: [6000], mri_ssim_loss: [0.26367474], pet_ssim_loss: [0.29625183],  total_ssim_loss: [0.55992657], total_l2_loss: [0.01982274], total_loss: [0.45190582]
# Epoch: [22],step: [6100], mri_ssim_loss: [0.14261252], pet_ssim_loss: [0.10399967],  total_ssim_loss: [0.24661219], total_l2_loss: [0.01622001], total_loss: [0.20053375]
# Epoch: [22],step: [6200], mri_ssim_loss: [0.59956717], pet_ssim_loss: [0.19581681],  total_ssim_loss: [0.79538399], total_l2_loss: [0.02094381], total_loss: [0.64049596]
# Epoch: [23],step: [6300], mri_ssim_loss: [0.32014608], pet_ssim_loss: [0.24775022],  total_ssim_loss: [0.56789631], total_l2_loss: [0.01723249], total_loss: [0.45776355]
# Epoch: [23],step: [6400], mri_ssim_loss: [0.31851035], pet_ssim_loss: [0.20844096],  total_ssim_loss: [0.52695131], total_l2_loss: [0.02576156], total_loss: [0.42671338]
# Epoch: [23],step: [6500], mri_ssim_loss: [0.21815807], pet_ssim_loss: [0.12415582],  total_ssim_loss: [0.34231389], total_l2_loss: [0.01359075], total_loss: [0.27656928]
# Epoch: [24],step: [6600], mri_ssim_loss: [0.25947338], pet_ssim_loss: [0.21340823],  total_ssim_loss: [0.47288162], total_l2_loss: [0.03781850], total_loss: [0.38586900]
# Epoch: [24],step: [6700], mri_ssim_loss: [0.22974181], pet_ssim_loss: [0.15099138],  total_ssim_loss: [0.38073319], total_l2_loss: [0.03164785], total_loss: [0.31091613]
# Epoch: [24],step: [6800], mri_ssim_loss: [0.47325170], pet_ssim_loss: [0.07810450],  total_ssim_loss: [0.55135620], total_l2_loss: [0.05457311], total_loss: [0.45199957]
# Epoch: [25],step: [6900], mri_ssim_loss: [0.15602010], pet_ssim_loss: [0.12361157],  total_ssim_loss: [0.27963167], total_l2_loss: [0.02076698], total_loss: [0.22785874]
# Epoch: [25],step: [7000], mri_ssim_loss: [0.32978380], pet_ssim_loss: [0.23181659],  total_ssim_loss: [0.56160039], total_l2_loss: [0.04081920], total_loss: [0.45744416]
# Epoch: [26],step: [7100], mri_ssim_loss: [0.16526496], pet_ssim_loss: [0.25610793],  total_ssim_loss: [0.42137289], total_l2_loss: [0.01226210], total_loss: [0.33955076]
# Epoch: [26],step: [7200], mri_ssim_loss: [0.12128824], pet_ssim_loss: [0.11054957],  total_ssim_loss: [0.23183781], total_l2_loss: [0.01869746], total_loss: [0.18920974]
# Epoch: [26],step: [7300], mri_ssim_loss: [0.54105759], pet_ssim_loss: [0.21990395],  total_ssim_loss: [0.76096153], total_l2_loss: [0.02283439], total_loss: [0.61333609]
# Epoch: [27],step: [7400], mri_ssim_loss: [0.27981633], pet_ssim_loss: [0.26480800],  total_ssim_loss: [0.54462433], total_l2_loss: [0.03418854], total_loss: [0.44253716]
# Epoch: [27],step: [7500], mri_ssim_loss: [0.28552961], pet_ssim_loss: [0.11466241],  total_ssim_loss: [0.40019202], total_l2_loss: [0.02610765], total_loss: [0.32537514]
# Epoch: [27],step: [7600], mri_ssim_loss: [0.20949733], pet_ssim_loss: [0.10518348],  total_ssim_loss: [0.31468081], total_l2_loss: [0.01812912], total_loss: [0.25537047]
# Epoch: [28],step: [7700], mri_ssim_loss: [0.16829991], pet_ssim_loss: [0.15800357],  total_ssim_loss: [0.32630348], total_l2_loss: [0.02751159], total_loss: [0.26654512]
# Epoch: [28],step: [7800], mri_ssim_loss: [0.35922647], pet_ssim_loss: [0.11151028],  total_ssim_loss: [0.47073674], total_l2_loss: [0.03305376], total_loss: [0.38320014]
# Epoch: [29],step: [7900], mri_ssim_loss: [0.21333283], pet_ssim_loss: [0.12864614],  total_ssim_loss: [0.34197897], total_l2_loss: [0.01706462], total_loss: [0.27699611]
# Epoch: [29],step: [8000], mri_ssim_loss: [0.15159190], pet_ssim_loss: [0.10857117],  total_ssim_loss: [0.26016307], total_l2_loss: [0.01685846], total_loss: [0.21150215]
# Epoch: [29],step: [8100], mri_ssim_loss: [0.28843361], pet_ssim_loss: [0.08569640],  total_ssim_loss: [0.37413001], total_l2_loss: [0.01843863], total_loss: [0.30299175]
# Epoch: [30],step: [8200], mri_ssim_loss: [0.31988329], pet_ssim_loss: [0.27571964],  total_ssim_loss: [0.59560293], total_l2_loss: [0.01942937], total_loss: [0.48036823]
# Epoch: [30],step: [8300], mri_ssim_loss: [0.11221594], pet_ssim_loss: [0.05836296],  total_ssim_loss: [0.17057890], total_l2_loss: [0.02141919], total_loss: [0.14074697]
# Epoch: [30],step: [8400], mri_ssim_loss: [0.28284448], pet_ssim_loss: [0.11549127],  total_ssim_loss: [0.39833575], total_l2_loss: [0.02006164], total_loss: [0.32268092]
# Epoch: [31],step: [8500], mri_ssim_loss: [0.27856737], pet_ssim_loss: [0.23894691],  total_ssim_loss: [0.51751429], total_l2_loss: [0.04166374], total_loss: [0.42234421]
# Epoch: [31],step: [8600], mri_ssim_loss: [0.22450197], pet_ssim_loss: [0.16940296],  total_ssim_loss: [0.39390492], total_l2_loss: [0.02161872], total_loss: [0.31944770]
# Epoch: [31],step: [8700], mri_ssim_loss: [0.25953430], pet_ssim_loss: [0.12214440],  total_ssim_loss: [0.38167870], total_l2_loss: [0.01723705], total_loss: [0.30879039]
# Epoch: [32],step: [8800], mri_ssim_loss: [0.15732741], pet_ssim_loss: [0.13058859],  total_ssim_loss: [0.28791600], total_l2_loss: [0.02093223], total_loss: [0.23451926]
# Epoch: [32],step: [8900], mri_ssim_loss: [0.39953893], pet_ssim_loss: [0.16989952],  total_ssim_loss: [0.56943846], total_l2_loss: [0.03550430], total_loss: [0.46265161]
# Epoch: [33],step: [9000], mri_ssim_loss: [0.21378112], pet_ssim_loss: [0.24604791],  total_ssim_loss: [0.45982903], total_l2_loss: [0.01542035], total_loss: [0.37094730]
# Epoch: [33],step: [9100], mri_ssim_loss: [0.13518006], pet_ssim_loss: [0.10893905],  total_ssim_loss: [0.24411911], total_l2_loss: [0.01869637], total_loss: [0.19903456]
# Epoch: [33],step: [9200], mri_ssim_loss: [0.41455543], pet_ssim_loss: [0.32489073],  total_ssim_loss: [0.73944616], total_l2_loss: [0.03823653], total_loss: [0.59920430]
# Epoch: [34],step: [9300], mri_ssim_loss: [0.26814181], pet_ssim_loss: [0.18580180],  total_ssim_loss: [0.45394361], total_l2_loss: [0.01739402], total_loss: [0.36663368]
# Epoch: [34],step: [9400], mri_ssim_loss: [0.18602705], pet_ssim_loss: [0.08102125],  total_ssim_loss: [0.26704830], total_l2_loss: [0.01604158], total_loss: [0.21684696]
# Epoch: [34],step: [9500], mri_ssim_loss: [0.21203136], pet_ssim_loss: [0.15023822],  total_ssim_loss: [0.36226958], total_l2_loss: [0.02831142], total_loss: [0.29547796]
# Epoch: [35],step: [9600], mri_ssim_loss: [0.17166179], pet_ssim_loss: [0.15197164],  total_ssim_loss: [0.32363343], total_l2_loss: [0.03332505], total_loss: [0.26557177]
# Epoch: [35],step: [9700], mri_ssim_loss: [0.37830043], pet_ssim_loss: [0.09723145],  total_ssim_loss: [0.47553188], total_l2_loss: [0.04019959], total_loss: [0.38846543]
# Epoch: [36],step: [9800], mri_ssim_loss: [0.21438152], pet_ssim_loss: [0.16279262],  total_ssim_loss: [0.37717414], total_l2_loss: [0.01061384], total_loss: [0.30386207]
# Epoch: [36],step: [9900], mri_ssim_loss: [0.14290863], pet_ssim_loss: [0.11864650],  total_ssim_loss: [0.26155514], total_l2_loss: [0.01726718], total_loss: [0.21269755]
# Epoch: [36],step: [10000], mri_ssim_loss: [0.28279239], pet_ssim_loss: [0.13559514],  total_ssim_loss: [0.41838753], total_l2_loss: [0.01493883], total_loss: [0.33769780]
# Epoch: [37],step: [10100], mri_ssim_loss: [0.32280260], pet_ssim_loss: [0.29586321],  total_ssim_loss: [0.61866581], total_l2_loss: [0.01876101], total_loss: [0.49868485]
# Epoch: [37],step: [10200], mri_ssim_loss: [0.12521476], pet_ssim_loss: [0.08134282],  total_ssim_loss: [0.20655757], total_l2_loss: [0.02101099], total_loss: [0.16944826]
# Epoch: [37],step: [10300], mri_ssim_loss: [0.29864866], pet_ssim_loss: [0.13823205],  total_ssim_loss: [0.43688071], total_l2_loss: [0.01863001], total_loss: [0.35323057]
# Epoch: [38],step: [10400], mri_ssim_loss: [0.27562726], pet_ssim_loss: [0.29572618],  total_ssim_loss: [0.57135344], total_l2_loss: [0.04639782], total_loss: [0.46636230]
# Epoch: [38],step: [10500], mri_ssim_loss: [0.23359954], pet_ssim_loss: [0.15135729],  total_ssim_loss: [0.38495684], total_l2_loss: [0.01427241], total_loss: [0.31081998]
# Epoch: [38],step: [10600], mri_ssim_loss: [0.31050420], pet_ssim_loss: [0.16940767],  total_ssim_loss: [0.47991186], total_l2_loss: [0.03617468], total_loss: [0.39116442]
# Epoch: [39],step: [10700], mri_ssim_loss: [0.16275191], pet_ssim_loss: [0.14229000],  total_ssim_loss: [0.30504191], total_l2_loss: [0.02337803], total_loss: [0.24870914]
# Epoch: [39],step: [10800], mri_ssim_loss: [0.25823259], pet_ssim_loss: [0.12727851],  total_ssim_loss: [0.38551110], total_l2_loss: [0.01422718], total_loss: [0.31125432]
# Epoch: [40],step: [10900], mri_ssim_loss: [0.24174958], pet_ssim_loss: [0.27890992],  total_ssim_loss: [0.52065951], total_l2_loss: [0.02243206], total_loss: [0.42101401]
# Epoch: [40],step: [11000], mri_ssim_loss: [0.13382918], pet_ssim_loss: [0.10596132],  total_ssim_loss: [0.23979050], total_l2_loss: [0.01728383], total_loss: [0.19528918]
# Epoch: [40],step: [11100], mri_ssim_loss: [0.45077002], pet_ssim_loss: [0.25358111],  total_ssim_loss: [0.70435113], total_l2_loss: [0.01619226], total_loss: [0.56671935]
# Epoch: [41],step: [11200], mri_ssim_loss: [0.31042403], pet_ssim_loss: [0.23356915],  total_ssim_loss: [0.54399318], total_l2_loss: [0.01910686], total_loss: [0.43901592]
# Epoch: [41],step: [11300], mri_ssim_loss: [0.24120378], pet_ssim_loss: [0.16149622],  total_ssim_loss: [0.40270001], total_l2_loss: [0.01573443], total_loss: [0.32530689]
# Epoch: [41],step: [11400], mri_ssim_loss: [0.22104877], pet_ssim_loss: [0.16700703],  total_ssim_loss: [0.38805580], total_l2_loss: [0.03165660], total_loss: [0.31677598]
# Epoch: [42],step: [11500], mri_ssim_loss: [0.22988343], pet_ssim_loss: [0.21146214],  total_ssim_loss: [0.44134557], total_l2_loss: [0.03669300], total_loss: [0.36041507]
# Epoch: [42],step: [11600], mri_ssim_loss: [0.21546566], pet_ssim_loss: [0.13440585],  total_ssim_loss: [0.34987152], total_l2_loss: [0.02017339], total_loss: [0.28393188]
# Epoch: [43],step: [11700], mri_ssim_loss: [0.26305562], pet_ssim_loss: [0.14127493],  total_ssim_loss: [0.40433055], total_l2_loss: [0.02599542], total_loss: [0.32866353]
# Epoch: [43],step: [11800], mri_ssim_loss: [0.13759595], pet_ssim_loss: [0.12675488],  total_ssim_loss: [0.26435083], total_l2_loss: [0.01907006], total_loss: [0.21529467]
# Epoch: [43],step: [11900], mri_ssim_loss: [0.33651716], pet_ssim_loss: [0.18290597],  total_ssim_loss: [0.51942313], total_l2_loss: [0.02447705], total_loss: [0.42043394]
# Epoch: [44],step: [12000], mri_ssim_loss: [0.34734952], pet_ssim_loss: [0.25250483],  total_ssim_loss: [0.59985435], total_l2_loss: [0.03367453], total_loss: [0.48661840]
# Epoch: [44],step: [12100], mri_ssim_loss: [0.12730831], pet_ssim_loss: [0.09921980],  total_ssim_loss: [0.22652811], total_l2_loss: [0.02086902], total_loss: [0.18539628]
# Epoch: [44],step: [12200], mri_ssim_loss: [0.38451767], pet_ssim_loss: [0.17697507],  total_ssim_loss: [0.56149274], total_l2_loss: [0.04492600], total_loss: [0.45817938]
# Epoch: [45],step: [12300], mri_ssim_loss: [0.29477447], pet_ssim_loss: [0.27871996],  total_ssim_loss: [0.57349443], total_l2_loss: [0.04652787], total_loss: [0.46810111]
# Epoch: [45],step: [12400], mri_ssim_loss: [0.24616408], pet_ssim_loss: [0.14802402],  total_ssim_loss: [0.39418811], total_l2_loss: [0.01455725], total_loss: [0.31826195]
# Epoch: [45],step: [12500], mri_ssim_loss: [0.11585820], pet_ssim_loss: [0.04288667],  total_ssim_loss: [0.15874487], total_l2_loss: [0.00729858], total_loss: [0.12845562]
# Epoch: [46],step: [12600], mri_ssim_loss: [0.17992842], pet_ssim_loss: [0.14041775],  total_ssim_loss: [0.32034618], total_l2_loss: [0.02571216], total_loss: [0.26141936]
# Epoch: [46],step: [12700], mri_ssim_loss: [0.31582677], pet_ssim_loss: [0.13689637],  total_ssim_loss: [0.45272315], total_l2_loss: [0.02891038], total_loss: [0.36796060]
# Epoch: [47],step: [12800], mri_ssim_loss: [0.27433473], pet_ssim_loss: [0.30360270],  total_ssim_loss: [0.57793742], total_l2_loss: [0.02136790], total_loss: [0.46662354]
# Epoch: [47],step: [12900], mri_ssim_loss: [0.14925551], pet_ssim_loss: [0.09658092],  total_ssim_loss: [0.24583644], total_l2_loss: [0.01660640], total_loss: [0.19999042]
# Epoch: [47],step: [13000], mri_ssim_loss: [0.50379014], pet_ssim_loss: [0.29340053],  total_ssim_loss: [0.79719067], total_l2_loss: [0.02186992], total_loss: [0.64212650]
# Epoch: [48],step: [13100], mri_ssim_loss: [0.33343691], pet_ssim_loss: [0.22222632],  total_ssim_loss: [0.55566323], total_l2_loss: [0.01860611], total_loss: [0.44825181]
# Epoch: [48],step: [13200], mri_ssim_loss: [0.32330108], pet_ssim_loss: [0.19790691],  total_ssim_loss: [0.52120799], total_l2_loss: [0.02572691], total_loss: [0.42211178]
# Epoch: [48],step: [13300], mri_ssim_loss: [0.21192127], pet_ssim_loss: [0.12056684],  total_ssim_loss: [0.33248812], total_l2_loss: [0.01343063], total_loss: [0.26867661]
# Epoch: [49],step: [13400], mri_ssim_loss: [0.25297850], pet_ssim_loss: [0.21885484],  total_ssim_loss: [0.47183335], total_l2_loss: [0.04038702], total_loss: [0.38554409]
# Epoch: [49],step: [13500], mri_ssim_loss: [0.22963846], pet_ssim_loss: [0.15032840],  total_ssim_loss: [0.37996686], total_l2_loss: [0.03161187], total_loss: [0.31029588]
# Epoch: [49],step: [13600], mri_ssim_loss: [0.47215468], pet_ssim_loss: [0.07487732],  total_ssim_loss: [0.54703200], total_l2_loss: [0.05474211], total_loss: [0.44857404]
# Epoch: [50],step: [13700], mri_ssim_loss: [0.15582055], pet_ssim_loss: [0.12213081],  total_ssim_loss: [0.27795136], total_l2_loss: [0.02079324], total_loss: [0.22651973]
# Epoch: [50],step: [13800], mri_ssim_loss: [0.33846951], pet_ssim_loss: [0.22099262],  total_ssim_loss: [0.55946213], total_l2_loss: [0.04098255], total_loss: [0.45576620]
# Epoch: [51],step: [13900], mri_ssim_loss: [0.17429763], pet_ssim_loss: [0.24774313],  total_ssim_loss: [0.42204076], total_l2_loss: [0.01408210], total_loss: [0.34044904]
# Epoch: [51],step: [14000], mri_ssim_loss: [0.12831336], pet_ssim_loss: [0.10307544],  total_ssim_loss: [0.23138881], total_l2_loss: [0.01879417], total_loss: [0.18886988]
# Epoch: [51],step: [14100], mri_ssim_loss: [0.54959619], pet_ssim_loss: [0.22654152],  total_ssim_loss: [0.77613771], total_l2_loss: [0.02265048], total_loss: [0.62544024]
# Epoch: [52],step: [14200], mri_ssim_loss: [0.29273635], pet_ssim_loss: [0.25084150],  total_ssim_loss: [0.54357785], total_l2_loss: [0.03299553], total_loss: [0.44146138]
# Epoch: [52],step: [14300], mri_ssim_loss: [0.28290701], pet_ssim_loss: [0.11630976],  total_ssim_loss: [0.39921677], total_l2_loss: [0.02734519], total_loss: [0.32484245]
# Epoch: [52],step: [14400], mri_ssim_loss: [0.19593066], pet_ssim_loss: [0.11700577],  total_ssim_loss: [0.31293643], total_l2_loss: [0.01706556], total_loss: [0.25376225]
# Epoch: [53],step: [14500], mri_ssim_loss: [0.17771548], pet_ssim_loss: [0.14890915],  total_ssim_loss: [0.32662463], total_l2_loss: [0.02808005], total_loss: [0.26691571]
# Epoch: [53],step: [14600], mri_ssim_loss: [0.35252792], pet_ssim_loss: [0.11278498],  total_ssim_loss: [0.46531290], total_l2_loss: [0.02891210], total_loss: [0.37803274]
# Epoch: [54],step: [14700], mri_ssim_loss: [0.21620333], pet_ssim_loss: [0.12473190],  total_ssim_loss: [0.34093523], total_l2_loss: [0.01616753], total_loss: [0.27598169]
# Epoch: [54],step: [14800], mri_ssim_loss: [0.15354651], pet_ssim_loss: [0.10572255],  total_ssim_loss: [0.25926906], total_l2_loss: [0.01682687], total_loss: [0.21078062]
# Epoch: [54],step: [14900], mri_ssim_loss: [0.28880280], pet_ssim_loss: [0.08393735],  total_ssim_loss: [0.37274015], total_l2_loss: [0.01855326], total_loss: [0.30190277]
# Epoch: [55],step: [15000], mri_ssim_loss: [0.32706589], pet_ssim_loss: [0.26740545],  total_ssim_loss: [0.59447134], total_l2_loss: [0.01936704], total_loss: [0.47945049]
# Epoch: [55],step: [15100], mri_ssim_loss: [0.11970276], pet_ssim_loss: [0.05038136],  total_ssim_loss: [0.17008412], total_l2_loss: [0.02169689], total_loss: [0.14040668]
# Epoch: [55],step: [15200], mri_ssim_loss: [0.28280449], pet_ssim_loss: [0.11183852],  total_ssim_loss: [0.39464301], total_l2_loss: [0.01916876], total_loss: [0.31954816]
# Epoch: [56],step: [15300], mri_ssim_loss: [0.28696674], pet_ssim_loss: [0.23126519],  total_ssim_loss: [0.51823193], total_l2_loss: [0.04243152], total_loss: [0.42307186]
# Epoch: [56],step: [15400], mri_ssim_loss: [0.21677744], pet_ssim_loss: [0.17565876],  total_ssim_loss: [0.39243621], total_l2_loss: [0.02135676], total_loss: [0.31822032]
# Epoch: [56],step: [15500], mri_ssim_loss: [0.25492162], pet_ssim_loss: [0.12491530],  total_ssim_loss: [0.37983692], total_l2_loss: [0.01776568], total_loss: [0.30742267]
# Epoch: [57],step: [15600], mri_ssim_loss: [0.15712106], pet_ssim_loss: [0.12994176],  total_ssim_loss: [0.28706282], total_l2_loss: [0.02096368], total_loss: [0.23384300]
# Epoch: [57],step: [15700], mri_ssim_loss: [0.41049856], pet_ssim_loss: [0.15703309],  total_ssim_loss: [0.56753165], total_l2_loss: [0.03578479], total_loss: [0.46118230]
# Epoch: [58],step: [15800], mri_ssim_loss: [0.21732014], pet_ssim_loss: [0.24153322],  total_ssim_loss: [0.45885336], total_l2_loss: [0.01532438], total_loss: [0.37014756]
# Epoch: [58],step: [15900], mri_ssim_loss: [0.14589715], pet_ssim_loss: [0.09727407],  total_ssim_loss: [0.24317122], total_l2_loss: [0.01886753], total_loss: [0.19831048]
# Epoch: [58],step: [16000], mri_ssim_loss: [0.44179577], pet_ssim_loss: [0.28507423],  total_ssim_loss: [0.72687000], total_l2_loss: [0.03301752], total_loss: [0.58809948]
# Epoch: [59],step: [16100], mri_ssim_loss: [0.27702081], pet_ssim_loss: [0.17479694],  total_ssim_loss: [0.45181775], total_l2_loss: [0.01861453], total_loss: [0.36517712]
# Epoch: [59],step: [16200], mri_ssim_loss: [0.18896914], pet_ssim_loss: [0.07670945],  total_ssim_loss: [0.26567858], total_l2_loss: [0.01611798], total_loss: [0.21576647]
# Epoch: [59],step: [16300], mri_ssim_loss: [0.21191388], pet_ssim_loss: [0.14811879],  total_ssim_loss: [0.36003268], total_l2_loss: [0.02857708], total_loss: [0.29374158]
# Epoch: [60],step: [16400], mri_ssim_loss: [0.17603779], pet_ssim_loss: [0.14568377],  total_ssim_loss: [0.32172155], total_l2_loss: [0.03345935], total_loss: [0.26406911]
# Epoch: [60],step: [16500], mri_ssim_loss: [0.37960714], pet_ssim_loss: [0.09393620],  total_ssim_loss: [0.47354335], total_l2_loss: [0.03902844], total_loss: [0.38664037]
# Epoch: [61],step: [16600], mri_ssim_loss: [0.21626568], pet_ssim_loss: [0.15911502],  total_ssim_loss: [0.37538069], total_l2_loss: [0.01109249], total_loss: [0.30252305]
# Epoch: [61],step: [16700], mri_ssim_loss: [0.15090084], pet_ssim_loss: [0.10957426],  total_ssim_loss: [0.26047510], total_l2_loss: [0.01732888], total_loss: [0.21184586]
# Epoch: [61],step: [16800], mri_ssim_loss: [0.28065825], pet_ssim_loss: [0.13500899],  total_ssim_loss: [0.41566724], total_l2_loss: [0.01501560], total_loss: [0.33553693]
# Epoch: [62],step: [16900], mri_ssim_loss: [0.33398914], pet_ssim_loss: [0.28300488],  total_ssim_loss: [0.61699402], total_l2_loss: [0.01896697], total_loss: [0.49738860]
# Epoch: [62],step: [17000], mri_ssim_loss: [0.13736117], pet_ssim_loss: [0.06769627],  total_ssim_loss: [0.20505744], total_l2_loss: [0.02131351], total_loss: [0.16830866]
# Epoch: [62],step: [17100], mri_ssim_loss: [0.29617417], pet_ssim_loss: [0.13686234],  total_ssim_loss: [0.43303651], total_l2_loss: [0.01868371], total_loss: [0.35016593]
# Epoch: [63],step: [17200], mri_ssim_loss: [0.27487028], pet_ssim_loss: [0.29162180],  total_ssim_loss: [0.56649208], total_l2_loss: [0.04608162], total_loss: [0.46240997]
# Epoch: [63],step: [17300], mri_ssim_loss: [0.22353739], pet_ssim_loss: [0.15765685],  total_ssim_loss: [0.38119423], total_l2_loss: [0.01367155], total_loss: [0.30768970]
# Epoch: [63],step: [17400], mri_ssim_loss: [0.31043756], pet_ssim_loss: [0.16584414],  total_ssim_loss: [0.47628170], total_l2_loss: [0.03599950], total_loss: [0.38822529]
# Epoch: [64],step: [17500], mri_ssim_loss: [0.16793990], pet_ssim_loss: [0.13542730],  total_ssim_loss: [0.30336720], total_l2_loss: [0.02383373], total_loss: [0.24746051]
# Epoch: [64],step: [17600], mri_ssim_loss: [0.26452506], pet_ssim_loss: [0.11886954],  total_ssim_loss: [0.38339460], total_l2_loss: [0.01442534], total_loss: [0.30960077]
# Epoch: [65],step: [17700], mri_ssim_loss: [0.24134505], pet_ssim_loss: [0.36015296],  total_ssim_loss: [0.60149801], total_l2_loss: [0.02405877], total_loss: [0.48601016]
# Epoch: [65],step: [17800], mri_ssim_loss: [0.13660079], pet_ssim_loss: [0.10757101],  total_ssim_loss: [0.24417180], total_l2_loss: [0.01686028], total_loss: [0.19870950]
# Epoch: [65],step: [17900], mri_ssim_loss: [0.41739082], pet_ssim_loss: [0.31952494],  total_ssim_loss: [0.73691577], total_l2_loss: [0.01995213], total_loss: [0.59352303]
# Epoch: [66],step: [18000], mri_ssim_loss: [0.32060987], pet_ssim_loss: [0.22621465],  total_ssim_loss: [0.54682451], total_l2_loss: [0.01900830], total_loss: [0.44126129]
# Epoch: [66],step: [18100], mri_ssim_loss: [0.24739295], pet_ssim_loss: [0.15658039],  total_ssim_loss: [0.40397334], total_l2_loss: [0.01572227], total_loss: [0.32632312]
# Epoch: [66],step: [18200], mri_ssim_loss: [0.21821904], pet_ssim_loss: [0.17007267],  total_ssim_loss: [0.38829172], total_l2_loss: [0.03095422], total_loss: [0.31682423]
# Epoch: [67],step: [18300], mri_ssim_loss: [0.23641801], pet_ssim_loss: [0.20427644],  total_ssim_loss: [0.44069445], total_l2_loss: [0.03415217], total_loss: [0.35938600]
# Epoch: [67],step: [18400], mri_ssim_loss: [0.21635157], pet_ssim_loss: [0.13391280],  total_ssim_loss: [0.35026437], total_l2_loss: [0.02042337], total_loss: [0.28429618]
# Epoch: [68],step: [18500], mri_ssim_loss: [0.26275259], pet_ssim_loss: [0.14228898],  total_ssim_loss: [0.40504158], total_l2_loss: [0.02687514], total_loss: [0.32940829]
# Epoch: [68],step: [18600], mri_ssim_loss: [0.14277154], pet_ssim_loss: [0.12182570],  total_ssim_loss: [0.26459724], total_l2_loss: [0.01906479], total_loss: [0.21549074]
# Epoch: [68],step: [18700], mri_ssim_loss: [0.33690637], pet_ssim_loss: [0.18127239],  total_ssim_loss: [0.51817876], total_l2_loss: [0.02472580], total_loss: [0.41948816]
# Epoch: [69],step: [18800], mri_ssim_loss: [0.32625133], pet_ssim_loss: [0.24465793],  total_ssim_loss: [0.57090926], total_l2_loss: [0.03244639], total_loss: [0.46321669]
# Epoch: [69],step: [18900], mri_ssim_loss: [0.13581771], pet_ssim_loss: [0.08625925],  total_ssim_loss: [0.22207695], total_l2_loss: [0.02115327], total_loss: [0.18189222]
# Epoch: [69],step: [19000], mri_ssim_loss: [0.34974307], pet_ssim_loss: [0.11542779],  total_ssim_loss: [0.46517086], total_l2_loss: [0.03922411], total_loss: [0.37998152]
# Epoch: [70],step: [19100], mri_ssim_loss: [0.29296494], pet_ssim_loss: [0.27437830],  total_ssim_loss: [0.56734324], total_l2_loss: [0.04692467], total_loss: [0.46325952]
# Epoch: [70],step: [19200], mri_ssim_loss: [0.25748199], pet_ssim_loss: [0.13234609],  total_ssim_loss: [0.38982809], total_l2_loss: [0.01505870], total_loss: [0.31487420]
# Epoch: [70],step: [19300], mri_ssim_loss: [0.11988086], pet_ssim_loss: [0.03870481],  total_ssim_loss: [0.15858567], total_l2_loss: [0.00729034], total_loss: [0.12832659]
# Epoch: [71],step: [19400], mri_ssim_loss: [0.17171609], pet_ssim_loss: [0.14310515],  total_ssim_loss: [0.31482124], total_l2_loss: [0.02658916], total_loss: [0.25717485]
# Epoch: [71],step: [19500], mri_ssim_loss: [0.31454754], pet_ssim_loss: [0.13562012],  total_ssim_loss: [0.45016766], total_l2_loss: [0.02888897], total_loss: [0.36591193]
# Epoch: [72],step: [19600], mri_ssim_loss: [0.29673266], pet_ssim_loss: [0.23932493],  total_ssim_loss: [0.53605759], total_l2_loss: [0.02015297], total_loss: [0.43287668]
# Epoch: [72],step: [19700], mri_ssim_loss: [0.15087610], pet_ssim_loss: [0.09122890],  total_ssim_loss: [0.24210501], total_l2_loss: [0.01672728], total_loss: [0.19702947]
# Epoch: [72],step: [19800], mri_ssim_loss: [0.61641043], pet_ssim_loss: [0.16507846],  total_ssim_loss: [0.78148890], total_l2_loss: [0.02166061], total_loss: [0.62952328]
# Epoch: [73],step: [19900], mri_ssim_loss: [0.31850129], pet_ssim_loss: [0.23148912],  total_ssim_loss: [0.54999042], total_l2_loss: [0.01777273], total_loss: [0.44354689]
# Epoch: [73],step: [20000], mri_ssim_loss: [0.33362055], pet_ssim_loss: [0.17999464],  total_ssim_loss: [0.51361519], total_l2_loss: [0.02577943], total_loss: [0.41604805]
# Epoch: [73],step: [20100], mri_ssim_loss: [0.21261877], pet_ssim_loss: [0.11832041],  total_ssim_loss: [0.33093917], total_l2_loss: [0.01325094], total_loss: [0.26740155]
# Epoch: [74],step: [20200], mri_ssim_loss: [0.26154196], pet_ssim_loss: [0.20546186],  total_ssim_loss: [0.46700382], total_l2_loss: [0.03793815], total_loss: [0.38119072]
# Epoch: [74],step: [20300], mri_ssim_loss: [0.22954899], pet_ssim_loss: [0.14808267],  total_ssim_loss: [0.37763166], total_l2_loss: [0.03168996], total_loss: [0.30844334]
# Epoch: [74],step: [20400], mri_ssim_loss: [0.46972024], pet_ssim_loss: [0.07522953],  total_ssim_loss: [0.54494977], total_l2_loss: [0.05444217], total_loss: [0.44684824]
# Epoch: [75],step: [20500], mri_ssim_loss: [0.16643465], pet_ssim_loss: [0.10834199],  total_ssim_loss: [0.27477664], total_l2_loss: [0.02120023], total_loss: [0.22406137]
# Epoch: [75],step: [20600], mri_ssim_loss: [0.34718537], pet_ssim_loss: [0.21177745],  total_ssim_loss: [0.55896282], total_l2_loss: [0.04122499], total_loss: [0.45541525]
# Epoch: [76],step: [20700], mri_ssim_loss: [0.17561740], pet_ssim_loss: [0.24250007],  total_ssim_loss: [0.41811746], total_l2_loss: [0.01261845], total_loss: [0.33701766]
# Epoch: [76],step: [20800], mri_ssim_loss: [0.14188606], pet_ssim_loss: [0.08614147],  total_ssim_loss: [0.22802752], total_l2_loss: [0.01910290], total_loss: [0.18624261]
# Epoch: [76],step: [20900], mri_ssim_loss: [0.54272056], pet_ssim_loss: [0.21090633],  total_ssim_loss: [0.75362688], total_l2_loss: [0.02272624], total_loss: [0.60744679]
# Epoch: [77],step: [21000], mri_ssim_loss: [0.28766030], pet_ssim_loss: [0.24823862],  total_ssim_loss: [0.53589892], total_l2_loss: [0.03296310], total_loss: [0.43531176]
# Epoch: [77],step: [21100], mri_ssim_loss: [0.28578407], pet_ssim_loss: [0.10777652],  total_ssim_loss: [0.39356059], total_l2_loss: [0.02675469], total_loss: [0.32019943]
# Epoch: [77],step: [21200], mri_ssim_loss: [0.20775104], pet_ssim_loss: [0.10039681],  total_ssim_loss: [0.30814785], total_l2_loss: [0.01706173], total_loss: [0.24993064]
# Epoch: [78],step: [21300], mri_ssim_loss: [0.16864043], pet_ssim_loss: [0.15116775],  total_ssim_loss: [0.31980819], total_l2_loss: [0.02871597], total_loss: [0.26158977]
# Epoch: [78],step: [21400], mri_ssim_loss: [0.34300345], pet_ssim_loss: [0.11834478],  total_ssim_loss: [0.46134824], total_l2_loss: [0.02875035], total_loss: [0.37482867]
# Epoch: [79],step: [21500], mri_ssim_loss: [0.22163785], pet_ssim_loss: [0.11613071],  total_ssim_loss: [0.33776855], total_l2_loss: [0.01662949], total_loss: [0.27354077]
# Epoch: [79],step: [21600], mri_ssim_loss: [0.16095424], pet_ssim_loss: [0.09589380],  total_ssim_loss: [0.25684804], total_l2_loss: [0.01708927], total_loss: [0.20889628]
# Epoch: [79],step: [21700], mri_ssim_loss: [0.28330964], pet_ssim_loss: [0.08742499],  total_ssim_loss: [0.37073463], total_l2_loss: [0.01823178], total_loss: [0.30023405]
# Epoch: [80],step: [21800], mri_ssim_loss: [0.32359803], pet_ssim_loss: [0.26567316],  total_ssim_loss: [0.58927119], total_l2_loss: [0.01969642], total_loss: [0.47535622]
# Epoch: [80],step: [21900], mri_ssim_loss: [0.12476844], pet_ssim_loss: [0.04377759],  total_ssim_loss: [0.16854602], total_l2_loss: [0.02226159], total_loss: [0.13928914]
# Epoch: [80],step: [22000], mri_ssim_loss: [0.28285539], pet_ssim_loss: [0.10873628],  total_ssim_loss: [0.39159167], total_l2_loss: [0.01940903], total_loss: [0.31715515]
# Epoch: [81],step: [22100], mri_ssim_loss: [0.28492349], pet_ssim_loss: [0.22743720],  total_ssim_loss: [0.51236069], total_l2_loss: [0.04128378], total_loss: [0.41814533]
# Epoch: [81],step: [22200], mri_ssim_loss: [0.22325349], pet_ssim_loss: [0.16640180],  total_ssim_loss: [0.38965529], total_l2_loss: [0.02124564], total_loss: [0.31597337]
# Epoch: [81],step: [22300], mri_ssim_loss: [0.27340180], pet_ssim_loss: [0.11872458],  total_ssim_loss: [0.39212638], total_l2_loss: [0.01725313], total_loss: [0.31715176]
# Epoch: [82],step: [22400], mri_ssim_loss: [0.16234475], pet_ssim_loss: [0.12305933],  total_ssim_loss: [0.28540409], total_l2_loss: [0.02134430], total_loss: [0.23259212]
# Epoch: [82],step: [22500], mri_ssim_loss: [0.41311663], pet_ssim_loss: [0.15305394],  total_ssim_loss: [0.56617057], total_l2_loss: [0.03604893], total_loss: [0.46014625]
# Epoch: [83],step: [22600], mri_ssim_loss: [0.22070765], pet_ssim_loss: [0.23382145],  total_ssim_loss: [0.45452911], total_l2_loss: [0.01529003], total_loss: [0.36668131]
# Epoch: [83],step: [22700], mri_ssim_loss: [0.14623976], pet_ssim_loss: [0.09574103],  total_ssim_loss: [0.24198079], total_l2_loss: [0.01900723], total_loss: [0.19738609]
# Epoch: [83],step: [22800], mri_ssim_loss: [0.45433444], pet_ssim_loss: [0.27238810],  total_ssim_loss: [0.72672254], total_l2_loss: [0.03336070], total_loss: [0.58805019]
# Epoch: [84],step: [22900], mri_ssim_loss: [0.27232492], pet_ssim_loss: [0.17736739],  total_ssim_loss: [0.44969231], total_l2_loss: [0.01755840], total_loss: [0.36326551]
# Epoch: [84],step: [23000], mri_ssim_loss: [0.19344729], pet_ssim_loss: [0.07116574],  total_ssim_loss: [0.26461303], total_l2_loss: [0.01619379], total_loss: [0.21492918]
# Epoch: [84],step: [23100], mri_ssim_loss: [0.21512181], pet_ssim_loss: [0.14202034],  total_ssim_loss: [0.35714215], total_l2_loss: [0.02791691], total_loss: [0.29129711]
# Epoch: [85],step: [23200], mri_ssim_loss: [0.17020619], pet_ssim_loss: [0.14871681],  total_ssim_loss: [0.31892300], total_l2_loss: [0.03399318], total_loss: [0.26193702]
# Epoch: [85],step: [23300], mri_ssim_loss: [0.37672377], pet_ssim_loss: [0.09442866],  total_ssim_loss: [0.47115242], total_l2_loss: [0.03844657], total_loss: [0.38461128]
# Epoch: [86],step: [23400], mri_ssim_loss: [0.21652293], pet_ssim_loss: [0.15600514],  total_ssim_loss: [0.37252808], total_l2_loss: [0.01088466], total_loss: [0.30019942]
# Epoch: [86],step: [23500], mri_ssim_loss: [0.15533566], pet_ssim_loss: [0.10341704],  total_ssim_loss: [0.25875270], total_l2_loss: [0.01775306], total_loss: [0.21055278]
# Epoch: [86],step: [23600], mri_ssim_loss: [0.28446293], pet_ssim_loss: [0.12911081],  total_ssim_loss: [0.41357374], total_l2_loss: [0.01500528], total_loss: [0.33386007]
# Epoch: [87],step: [23700], mri_ssim_loss: [0.33379066], pet_ssim_loss: [0.28092819],  total_ssim_loss: [0.61471885], total_l2_loss: [0.01935939], total_loss: [0.49564698]
# Epoch: [87],step: [23800], mri_ssim_loss: [0.15258431], pet_ssim_loss: [0.05005854],  total_ssim_loss: [0.20264286], total_l2_loss: [0.02219664], total_loss: [0.16655362]
# Epoch: [87],step: [23900], mri_ssim_loss: [0.29848129], pet_ssim_loss: [0.13306159],  total_ssim_loss: [0.43154287], total_l2_loss: [0.01883555], total_loss: [0.34900141]
# Epoch: [88],step: [24000], mri_ssim_loss: [0.27690488], pet_ssim_loss: [0.28748959],  total_ssim_loss: [0.56439447], total_l2_loss: [0.04673828], total_loss: [0.46086323]
# Epoch: [88],step: [24100], mri_ssim_loss: [0.22505027], pet_ssim_loss: [0.15429372],  total_ssim_loss: [0.37934399], total_l2_loss: [0.01372173], total_loss: [0.30621955]
# Epoch: [88],step: [24200], mri_ssim_loss: [0.31102794], pet_ssim_loss: [0.16381931],  total_ssim_loss: [0.47484726], total_l2_loss: [0.03604008], total_loss: [0.38708583]
# Epoch: [89],step: [24300], mri_ssim_loss: [0.17267078], pet_ssim_loss: [0.12857723],  total_ssim_loss: [0.30124801], total_l2_loss: [0.02381653], total_loss: [0.24576172]
# Epoch: [89],step: [24400], mri_ssim_loss: [0.26815009], pet_ssim_loss: [0.11320478],  total_ssim_loss: [0.38135487], total_l2_loss: [0.01450105], total_loss: [0.30798411]
# Epoch: [90],step: [24500], mri_ssim_loss: [0.26251030], pet_ssim_loss: [0.25457436],  total_ssim_loss: [0.51708466], total_l2_loss: [0.02225709], total_loss: [0.41811916]
# Epoch: [90],step: [24600], mri_ssim_loss: [0.14527506], pet_ssim_loss: [0.09238273],  total_ssim_loss: [0.23765779], total_l2_loss: [0.01755153], total_loss: [0.19363654]
# Epoch: [90],step: [24700], mri_ssim_loss: [0.47497958], pet_ssim_loss: [0.22649324],  total_ssim_loss: [0.70147282], total_l2_loss: [0.01686973], total_loss: [0.56455219]
# Epoch: [91],step: [24800], mri_ssim_loss: [0.31127167], pet_ssim_loss: [0.22803384],  total_ssim_loss: [0.53930551], total_l2_loss: [0.01982081], total_loss: [0.43540856]
# Epoch: [91],step: [24900], mri_ssim_loss: [0.25607282], pet_ssim_loss: [0.14319235],  total_ssim_loss: [0.39926517], total_l2_loss: [0.01599112], total_loss: [0.32261038]
# Epoch: [91],step: [25000], mri_ssim_loss: [0.23461580], pet_ssim_loss: [0.15788949],  total_ssim_loss: [0.39250529], total_l2_loss: [0.03318085], total_loss: [0.32064041]
# Epoch: [92],step: [25100], mri_ssim_loss: [0.23519546], pet_ssim_loss: [0.20241946],  total_ssim_loss: [0.43761492], total_l2_loss: [0.03424905], total_loss: [0.35694173]
# Epoch: [92],step: [25200], mri_ssim_loss: [0.21505928], pet_ssim_loss: [0.13193744],  total_ssim_loss: [0.34699672], total_l2_loss: [0.02026393], total_loss: [0.28165019]
# Epoch: [93],step: [25300], mri_ssim_loss: [0.26336199], pet_ssim_loss: [0.13559228],  total_ssim_loss: [0.39895427], total_l2_loss: [0.02629380], total_loss: [0.32442218]
# Epoch: [93],step: [25400], mri_ssim_loss: [0.15039146], pet_ssim_loss: [0.11119217],  total_ssim_loss: [0.26158363], total_l2_loss: [0.01948982], total_loss: [0.21316487]
# Epoch: [93],step: [25500], mri_ssim_loss: [0.34578890], pet_ssim_loss: [0.16768157],  total_ssim_loss: [0.51347047], total_l2_loss: [0.02500216], total_loss: [0.41577682]
# Epoch: [94],step: [25600], mri_ssim_loss: [0.34004402], pet_ssim_loss: [0.22478616],  total_ssim_loss: [0.56483018], total_l2_loss: [0.03252754], total_loss: [0.45836967]
# Epoch: [94],step: [25700], mri_ssim_loss: [0.15584373], pet_ssim_loss: [0.06193900],  total_ssim_loss: [0.21778274], total_l2_loss: [0.02205123], total_loss: [0.17863645]
# Epoch: [94],step: [25800], mri_ssim_loss: [0.34315509], pet_ssim_loss: [0.11856151],  total_ssim_loss: [0.46171659], total_l2_loss: [0.03903289], total_loss: [0.37717986]
# Epoch: [95],step: [25900], mri_ssim_loss: [0.29240084], pet_ssim_loss: [0.27074522],  total_ssim_loss: [0.56314605], total_l2_loss: [0.04765222], total_loss: [0.46004730]
# Epoch: [95],step: [26000], mri_ssim_loss: [0.25849158], pet_ssim_loss: [0.12767172],  total_ssim_loss: [0.38616329], total_l2_loss: [0.01500830], total_loss: [0.31193230]
# Epoch: [95],step: [26100], mri_ssim_loss: [0.11821514], pet_ssim_loss: [0.03907561],  total_ssim_loss: [0.15729076], total_l2_loss: [0.00726560], total_loss: [0.12728572]
# Epoch: [96],step: [26200], mri_ssim_loss: [0.17403305], pet_ssim_loss: [0.13883477],  total_ssim_loss: [0.31286782], total_l2_loss: [0.02737500], total_loss: [0.25576928]
# Epoch: [96],step: [26300], mri_ssim_loss: [0.31733334], pet_ssim_loss: [0.12966800],  total_ssim_loss: [0.44700134], total_l2_loss: [0.02899113], total_loss: [0.36339930]
# Epoch: [97],step: [26400], mri_ssim_loss: [0.30277687], pet_ssim_loss: [0.24455303],  total_ssim_loss: [0.54732990], total_l2_loss: [0.02142708], total_loss: [0.44214934]
# Epoch: [97],step: [26500], mri_ssim_loss: [0.15095365], pet_ssim_loss: [0.08934623],  total_ssim_loss: [0.24029988], total_l2_loss: [0.01695583], total_loss: [0.19563107]
# Epoch: [97],step: [26600], mri_ssim_loss: [0.67674267], pet_ssim_loss: [0.16116339],  total_ssim_loss: [0.83790606], total_l2_loss: [0.02549625], total_loss: [0.67542410]
# Epoch: [98],step: [26700], mri_ssim_loss: [0.32349688], pet_ssim_loss: [0.22402304],  total_ssim_loss: [0.54751992], total_l2_loss: [0.01801798], total_loss: [0.44161955]
# Epoch: [98],step: [26800], mri_ssim_loss: [0.33438402], pet_ssim_loss: [0.17622805],  total_ssim_loss: [0.51061207], total_l2_loss: [0.02580062], total_loss: [0.41364980]
# Epoch: [98],step: [26900], mri_ssim_loss: [0.21602803], pet_ssim_loss: [0.11487478],  total_ssim_loss: [0.33090281], total_l2_loss: [0.01334194], total_loss: [0.26739064]
# Epoch: [99],step: [27000], mri_ssim_loss: [0.25939924], pet_ssim_loss: [0.20502371],  total_ssim_loss: [0.46442294], total_l2_loss: [0.03803327], total_loss: [0.37914503]
# Epoch: [99],step: [27100], mri_ssim_loss: [0.22520000], pet_ssim_loss: [0.15138149],  total_ssim_loss: [0.37658149], total_l2_loss: [0.03171369], total_loss: [0.30760795]
# Epoch: [99],step: [27200], mri_ssim_loss: [0.47126019], pet_ssim_loss: [0.07267541],  total_ssim_loss: [0.54393560], total_l2_loss: [0.05438218], total_loss: [0.44602492]
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\torch\serialization.py:250: UserWarning: Couldn't retrieve source code for container of type DeepPedestrian. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "

# %%
l1 = np.asarray(ep_mri_ssim_loss)
l2 = np.asarray(ep_pet_ssim_loss)
l3 = np.asarray(ep_total_l2_loss)

# %%
h5f = h5py.File('C:/Users/horan/Desktop/FuseVis/Loss curves/DeepPedestrian/H5 Files/Loss_L2.h5', 'w')
h5f.create_dataset('L2_dataset', data=l3)
h5f.close()

# %%
plt.plot(l3)
plt.xlabel('epoch')
plt.ylabel('L2')
plt.title('DeepPedestrian')
plt.savefig('C:/Users/horan/Desktop/FuseVis/Loss curves/DeepPedestrian/Loss curves/L2_loss.png', bbox_inches = 'tight',pad_inches = 0)

# %%
#load the test input MRI dataset
filenames = os.listdir('C:/Users/horan/Desktop/FuseVis/MRI/')
dataset = os.path.join(os.getcwd(), 'C:/Users/horan/Desktop/FuseVis/MRI/')
data = glob.glob(os.path.join(dataset, "*.gif"))
data = natsort.natsorted(data,reverse=False)
test_mri = np.zeros((len(data), image_width,image_length))
for i in range(len(data)):
    test_mri[i,:,:] =(imageio.imread(data[i]))
    test_mri[i,:,:] =(test_mri[i,:,:] - np.min(test_mri[i,:,:])) / (np.max(test_mri[i,:,:]) - np.min(test_mri[i,:,:]))
    test_mri[i,:,:] = np.float32(test_mri[i,:,:])

# %%
#expand dimension to add the channel
test_mri = np.expand_dims(test_mri,axis=1)
#verify the shape matches the pytorch standard
test_mri.shape
# Out:
# (1, 1, 256, 256)

# %%
#verify the test mri image
#test_mri = test_mri[0,:,:,:]
#test_mri = np.expand_dims(test_mri,axis=0)
plt.imshow(test_mri[0,0,:,:],'gray')
#plt.savefig('MRI.png', bbox_inches = 'tight',pad_inches = 0,dpi=200)

# %%
#convert the MRI Testing data to pytorch tensor
test_mri_tensor = torch.from_numpy(test_mri).float()
test_mri_tensor = test_mri_tensor.to(device)
print(test_mri_tensor.shape)
test_mri_tensor.requires_grad =True
# Out:
# torch.Size([1, 1, 256, 256])

# %%
#load the test input PET dataset
filenames = os.listdir('C:/Users/horan/Desktop/FuseVis/PET/')
dataset = os.path.join(os.getcwd(), 'C:/Users/horan/Desktop/FuseVis/PET/')
data = glob.glob(os.path.join(dataset, "*.png"))
data = natsort.natsorted(data,reverse=False)
test_pet = np.zeros((len(data), image_width,image_length))
for i in range(len(data)):
    test_pet[i,:,:] =(imageio.imread(data[i]))
    test_pet[i,:,:] =(test_pet[i,:,:] - np.min(test_pet[i,:,:])) / (np.max(test_pet[i,:,:]) - np.min(test_pet[i,:,:]))
    test_pet[i,:,:] = np.float32(test_pet[i,:,:])

# %%
#expand dimension to add the channel
test_pet = np.expand_dims(test_pet,axis=1)
#verify the shape matches the pytorch standard
test_pet.shape
# Out:
# (1, 1, 256, 256)

# %%
plt.imshow(test_pet[0,0,:,:],'gray')
#plt.savefig('PET.png', bbox_inches = 'tight',pad_inches = 0,dpi=200)

# %%
#convert the MRI Testing data to pytorch tensor
test_pet_tensor = torch.from_numpy(test_pet).float()
test_pet_tensor = test_pet_tensor.to(device)
print(test_pet_tensor.shape)
test_pet_tensor.requires_grad =True
# Out:
# torch.Size([1, 1, 256, 256])

# %%
#load the model
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
cnn =torch.load('C:/Users/horan/Desktop/FuseVis/.ipynb_checkpoints/DeepPedestrian/checkpoint.pth')
cnn.eval()
# Out:
# DeepPedestrian(
#   (conv1): Sequential(
#     (0): Conv2d(2, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU()
#     (6): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (conv2): Sequential(
#     (0): ReLU()
#     (1): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (2): ReLU()
#     (3): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU()
#     (5): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU()
#     (7): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (conv3): Sequential(
#     (0): ReLU()
#     (1): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (2): ReLU()
#     (3): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU()
#     (5): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU()
#     (7): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (conv4): Sequential(
#     (0): ReLU()
#     (1): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (2): ReLU()
#     (3): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU()
#     (5): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU()
#     (7): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (conv5): Sequential(
#     (0): ReLU()
#     (1): Conv2d(48, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
# )

# %%
#predicted the fused image
fused = cnn(test_mri_tensor.to(device), test_pet_tensor.to(device))
fused_numpy = fused.data.cpu().numpy()

# %%
fused.shape
# Out:
# torch.Size([1, 1, 256, 256])

# %%
#verify the output image
plt.imshow(fused_numpy[0,0,:,:],'gray')
#plt.savefig('Fused.png', bbox_inches = 'tight',pad_inches = 0,dpi=200)

# %%
imageio.imwrite('C:/Users/horan/Desktop/FuseVis/Fused/DeepPedestrian/Fused.png',np.uint8(cv2.normalize(fused_numpy[0,0,:,:], None, alpha=0, beta=255, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_32F)))

# %%
#calculate the guidance image for MRI and PET wrt to the fused image
time1 = time.time()
count = 0 
guide_fuse_mri = np.zeros((256,256),dtype=float)
guide_fuse_pet = np.zeros((256,256),dtype=float)

for y_coord in range(0,256):
    for x_coord in range(0,256):
        jacob_fuse_mri = torch.autograd.grad(fused[0,0,y_coord,x_coord], test_mri_tensor, retain_graph=True, create_graph=True)[0]
        jacob_numpy_mri = np.squeeze(jacob_fuse_mri.data.cpu().numpy())  
        guide_fuse_mri[y_coord,x_coord] = jacob_numpy_mri[y_coord,x_coord]
        jacob_fuse_pet = torch.autograd.grad(fused[0,0,y_coord,x_coord], test_pet_tensor, retain_graph=True, create_graph=True)[0]
        jacob_numpy_pet = np.squeeze(jacob_fuse_pet.data.cpu().numpy())  
        guide_fuse_pet[y_coord,x_coord] = jacob_numpy_pet[y_coord,x_coord]
        count += 1
        if count % 1000 == 0:
            print('Count is %d' %count)
time2 = time.time()
print('Time taken to compute is %d seconds' %(time2-time1))
# Out:
# Count is 1000
# Count is 2000
# Count is 3000
# Count is 4000
# Count is 5000
# Count is 6000
# Count is 7000
# Count is 8000
# Count is 9000
# Count is 10000
# Count is 11000
# Count is 12000
# Count is 13000
# Count is 14000
# Count is 15000
# Count is 16000
# Count is 17000
# Count is 18000
# Count is 19000
# Count is 20000
# Count is 21000
# Count is 22000
# Count is 23000
# Count is 24000
# Count is 25000
# Count is 26000
# Count is 27000
# Count is 28000
# Count is 29000
# Count is 30000
# Count is 31000
# Count is 32000
# Count is 33000
# Count is 34000
# Count is 35000
# Count is 36000
# Count is 37000
# Count is 38000
# Count is 39000
# Count is 40000
# Count is 41000
# Count is 42000
# Count is 43000
# Count is 44000
# Count is 45000
# Count is 46000
# Count is 47000
# Count is 48000
# Count is 49000
# Count is 50000
# Count is 51000
# Count is 52000
# Count is 53000
# Count is 54000
# Count is 55000
# Count is 56000
# Count is 57000
# Count is 58000
# Count is 59000
# Count is 60000
# Count is 61000
# Count is 62000
# Count is 63000
# Count is 64000
# Count is 65000
# Time taken to compute is 2683 seconds

# %%
h5f = h5py.File('C:/Users/horan/Desktop/FuseVis/Guidance images/DeepPedestrian/H5 Files/Jacobian_MRI.h5', 'w')
h5f.create_dataset('Jacob_MRI_dataset', data=guide_fuse_mri)
h5f.close()

# %%
plt.imshow(guide_fuse_mri,cmap='viridis')
plt.colorbar()
plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/DeepPedestrian/Resultant images/Guide_Fused_MRI_DPI.png', bbox_inches = 'tight',pad_inches = 0,dpi=200)

# %%
h5f = h5py.File('C:/Users/horan/Desktop/FuseVis/Guidance images/DeepPedestrian/H5 Files/Jacobian_PET.h5', 'w')
h5f.create_dataset('Jacob_PET_dataset', data=guide_fuse_pet)
h5f.close()

# %%
plt.imshow(guide_fuse_pet,cmap='viridis')
plt.colorbar()
plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/DeepPedestrian/Resultant images/Guide_Fused_PET_DPI.png', bbox_inches = 'tight',pad_inches = 0,dpi=200)

# %%
#define overlay images
fused_RGB = np.zeros((256,256,3),dtype=float)
mri_RGB   = np.zeros((256,256,3),dtype=float)
pet_RGB   = np.zeros((256,256,3),dtype=float)

# %%
fused_RGB[:,:,0]  = guide_fuse_mri 
fused_RGB[:,:,1]  = guide_fuse_pet 
fused_RGB[:,:,2]  = fused_numpy[0,0,:,:]

# %%
plt.imshow(fused_RGB)
plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/DeepPedestrian/Resultant images/Fused_RGB_DPI.png', bbox_inches = 'tight',pad_inches = 0,dpi=200)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
mri_RGB[:,:,0]  = guide_fuse_mri
mri_RGB[:,:,1]  = guide_fuse_pet 
mri_RGB[:,:,2]  = test_mri[0,0,:,:]

# %%
plt.imshow(mri_RGB)
plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/DeepPedestrian/Resultant images/MRI_RGB_DPI.png', bbox_inches = 'tight',pad_inches = 0,dpi=200)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
pet_RGB[:,:,0]  = guide_fuse_mri
pet_RGB[:,:,1]  = guide_fuse_pet 
pet_RGB[:,:,2]  = test_pet[0,0,:,:]

# %%
plt.imshow(pet_RGB)
plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/DeepPedestrian/Resultant images/PET_RGB_DPI.png', bbox_inches = 'tight',pad_inches = 0,dpi=200)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
#define the window
root = Tk()  
root.title('Visualisation of fusion networks')
root.configure(background='white')


#Label the images
#fontStyle = tkFont.Font(family="Lucida Grande", size=15)
#w1 = tk.Label(root, bg='white', font=fontStyle, text="Fused Image")
#w1.grid(row=0, column=1)
#w1.pack()

#define the frame
canvasframe = Frame(root)  # define Input and output frame
buttonframe = Frame(root)  # define button frame
canvasframe.pack()  # pack the Input and Output frame
buttonframe.pack()  # pack the button frame


#define the canvas
canvas = Canvas(canvasframe, width=1800, height=920, bg = 'white')
canvas.grid(row=0, column=0)

#Insert fused image to the canvas
img_fused = ImageTk.PhotoImage(file ="C:/Users/horan/Desktop/FuseVis/Fused/DeepPedestrian/Fused.png") # load the image
canvas.create_image(0, 0, image=img_fused, anchor=NW)

#Insert MRI image to the canvas
img_mri = ImageTk.PhotoImage(file ="C:/Users/horan/Desktop/FuseVis/MRI/MRI.gif") # load the image
canvas.create_image(600, 0, image=img_mri, anchor=NW)

#Insert PET image to the canvas
img_pet = ImageTk.PhotoImage(file ="C:/Users/horan/Desktop/FuseVis/PET/3.png") # load the image
canvas.create_image(1200, 0, image=img_pet, anchor=NW)

def start_mouseover():  # function called when user clicks the button 
    # link the function to the left-mouse-click event
    canvas.bind("<B1-Motion>", Coordinates)

def Coordinates(event): # function called when left-mouse-button is clicked with a mouseover
    x_coord = event.x  # save x and y coordinates selected by the user   
    y_coord = event.y
    print('mouse position is at' + '(' + str(y_coord) + ',' + str(x_coord) + ')', end='\r')
    #display the output MRI Jacobian image
    #img_MR_out = ImageTk.PhotoImage(file ='C:/Users/cgvadmin/Desktop/FuseVis/Fused_MRI/im_' + str(y_coord) + '_' + str(x_coord) + '.png') # load the image
    jacobian_fuse_mri = torch.autograd.grad(fused[0,0,y_coord,x_coord], test_mri_tensor, retain_graph=True, create_graph=True)[0]
    jacobian_fuse_pet = torch.autograd.grad(fused[0,0,y_coord,x_coord], test_pet_tensor, retain_graph=True, create_graph=True)[0]
    
    jacob_val_mri = np.squeeze(jacobian_fuse_mri.data.cpu().numpy())    
    jacob_val_pet = np.squeeze(jacobian_fuse_pet.data.cpu().numpy())
    
    x_mri = np.asarray(np.where(np.any(jacob_val_mri, axis = 0)))
    y_mri = np.asarray(np.where(np.any(jacob_val_mri, axis = 1)))
    minx_mri, maxx_mri, miny_mri, maxy_mri = np.min(x_mri), np.max(x_mri), np.min(y_mri), np.max(y_mri)  #return min and max coordinates
    zoom_im_mri = jacob_val_mri[miny_mri:maxy_mri,minx_mri:maxx_mri] 
    
    x_pet = np.asarray(np.where(np.any(jacob_val_pet, axis = 0)))
    y_pet = np.asarray(np.where(np.any(jacob_val_pet, axis = 1)))
    minx_pet, maxx_pet, miny_pet, maxy_pet = np.min(x_pet), np.max(x_pet), np.min(y_pet), np.max(y_pet)  #return min and max coordinates
    zoom_im_pet = jacob_val_pet[miny_pet:maxy_pet,minx_pet:maxx_pet] 
    
    plt.imshow(fused_numpy[0,0,miny_mri:maxy_mri,minx_mri:maxx_mri], cmap = 'gray', aspect ='equal')
    plt.title('Zoom Fused')
    plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/DeepPedestrian/Resultant images/Zoom_Fused.png', bbox_inches = 'tight',pad_inches = 0)
    plt.close()
    im_out11 = ImageTk.PhotoImage(file ='C:/Users/horan/Desktop/FuseVis/Guidance images/DeepPedestrian/Resultant images/Zoom_Fused.png')
    canvas.create_image(300,5,image=im_out11,anchor=NW)
    canvas.image11 = im_out11
    plt.tight_layout()
    
    plt.imshow(test_mri[0,0,miny_mri:maxy_mri,minx_mri:maxx_mri], cmap = 'gray', aspect ='equal')
    plt.title('Zoom MRI')
    plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/DeepPedestrian/Resultant images/Zoom_MRI.png', bbox_inches = 'tight',pad_inches = 0)
    plt.close()
    im_out12 = ImageTk.PhotoImage(file ='C:/Users/horan/Desktop/FuseVis/Guidance images/DeepPedestrian/Resultant images/Zoom_MRI.png')
    canvas.create_image(900,5,image=im_out12,anchor=NW)
    canvas.image12 = im_out12
    plt.tight_layout()
    
    plt.imshow(test_pet[0,0,miny_mri:maxy_mri,minx_mri:maxx_mri], cmap = 'gray', aspect ='equal')
    plt.title('Zoom PET')
    plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/DeepPedestrian/Resultant images/Zoom_PET.png', bbox_inches = 'tight',pad_inches = 0)
    plt.close()
    im_out13 = ImageTk.PhotoImage(file ='C:/Users/horan/Desktop/FuseVis/Guidance images/DeepPedestrian/Resultant images/Zoom_PET.png')
    canvas.create_image(1500,5,image=im_out13,anchor=NW)
    canvas.image13 = im_out13
    plt.tight_layout()
    
    plt.imshow(jacob_val_mri,cmap='viridis', aspect ='equal')
    plt.title('Jacobian (Fused wrt MRI)')
    plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/DeepPedestrian/Resultant images/Jacob_Fused_MRI.png', bbox_inches = 'tight',pad_inches = 0)
    plt.close()
    im_out1 = ImageTk.PhotoImage(file ='C:/Users/horan/Desktop/FuseVis/Guidance images/DeepPedestrian/Resultant images/Jacob_Fused_MRI.png')
    canvas.create_image(40,320,image=im_out1,anchor=NW)
    canvas.image1 = im_out1
    #plt.tight_layout()
    
    #f.add_subplot(1,5,2)
    plt.imshow(zoom_im_mri,cmap='viridis',aspect ='equal')
    plt.title('Zoom Jacobian (Fused wrt MRI)')
    plt.colorbar()
    plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/DeepPedestrian/Resultant images/Zoom_Jacob_MRI.png', bbox_inches = 'tight',pad_inches = 0)
    plt.close()
    im_out2 = ImageTk.PhotoImage(file ='C:/Users/horan/Desktop/FuseVis/Guidance images/DeepPedestrian/Resultant images/Zoom_Jacob_MRI.png')
    canvas.create_image(380,320,image=im_out2,anchor=NW)
    canvas.image2 = im_out2
    
    #f.add_subplot(1,5,3)
    plt.xlim(0,0.7)
    plt.ylim(0,0.7)
    plt.plot(jacob_val_mri[y_coord,x_coord],jacob_val_pet[y_coord,x_coord],'-ro')
    plt.xlabel('MRI pixel score (Fused wrt MRI)')
    plt.ylabel('PET pixel score (Fused wrt PET)')
    plt.title('Mouse position at: (' + str(y_coord) + ',' + str(x_coord) + ')')
    plt.gca().set_aspect('equal', adjustable='box')
    plt.draw()
    plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/DeepPedestrian/Resultant images/Pixel_intensities.png', bbox_inches = 'tight',pad_inches = 0.1)
    plt.close()
    im_out3 = ImageTk.PhotoImage(file ='C:/Users/horan/Desktop/FuseVis/Guidance images/DeepPedestrian/Resultant images/Pixel_intensities.png')
    canvas.create_image(750,320,image=im_out3,anchor=NW)
    canvas.image3 = im_out3
    
    #f.add_subplot(1,5,4)
    plt.imshow(jacob_val_pet,cmap='viridis',aspect ='equal')
    plt.title('Jacobian (Fused wrt PET)')
    plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/DeepPedestrian/Resultant images/Jacob_Fused_PET.png', bbox_inches = 'tight',pad_inches = 0)
    plt.close()
    im_out4 = ImageTk.PhotoImage(file ='C:/Users/horan/Desktop/FuseVis/Guidance images/DeepPedestrian/Resultant images/Jacob_Fused_PET.png')
    canvas.create_image(1110,320,image=im_out4,anchor=NW)
    canvas.image4 = im_out4
    #plt.tight_layout()
    
    #f.add_subplot(1,5,5)
    plt.imshow(zoom_im_pet,cmap='viridis',aspect ='equal')
    plt.title('Zoomed Jacobian (Fused wrt PET)')
    plt.colorbar()
    plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/DeepPedestrian/Resultant images/Zoom_Jacob_PET.png', bbox_inches = 'tight',pad_inches = 0)
    plt.close()
    im_out5 = ImageTk.PhotoImage(file ='C:/Users/horan/Desktop/FuseVis/Guidance images/DeepPedestrian/Resultant images/Zoom_Jacob_PET.png')
    canvas.create_image(1450,320,image=im_out5,anchor=NW)
    canvas.image5 = im_out5

    plt.imshow(guide_fuse_mri,cmap='viridis')
    plt.title('Guidance (Fused wrt MRI)')
    plt.colorbar()
    plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/DeepPedestrian/Resultant images/Guide_Fused_MRI.png', bbox_inches = 'tight',pad_inches = 0)
    plt.close()
    im_out6 = ImageTk.PhotoImage(file ='C:/Users/horan/Desktop/FuseVis/Guidance images/DeepPedestrian/Resultant images/Guide_Fused_MRI.png')
    canvas.create_image(100,650,image=im_out6,anchor=NW)
    canvas.image6 = im_out6
    
    plt.imshow(fused_RGB)
    plt.title('R=I1 G=I2 B=Fused')
    plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/DeepPedestrian/Resultant images/Fused_RGB.png', bbox_inches = 'tight',pad_inches = 0)
    plt.close()
    im_out8 = ImageTk.PhotoImage(file ='C:/Users/horan/Desktop/FuseVis/Guidance images/DeepPedestrian/Resultant images/Fused_RGB.png')
    canvas.create_image(420,650,image=im_out8,anchor=NW)
    canvas.image8 = im_out8
    
    plt.imshow(mri_RGB)
    plt.title('R=I1 G=I2 B=MRI')
    plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/DeepPedestrian/Resultant images/MRI_RGB.png', bbox_inches = 'tight',pad_inches = 0)
    plt.close()
    im_out9 = ImageTk.PhotoImage(file ='C:/Users/horan/Desktop/FuseVis/Guidance images/DeepPedestrian/Resultant images/MRI_RGB.png')
    canvas.create_image(740,650,image=im_out9,anchor=NW)
    canvas.image9 = im_out9
    
    plt.imshow(pet_RGB)
    plt.title('R=I1 G=I2 B=PET')
    plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/DeepPedestrian/Resultant images/PET_RGB.png', bbox_inches = 'tight',pad_inches = 0)
    plt.close()
    im_out10 = ImageTk.PhotoImage(file ='C:/Users/horan/Desktop/FuseVis/Guidance images/DeepPedestrian/Resultant images/PET_RGB.png')
    canvas.create_image(1100,650,image=im_out10,anchor=NW)
    canvas.image10 = im_out10
    
    plt.imshow(guide_fuse_pet,cmap='viridis')
    plt.title('Guidance (Fused wrt PET)')
    plt.colorbar()
    plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/DeepPedestrian/Resultant images/Guide_Fused_PET.png', bbox_inches = 'tight',pad_inches = 0)
    plt.close()
    im_out7 = ImageTk.PhotoImage(file ='C:/Users/horan/Desktop/FuseVis/Guidance images/DeepPedestrian/Resultant images/Guide_Fused_PET.png')
    canvas.create_image(1400,650,image=im_out7,anchor=NW)
    canvas.image7 = im_out7
    
    radius = 5
    i = canvas.create_oval(x_coord-radius, y_coord-radius, x_coord+radius, y_coord+radius, fill = 'red')
    canvas.after(20,canvas.delete,i)

# insert button to the middleframe and link it to "Start Mouseover"
button_start_mouseover = Button(buttonframe, text="Start Mouseover",command=start_mouseover)
button_start_mouseover.grid(row=1, column=0, pady=0)


root.mainloop()  #keep the GUI open
# Out:
# mouse position is at(96,78)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# mouse position is at(127,89)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# mouse position is at(127,90)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# mouse position is at(101,106)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# mouse position is at(100,99)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# mouse position is at(101,99)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# mouse position is at(111,96)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# mouse position is at(157,151)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# mouse position is at(161,150)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# mouse position is at(162,150)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# mouse position is at(161,150)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# mouse position is at(162,150)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
