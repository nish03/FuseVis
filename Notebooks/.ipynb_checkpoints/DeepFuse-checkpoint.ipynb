# %% [markdown]
# # This is the pytorch implementation of the paper "DeepFuse: A Deep Unsupervised Approach for Exposure Fusion with Extreme Exposure Image Pairs"

# %%
#Import packages
import time
import torch.nn as nn
import torch
from torch.utils.data import Dataset, DataLoader
import torchvision.datasets as datasets
import numpy as np
from torchvision import transforms
from torch.autograd import Variable
from PIL import Image
import torchvision.transforms.functional as TF
from torchvision.models.vgg import vgg19
import torch.nn as nn
import torch.nn.functional as F
import torch
from skimage import img_as_ubyte
import torch.nn as nn
import torch.utils.data as Data
import torchvision      # dataset
import matplotlib.pyplot as plt
import scipy
import numpy as np
import argparse
import glob
import imageio
from skimage import color
import numpy
import natsort
import scipy
from pytorch_msssim import ssim, ms_ssim, SSIM, MS_SSIM
import pprint
from scipy.ndimage import correlate
from scipy.ndimage.filters import gaussian_gradient_magnitude
import torchvision.datasets as dset
import torch.utils.data as data
import os
import os.path
from tkinter import *
import tkinter as tk
import tkinter.font as tkFont
from PIL import ImageTk, Image
import pylab
import cv2
import h5py
from mpl_toolkits.axes_grid1 import make_axes_locatable
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
device
# Out:
# 'cuda'

# %%
import multiprocessing

multiprocessing.cpu_count()
# Out:
# 12

# %%
#define the hyperparameters
image_length = 256
image_width  = 256
mr_channels  = 1
gray_channels = 1
pet_channels = 4    
rgb_channels = 3     
batch_size   = 1
EPOCH = 500
learning_rate = 0.002

# %%
#load the train mri data
filenames = os.listdir('C:/Users/horan/Desktop/FuseVis/Training/MRI')
dataset = os.path.join(os.getcwd(), 'C:/Users/horan/Desktop/FuseVis/Training/MRI')
data = glob.glob(os.path.join(dataset, "*.gif"))
data = natsort.natsorted(data,reverse=False)
train_mri = np.zeros((len(data), image_width,image_length))
for i in range(len(data)):
    train_mri[i,:,:] =(imageio.imread(data[i]))
    train_mri[i,:,:] =(train_mri[i,:,:] - np.min(train_mri[i,:,:])) / (np.max(train_mri[i,:,:]) - np.min(train_mri[i,:,:]))
    train_mri[i,:,:] = np.float32(train_mri[i,:,:])

# %%
#expand dimension to add the channel
train_mri = np.expand_dims(train_mri,axis=1)

# %%
#verify the shape matches the pytorch standard
train_mri.shape
# Out:
# (272, 1, 256, 256)

# %%
#convert the MRI training data to pytorch tensor
train_mri_tensor = torch.from_numpy(train_mri).float()
train_mri_tensor.shape
# Out:
# torch.Size([272, 1, 256, 256])

# %%
#load the train pet data
filenames = os.listdir('C:/Users/horan/Desktop/FuseVis/Training/PET')
dataset = os.path.join(os.getcwd(), 'C:/Users/horan/Desktop/FuseVis/Training/PET')
data = glob.glob(os.path.join(dataset, "*.gif"))
data = natsort.natsorted(data,reverse=False)
train_other = np.zeros((len(data),image_width,image_length,pet_channels),dtype=float)
train_pet = np.zeros((len(data),image_width,image_length),dtype=float)
for i in range(len(data)):
    train_other[i,:,:,:] =(imageio.imread(data[i]))
    train_pet[i,:,:] = 0.2989 * train_other[i,:,:,0] + 0.5870 *  train_other[i,:,:,1]  + 0.1140 * train_other[i,:,:,2]
    train_pet[i,:,:] =(train_pet[i,:,:] - np.min(train_pet[i,:,:])) / (np.max(train_pet[i,:,:]) - np.min(train_pet[i,:,:]))

# %%
#expand the dimension to add the channel
train_pet = np.expand_dims(train_pet,axis=1)

# %%
#verify the shape matches the pytorch standard
train_pet.shape
# Out:
# (272, 1, 256, 256)

# %%
#convert the PET training data to pytorch tensor
train_pet_tensor = torch.from_numpy(train_pet).float()
train_pet_tensor.shape
# Out:
# torch.Size([272, 1, 256, 256])

# %%
#define the network
class ConvLayer_DeepFuse(nn.Module):
    def __init__(self, in_channels = 1, out_channels = 16, kernel_size = 5, last = nn.ReLU):
        super().__init__()
        if kernel_size == 5:
            padding = 2
        elif kernel_size == 7:
            padding = 3
        self.main = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size = kernel_size, stride = 1, padding = padding),
            nn.BatchNorm2d(out_channels),
            last()
        )

    def forward(self, x):
        out = self.main(x)
        return out

class FusionLayer(nn.Module):
    def forward(self, x, y):
        return x + y

# -------------------------------------------------------------------------------------------------------
#   Define model
# -------------------------------------------------------------------------------------------------------
class DeepFuse(nn.Module):
    def __init__(self):
        super(DeepFuse, self).__init__()
        self.layer1 = ConvLayer_DeepFuse(1, 16, 5, last = nn.LeakyReLU)
        self.layer2 = ConvLayer_DeepFuse(16, 32, 7)
        self.layer3 = FusionLayer()
        self.layer4 = ConvLayer_DeepFuse(32, 32, 7, last = nn.LeakyReLU)
        self.layer5 = ConvLayer_DeepFuse(32, 16, 5, last = nn.LeakyReLU)
        self.layer6 = ConvLayer_DeepFuse(16, 1, 5, last = nn.Tanh)

    def setInput(self, y_1, y_2):
        self.y_1 = y_1
        self.y_2 = y_2

    def forward(self):
        c11 = self.layer1(self.y_1)
        c12 = self.layer1(self.y_2)
        c21 = self.layer2(c11)
        c22 = self.layer2(c12)
        f_m = self.layer3(c21, c22)
        c3  = self.layer4(f_m)
        c4  = self.layer5(c3)
        c5  = self.layer6(c4)
        return c5

cnn = DeepFuse().to(device)
cnn = cnn.float()
print(cnn)
# Out:
# DeepFuse(
#   (layer1): ConvLayer_DeepFuse(
#     (main): Sequential(
#       (0): Conv2d(1, 16, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.01)
#     )
#   )
#   (layer2): ConvLayer_DeepFuse(
#     (main): Sequential(
#       (0): Conv2d(16, 32, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#   )
#   (layer3): FusionLayer()
#   (layer4): ConvLayer_DeepFuse(
#     (main): Sequential(
#       (0): Conv2d(32, 32, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.01)
#     )
#   )
#   (layer5): ConvLayer_DeepFuse(
#     (main): Sequential(
#       (0): Conv2d(32, 16, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.01)
#     )
#   )
#   (layer6): ConvLayer_DeepFuse(
#     (main): Sequential(
#       (0): Conv2d(16, 1, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (1): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): Tanh()
#     )
#   )
# )

# %%
#define the optimizers and loss functions 
optimizer = torch.optim.Adam(cnn.parameters(), lr=learning_rate)   # optimize all cnn parameters
l2_loss   = nn.MSELoss() #MSEloss

# %%
# perform the training
counter = 0
start_time = time.time()
lamda = 0.8
ep_mri_ssim_loss = []
ep_pet_ssim_loss = []
ep_l2_loss = []
for epoch in range(EPOCH):
    mri_ssim_Loss = []
    pet_ssim_Loss = []
    l2_Loss = []
    #run batch images
    batch_idxs = 272 // batch_size
    for idx in range(0, batch_idxs):
        b_x = train_mri_tensor[idx*batch_size : (idx+1)*batch_size,:,:,:].to(device)
        b_y = train_pet_tensor[idx*batch_size : (idx+1)*batch_size,:,:,:].to(device)
        counter += 1
        cnn.setInput(b_x, b_y)              # cnn output
        output = cnn.forward()
        ssim_loss_mri = 1 - ssim(output, b_x,data_range=1)
        ssim_loss_pet = 1 - ssim(output, b_y,data_range=1)
        ssim_total = ssim_loss_mri + ssim_loss_pet
        l2_total = l2_loss(output,b_x) + l2_loss(output,b_y)
        loss_total = lamda*ssim_total + (1-lamda)*l2_total 
        optimizer.zero_grad()           # clear gradients for this training step
        loss_total.backward()           # backpropagation, compute gradients
        optimizer.step()                # apply gradients
        
        mri_ssim_Loss.append(ssim_loss_mri.item())
        pet_ssim_Loss.append(ssim_loss_pet.item())
        l2_Loss.append(l2_total.item())
        
        if counter % 100 == 0:
            print("Epoch: [%2d],step: [%2d], mri_ssim_loss: [%.8f], pet_ssim_loss: [%.8f],  total_ssim_loss: [%.8f] total_loss: [%.8f]" 
                   %(epoch, counter, ssim_loss_mri, ssim_loss_pet, ssim_total, loss_total))
    
    av_mri_ssim_loss = np.average(mri_ssim_Loss)
    ep_mri_ssim_loss.append(av_mri_ssim_loss)
    
    av_pet_ssim_loss = np.average(pet_ssim_Loss)
    ep_pet_ssim_loss.append(av_pet_ssim_loss)
    
    av_l2_loss = np.average(l2_Loss)
    ep_l2_loss.append(av_l2_loss)
    
    if(epoch == EPOCH -1):
        #Save a checkpoint
        torch.save(cnn, 'C:/Users/horan/Desktop/FuseVis/.ipynb_checkpoints/DeepFuse/checkpoint.pth')
# Out:
# Epoch: [ 0],step: [100], mri_ssim_loss: [0.84839535], pet_ssim_loss: [0.85031462],  total_ssim_loss: [1.69870996] total_loss: [1.38138652]
# Epoch: [ 0],step: [200], mri_ssim_loss: [0.71175706], pet_ssim_loss: [0.69973838],  total_ssim_loss: [1.41149545] total_loss: [1.15014112]
# Epoch: [ 1],step: [300], mri_ssim_loss: [0.84710371], pet_ssim_loss: [0.74195439],  total_ssim_loss: [1.58905816] total_loss: [1.28687119]
# Epoch: [ 1],step: [400], mri_ssim_loss: [0.32085437], pet_ssim_loss: [0.29712743],  total_ssim_loss: [0.61798179] total_loss: [0.50281203]
# Epoch: [ 1],step: [500], mri_ssim_loss: [0.67934412], pet_ssim_loss: [0.77129656],  total_ssim_loss: [1.45064068] total_loss: [1.17689979]
# Epoch: [ 2],step: [600], mri_ssim_loss: [0.71695065], pet_ssim_loss: [0.71993011],  total_ssim_loss: [1.43688083] total_loss: [1.16383874]
# Epoch: [ 2],step: [700], mri_ssim_loss: [0.83384907], pet_ssim_loss: [0.80665720],  total_ssim_loss: [1.64050627] total_loss: [1.32552457]
# Epoch: [ 2],step: [800], mri_ssim_loss: [0.73068756], pet_ssim_loss: [0.81408262],  total_ssim_loss: [1.54477024] total_loss: [1.24434114]
# Epoch: [ 3],step: [900], mri_ssim_loss: [0.81804776], pet_ssim_loss: [0.83898509],  total_ssim_loss: [1.65703285] total_loss: [1.33566225]
# Epoch: [ 3],step: [1000], mri_ssim_loss: [0.73720455], pet_ssim_loss: [0.72299361],  total_ssim_loss: [1.46019816] total_loss: [1.18060851]
# Epoch: [ 4],step: [1100], mri_ssim_loss: [0.76446849], pet_ssim_loss: [0.75767362],  total_ssim_loss: [1.52214217] total_loss: [1.22235608]
# Epoch: [ 4],step: [1200], mri_ssim_loss: [0.18803656], pet_ssim_loss: [0.16500872],  total_ssim_loss: [0.35304528] total_loss: [0.28739896]
# Epoch: [ 4],step: [1300], mri_ssim_loss: [0.77856237], pet_ssim_loss: [0.78890461],  total_ssim_loss: [1.56746697] total_loss: [1.26381540]
# Epoch: [ 5],step: [1400], mri_ssim_loss: [0.68927330], pet_ssim_loss: [0.75414455],  total_ssim_loss: [1.44341779] total_loss: [1.16703582]
# Epoch: [ 5],step: [1500], mri_ssim_loss: [0.17721725], pet_ssim_loss: [0.16276371],  total_ssim_loss: [0.33998096] total_loss: [0.27946189]
# Epoch: [ 5],step: [1600], mri_ssim_loss: [0.70474732], pet_ssim_loss: [0.71142566],  total_ssim_loss: [1.41617298] total_loss: [1.13989079]
# Epoch: [ 6],step: [1700], mri_ssim_loss: [0.67344201], pet_ssim_loss: [0.73315096],  total_ssim_loss: [1.40659297] total_loss: [1.14194989]
# Epoch: [ 6],step: [1800], mri_ssim_loss: [0.76506138], pet_ssim_loss: [0.82972270],  total_ssim_loss: [1.59478402] total_loss: [1.28307676]
# Epoch: [ 6],step: [1900], mri_ssim_loss: [0.71892226], pet_ssim_loss: [0.78588897],  total_ssim_loss: [1.50481129] total_loss: [1.20941424]
# Epoch: [ 7],step: [2000], mri_ssim_loss: [0.28685045], pet_ssim_loss: [0.27861112],  total_ssim_loss: [0.56546158] total_loss: [0.45786038]
# Epoch: [ 7],step: [2100], mri_ssim_loss: [0.76306766], pet_ssim_loss: [0.77143031],  total_ssim_loss: [1.53449798] total_loss: [1.23887801]
# Epoch: [ 8],step: [2200], mri_ssim_loss: [0.63663906], pet_ssim_loss: [0.80229169],  total_ssim_loss: [1.43893075] total_loss: [1.15833044]
# Epoch: [ 8],step: [2300], mri_ssim_loss: [0.20379603], pet_ssim_loss: [0.16509920],  total_ssim_loss: [0.36889523] total_loss: [0.30066589]
# Epoch: [ 8],step: [2400], mri_ssim_loss: [0.78947562], pet_ssim_loss: [0.75609541],  total_ssim_loss: [1.54557109] total_loss: [1.24999321]
# Epoch: [ 9],step: [2500], mri_ssim_loss: [0.81287438], pet_ssim_loss: [0.84179211],  total_ssim_loss: [1.65466642] total_loss: [1.33500528]
# Epoch: [ 9],step: [2600], mri_ssim_loss: [0.86435813], pet_ssim_loss: [0.90316021],  total_ssim_loss: [1.76751828] total_loss: [1.42091632]
# Epoch: [ 9],step: [2700], mri_ssim_loss: [0.68614149], pet_ssim_loss: [0.75595105],  total_ssim_loss: [1.44209254] total_loss: [1.16374969]
# Epoch: [10],step: [2800], mri_ssim_loss: [0.74037457], pet_ssim_loss: [0.76616919],  total_ssim_loss: [1.50654376] total_loss: [1.21323943]
# Epoch: [10],step: [2900], mri_ssim_loss: [0.84108496], pet_ssim_loss: [0.75819176],  total_ssim_loss: [1.59927678] total_loss: [1.29065502]
# Epoch: [11],step: [3000], mri_ssim_loss: [0.70222223], pet_ssim_loss: [0.72242963],  total_ssim_loss: [1.42465186] total_loss: [1.14519322]
# Epoch: [11],step: [3100], mri_ssim_loss: [0.78057605], pet_ssim_loss: [0.79335433],  total_ssim_loss: [1.57393038] total_loss: [1.26434183]
# Epoch: [11],step: [3200], mri_ssim_loss: [0.67299753], pet_ssim_loss: [0.69527769],  total_ssim_loss: [1.36827517] total_loss: [1.10453570]
# Epoch: [12],step: [3300], mri_ssim_loss: [0.64159858], pet_ssim_loss: [0.74568129],  total_ssim_loss: [1.38727987] total_loss: [1.11902547]
# Epoch: [12],step: [3400], mri_ssim_loss: [0.20965898], pet_ssim_loss: [0.18583572],  total_ssim_loss: [0.39549470] total_loss: [0.32303971]
# Epoch: [12],step: [3500], mri_ssim_loss: [0.70178342], pet_ssim_loss: [0.72507221],  total_ssim_loss: [1.42685556] total_loss: [1.15049064]
# Epoch: [13],step: [3600], mri_ssim_loss: [0.69059753], pet_ssim_loss: [0.77353442],  total_ssim_loss: [1.46413195] total_loss: [1.18773735]
# Epoch: [13],step: [3700], mri_ssim_loss: [0.74353862], pet_ssim_loss: [0.76587832],  total_ssim_loss: [1.50941694] total_loss: [1.21381223]
# Epoch: [13],step: [3800], mri_ssim_loss: [0.70901912], pet_ssim_loss: [0.70037413],  total_ssim_loss: [1.40939331] total_loss: [1.13919544]
# Epoch: [14],step: [3900], mri_ssim_loss: [0.73332167], pet_ssim_loss: [0.74723077],  total_ssim_loss: [1.48055243] total_loss: [1.19052541]
# Epoch: [14],step: [4000], mri_ssim_loss: [0.65246600], pet_ssim_loss: [0.76781380],  total_ssim_loss: [1.42027974] total_loss: [1.14576054]
# Epoch: [15],step: [4100], mri_ssim_loss: [0.63149536], pet_ssim_loss: [0.72833800],  total_ssim_loss: [1.35983336] total_loss: [1.09922564]
# Epoch: [15],step: [4200], mri_ssim_loss: [0.20125473], pet_ssim_loss: [0.19220102],  total_ssim_loss: [0.39345574] total_loss: [0.31977078]
# Epoch: [15],step: [4300], mri_ssim_loss: [0.65091437], pet_ssim_loss: [0.72277629],  total_ssim_loss: [1.37369061] total_loss: [1.11063421]
# Epoch: [16],step: [4400], mri_ssim_loss: [0.60576618], pet_ssim_loss: [0.70553160],  total_ssim_loss: [1.31129777] total_loss: [1.05545378]
# Epoch: [16],step: [4500], mri_ssim_loss: [0.74533641], pet_ssim_loss: [0.81132299],  total_ssim_loss: [1.55665946] total_loss: [1.25231659]
# Epoch: [16],step: [4600], mri_ssim_loss: [0.68591154], pet_ssim_loss: [0.77848089],  total_ssim_loss: [1.46439242] total_loss: [1.18453991]
# Epoch: [17],step: [4700], mri_ssim_loss: [0.70141578], pet_ssim_loss: [0.80877101],  total_ssim_loss: [1.51018679] total_loss: [1.22135484]
# Epoch: [17],step: [4800], mri_ssim_loss: [0.77562618], pet_ssim_loss: [0.81778622],  total_ssim_loss: [1.59341240] total_loss: [1.28078878]
# Epoch: [18],step: [4900], mri_ssim_loss: [0.69493580], pet_ssim_loss: [0.80015987],  total_ssim_loss: [1.49509573] total_loss: [1.20445251]
# Epoch: [18],step: [5000], mri_ssim_loss: [0.42752373], pet_ssim_loss: [0.43289435],  total_ssim_loss: [0.86041808] total_loss: [0.69352084]
# Epoch: [18],step: [5100], mri_ssim_loss: [0.65718049], pet_ssim_loss: [0.70785165],  total_ssim_loss: [1.36503220] total_loss: [1.10768914]
# Epoch: [19],step: [5200], mri_ssim_loss: [0.61836040], pet_ssim_loss: [0.78755426],  total_ssim_loss: [1.40591466] total_loss: [1.13977253]
# Epoch: [19],step: [5300], mri_ssim_loss: [0.18743551], pet_ssim_loss: [0.18196899],  total_ssim_loss: [0.36940449] total_loss: [0.30131936]
# Epoch: [19],step: [5400], mri_ssim_loss: [0.64777219], pet_ssim_loss: [0.75349724],  total_ssim_loss: [1.40126944] total_loss: [1.13173187]
# Epoch: [20],step: [5500], mri_ssim_loss: [0.65201473], pet_ssim_loss: [0.75688732],  total_ssim_loss: [1.40890205] total_loss: [1.14094937]
# Epoch: [20],step: [5600], mri_ssim_loss: [0.77502507], pet_ssim_loss: [0.79611832],  total_ssim_loss: [1.57114339] total_loss: [1.26346838]
# Epoch: [20],step: [5700], mri_ssim_loss: [0.69590616], pet_ssim_loss: [0.72270131],  total_ssim_loss: [1.41860747] total_loss: [1.14062047]
# Epoch: [21],step: [5800], mri_ssim_loss: [0.73272169], pet_ssim_loss: [0.70985770],  total_ssim_loss: [1.44257939] total_loss: [1.16191554]
# Epoch: [21],step: [5900], mri_ssim_loss: [0.67495275], pet_ssim_loss: [0.71492285],  total_ssim_loss: [1.38987565] total_loss: [1.12332523]
# Epoch: [22],step: [6000], mri_ssim_loss: [0.64962614], pet_ssim_loss: [0.74618161],  total_ssim_loss: [1.39580774] total_loss: [1.12615693]
# Epoch: [22],step: [6100], mri_ssim_loss: [0.26301420], pet_ssim_loss: [0.22075081],  total_ssim_loss: [0.48376501] total_loss: [0.39158845]
# Epoch: [22],step: [6200], mri_ssim_loss: [0.74999946], pet_ssim_loss: [0.73596907],  total_ssim_loss: [1.48596859] total_loss: [1.19643283]
# Epoch: [23],step: [6300], mri_ssim_loss: [0.64539504], pet_ssim_loss: [0.70023537],  total_ssim_loss: [1.34563041] total_loss: [1.08349013]
# Epoch: [23],step: [6400], mri_ssim_loss: [0.64813381], pet_ssim_loss: [0.73505270],  total_ssim_loss: [1.38318658] total_loss: [1.11695278]
# Epoch: [23],step: [6500], mri_ssim_loss: [0.70825124], pet_ssim_loss: [0.78631055],  total_ssim_loss: [1.49456179] total_loss: [1.20000648]
# Epoch: [24],step: [6600], mri_ssim_loss: [0.65512967], pet_ssim_loss: [0.73572701],  total_ssim_loss: [1.39085674] total_loss: [1.12656081]
# Epoch: [24],step: [6700], mri_ssim_loss: [0.73590648], pet_ssim_loss: [0.77281296],  total_ssim_loss: [1.50871944] total_loss: [1.21541238]
# Epoch: [24],step: [6800], mri_ssim_loss: [0.72238916], pet_ssim_loss: [0.79447627],  total_ssim_loss: [1.51686549] total_loss: [1.22255754]
# Epoch: [25],step: [6900], mri_ssim_loss: [0.21605837], pet_ssim_loss: [0.22235888],  total_ssim_loss: [0.43841726] total_loss: [0.35559887]
# Epoch: [25],step: [7000], mri_ssim_loss: [0.65972674], pet_ssim_loss: [0.65236288],  total_ssim_loss: [1.31208968] total_loss: [1.06337905]
# Epoch: [26],step: [7100], mri_ssim_loss: [0.63614893], pet_ssim_loss: [0.80007702],  total_ssim_loss: [1.43622589] total_loss: [1.15403163]
# Epoch: [26],step: [7200], mri_ssim_loss: [0.13948935], pet_ssim_loss: [0.16763747],  total_ssim_loss: [0.30712682] total_loss: [0.25065258]
# Epoch: [26],step: [7300], mri_ssim_loss: [0.58228928], pet_ssim_loss: [0.77049935],  total_ssim_loss: [1.35278869] total_loss: [1.09420872]
# Epoch: [27],step: [7400], mri_ssim_loss: [0.64989722], pet_ssim_loss: [0.74520338],  total_ssim_loss: [1.39510059] total_loss: [1.12692738]
# Epoch: [27],step: [7500], mri_ssim_loss: [0.71250939], pet_ssim_loss: [0.82563955],  total_ssim_loss: [1.53814888] total_loss: [1.23842871]
# Epoch: [27],step: [7600], mri_ssim_loss: [0.71062160], pet_ssim_loss: [0.84138346],  total_ssim_loss: [1.55200505] total_loss: [1.24810326]
# Epoch: [28],step: [7700], mri_ssim_loss: [0.65242410], pet_ssim_loss: [0.68943167],  total_ssim_loss: [1.34185576] total_loss: [1.07956398]
# Epoch: [28],step: [7800], mri_ssim_loss: [0.62403095], pet_ssim_loss: [0.73146188],  total_ssim_loss: [1.35549283] total_loss: [1.09979939]
# Epoch: [29],step: [7900], mri_ssim_loss: [0.72039139], pet_ssim_loss: [0.82635343],  total_ssim_loss: [1.54674482] total_loss: [1.24282718]
# Epoch: [29],step: [8000], mri_ssim_loss: [0.27677292], pet_ssim_loss: [0.31077969],  total_ssim_loss: [0.58755261] total_loss: [0.47489256]
# Epoch: [29],step: [8100], mri_ssim_loss: [0.72914720], pet_ssim_loss: [0.78791165],  total_ssim_loss: [1.51705885] total_loss: [1.22190809]
# Epoch: [30],step: [8200], mri_ssim_loss: [0.61727035], pet_ssim_loss: [0.72691262],  total_ssim_loss: [1.34418297] total_loss: [1.08541930]
# Epoch: [30],step: [8300], mri_ssim_loss: [0.14348698], pet_ssim_loss: [0.13222980],  total_ssim_loss: [0.27571678] total_loss: [0.22797480]
# Epoch: [30],step: [8400], mri_ssim_loss: [0.68696785], pet_ssim_loss: [0.74334407],  total_ssim_loss: [1.43031192] total_loss: [1.15747404]
# Epoch: [31],step: [8500], mri_ssim_loss: [0.62062883], pet_ssim_loss: [0.74980092],  total_ssim_loss: [1.37042975] total_loss: [1.11351502]
# Epoch: [31],step: [8600], mri_ssim_loss: [0.72338533], pet_ssim_loss: [0.74043816],  total_ssim_loss: [1.46382356] total_loss: [1.17846954]
# Epoch: [31],step: [8700], mri_ssim_loss: [0.68352938], pet_ssim_loss: [0.74089336],  total_ssim_loss: [1.42442274] total_loss: [1.14565289]
# Epoch: [32],step: [8800], mri_ssim_loss: [0.33036125], pet_ssim_loss: [0.33703864],  total_ssim_loss: [0.66739988] total_loss: [0.53902513]
# Epoch: [32],step: [8900], mri_ssim_loss: [0.68540436], pet_ssim_loss: [0.70680523],  total_ssim_loss: [1.39220953] total_loss: [1.12543070]
# Epoch: [33],step: [9000], mri_ssim_loss: [0.61977720], pet_ssim_loss: [0.73196012],  total_ssim_loss: [1.35173726] total_loss: [1.09262347]
# Epoch: [33],step: [9100], mri_ssim_loss: [0.16710347], pet_ssim_loss: [0.21175975],  total_ssim_loss: [0.37886322] total_loss: [0.30847031]
# Epoch: [33],step: [9200], mri_ssim_loss: [0.68975759], pet_ssim_loss: [0.76506174],  total_ssim_loss: [1.45481932] total_loss: [1.17934942]
# Epoch: [34],step: [9300], mri_ssim_loss: [0.69107699], pet_ssim_loss: [0.87490797],  total_ssim_loss: [1.56598496] total_loss: [1.25873971]
# Epoch: [34],step: [9400], mri_ssim_loss: [0.82665598], pet_ssim_loss: [0.89452028],  total_ssim_loss: [1.72117627] total_loss: [1.38221383]
# Epoch: [34],step: [9500], mri_ssim_loss: [0.64949441], pet_ssim_loss: [0.75751913],  total_ssim_loss: [1.40701354] total_loss: [1.13642108]
# Epoch: [35],step: [9600], mri_ssim_loss: [0.78950799], pet_ssim_loss: [0.82472312],  total_ssim_loss: [1.61423111] total_loss: [1.29880714]
# Epoch: [35],step: [9700], mri_ssim_loss: [0.66261667], pet_ssim_loss: [0.76615393],  total_ssim_loss: [1.42877054] total_loss: [1.15484989]
# Epoch: [36],step: [9800], mri_ssim_loss: [0.62004125], pet_ssim_loss: [0.77568233],  total_ssim_loss: [1.39572358] total_loss: [1.12128305]
# Epoch: [36],step: [9900], mri_ssim_loss: [0.23053271], pet_ssim_loss: [0.26481992],  total_ssim_loss: [0.49535263] total_loss: [0.40048581]
# Epoch: [36],step: [10000], mri_ssim_loss: [0.60713577], pet_ssim_loss: [0.67337608],  total_ssim_loss: [1.28051186] total_loss: [1.03453588]
# Epoch: [37],step: [10100], mri_ssim_loss: [0.59004802], pet_ssim_loss: [0.73776078],  total_ssim_loss: [1.32780886] total_loss: [1.07245481]
# Epoch: [37],step: [10200], mri_ssim_loss: [0.18840462], pet_ssim_loss: [0.17270255],  total_ssim_loss: [0.36110717] total_loss: [0.29530162]
# Epoch: [37],step: [10300], mri_ssim_loss: [0.63803035], pet_ssim_loss: [0.73257911],  total_ssim_loss: [1.37060952] total_loss: [1.10700977]
# Epoch: [38],step: [10400], mri_ssim_loss: [0.60004580], pet_ssim_loss: [0.77828497],  total_ssim_loss: [1.37833071] total_loss: [1.11739850]
# Epoch: [38],step: [10500], mri_ssim_loss: [0.63964784], pet_ssim_loss: [0.74722385],  total_ssim_loss: [1.38687170] total_loss: [1.11665058]
# Epoch: [38],step: [10600], mri_ssim_loss: [0.67020464], pet_ssim_loss: [0.70807695],  total_ssim_loss: [1.37828159] total_loss: [1.11596072]
# Epoch: [39],step: [10700], mri_ssim_loss: [0.23355663], pet_ssim_loss: [0.22119141],  total_ssim_loss: [0.45474803] total_loss: [0.36946175]
# Epoch: [39],step: [10800], mri_ssim_loss: [0.67863387], pet_ssim_loss: [0.76842797],  total_ssim_loss: [1.44706178] total_loss: [1.16602647]
# Epoch: [40],step: [10900], mri_ssim_loss: [0.63236070], pet_ssim_loss: [0.74058360],  total_ssim_loss: [1.37294436] total_loss: [1.11442697]
# Epoch: [40],step: [11000], mri_ssim_loss: [0.18720043], pet_ssim_loss: [0.19173753],  total_ssim_loss: [0.37893796] total_loss: [0.30837506]
# Epoch: [40],step: [11100], mri_ssim_loss: [0.55909956], pet_ssim_loss: [0.72172749],  total_ssim_loss: [1.28082705] total_loss: [1.03692913]
# Epoch: [41],step: [11200], mri_ssim_loss: [0.64660138], pet_ssim_loss: [0.71137065],  total_ssim_loss: [1.35797203] total_loss: [1.09454036]
# Epoch: [41],step: [11300], mri_ssim_loss: [0.64941585], pet_ssim_loss: [0.73213017],  total_ssim_loss: [1.38154602] total_loss: [1.11487889]
# Epoch: [41],step: [11400], mri_ssim_loss: [0.65883291], pet_ssim_loss: [0.75305557],  total_ssim_loss: [1.41188848] total_loss: [1.14241135]
# Epoch: [42],step: [11500], mri_ssim_loss: [0.67460978], pet_ssim_loss: [0.80717802],  total_ssim_loss: [1.48178780] total_loss: [1.19834661]
# Epoch: [42],step: [11600], mri_ssim_loss: [0.71840525], pet_ssim_loss: [0.78758156],  total_ssim_loss: [1.50598681] total_loss: [1.21208048]
# Epoch: [43],step: [11700], mri_ssim_loss: [0.65502703], pet_ssim_loss: [0.77957511],  total_ssim_loss: [1.43460214] total_loss: [1.15727520]
# Epoch: [43],step: [11800], mri_ssim_loss: [0.74111426], pet_ssim_loss: [0.78975111],  total_ssim_loss: [1.53086543] total_loss: [1.23049533]
# Epoch: [43],step: [11900], mri_ssim_loss: [0.58087492], pet_ssim_loss: [0.71531278],  total_ssim_loss: [1.29618764] total_loss: [1.05419707]
# Epoch: [44],step: [12000], mri_ssim_loss: [0.58376938], pet_ssim_loss: [0.77362710],  total_ssim_loss: [1.35739648] total_loss: [1.10324728]
# Epoch: [44],step: [12100], mri_ssim_loss: [0.41642022], pet_ssim_loss: [0.47706717],  total_ssim_loss: [0.89348739] total_loss: [0.72062683]
# Epoch: [44],step: [12200], mri_ssim_loss: [0.65833855], pet_ssim_loss: [0.74127418],  total_ssim_loss: [1.39961267] total_loss: [1.13228333]
# Epoch: [45],step: [12300], mri_ssim_loss: [0.61550891], pet_ssim_loss: [0.77288496],  total_ssim_loss: [1.38839388] total_loss: [1.12820387]
# Epoch: [45],step: [12400], mri_ssim_loss: [0.65351868], pet_ssim_loss: [0.75570458],  total_ssim_loss: [1.40922332] total_loss: [1.13427985]
# Epoch: [45],step: [12500], mri_ssim_loss: [0.20662487], pet_ssim_loss: [0.22669178],  total_ssim_loss: [0.43331665] total_loss: [0.35283086]
# Epoch: [46],step: [12600], mri_ssim_loss: [0.24778509], pet_ssim_loss: [0.24175233],  total_ssim_loss: [0.48953742] total_loss: [0.39737889]
# Epoch: [46],step: [12700], mri_ssim_loss: [0.61612886], pet_ssim_loss: [0.67864072],  total_ssim_loss: [1.29476953] total_loss: [1.04922807]
# Epoch: [47],step: [12800], mri_ssim_loss: [0.60047090], pet_ssim_loss: [0.71552551],  total_ssim_loss: [1.31599641] total_loss: [1.06098986]
# Epoch: [47],step: [12900], mri_ssim_loss: [0.19111735], pet_ssim_loss: [0.21264201],  total_ssim_loss: [0.40375936] total_loss: [0.32732880]
# Epoch: [47],step: [13000], mri_ssim_loss: [0.56278896], pet_ssim_loss: [0.73154426],  total_ssim_loss: [1.29433322] total_loss: [1.04325581]
# Epoch: [48],step: [13100], mri_ssim_loss: [0.65426165], pet_ssim_loss: [0.65965331],  total_ssim_loss: [1.31391501] total_loss: [1.06076884]
# Epoch: [48],step: [13200], mri_ssim_loss: [0.63549876], pet_ssim_loss: [0.65014160],  total_ssim_loss: [1.28564036] total_loss: [1.03946853]
# Epoch: [48],step: [13300], mri_ssim_loss: [0.69988632], pet_ssim_loss: [0.80355644],  total_ssim_loss: [1.50344276] total_loss: [1.20845377]
# Epoch: [49],step: [13400], mri_ssim_loss: [0.62863553], pet_ssim_loss: [0.72034115],  total_ssim_loss: [1.34897661] total_loss: [1.09197652]
# Epoch: [49],step: [13500], mri_ssim_loss: [0.69219327], pet_ssim_loss: [0.75232852],  total_ssim_loss: [1.44452178] total_loss: [1.16393161]
# Epoch: [49],step: [13600], mri_ssim_loss: [0.61620569], pet_ssim_loss: [0.81309575],  total_ssim_loss: [1.42930150] total_loss: [1.15293765]
# Epoch: [50],step: [13700], mri_ssim_loss: [0.18910885], pet_ssim_loss: [0.20092911],  total_ssim_loss: [0.39003795] total_loss: [0.31693286]
# Epoch: [50],step: [13800], mri_ssim_loss: [0.62926179], pet_ssim_loss: [0.64903992],  total_ssim_loss: [1.27830172] total_loss: [1.03532565]
# Epoch: [51],step: [13900], mri_ssim_loss: [0.60680616], pet_ssim_loss: [0.76745200],  total_ssim_loss: [1.37425816] total_loss: [1.10370231]
# Epoch: [51],step: [14000], mri_ssim_loss: [0.12009585], pet_ssim_loss: [0.15899003],  total_ssim_loss: [0.27908587] total_loss: [0.22823572]
# Epoch: [51],step: [14100], mri_ssim_loss: [0.49086684], pet_ssim_loss: [0.78508383],  total_ssim_loss: [1.27595067] total_loss: [1.03619885]
# Epoch: [52],step: [14200], mri_ssim_loss: [0.61197126], pet_ssim_loss: [0.74546069],  total_ssim_loss: [1.35743189] total_loss: [1.09604967]
# Epoch: [52],step: [14300], mri_ssim_loss: [0.72117168], pet_ssim_loss: [0.85239059],  total_ssim_loss: [1.57356226] total_loss: [1.26693320]
# Epoch: [52],step: [14400], mri_ssim_loss: [0.68161213], pet_ssim_loss: [0.81660241],  total_ssim_loss: [1.49821448] total_loss: [1.20422101]
# Epoch: [53],step: [14500], mri_ssim_loss: [0.68332654], pet_ssim_loss: [0.71608788],  total_ssim_loss: [1.39941442] total_loss: [1.12583590]
# Epoch: [53],step: [14600], mri_ssim_loss: [0.58670753], pet_ssim_loss: [0.71708190],  total_ssim_loss: [1.30378938] total_loss: [1.05862296]
# Epoch: [54],step: [14700], mri_ssim_loss: [0.67315984], pet_ssim_loss: [0.77307987],  total_ssim_loss: [1.44623971] total_loss: [1.16275060]
# Epoch: [54],step: [14800], mri_ssim_loss: [0.19455874], pet_ssim_loss: [0.21154678],  total_ssim_loss: [0.40610552] total_loss: [0.32920974]
# Epoch: [54],step: [14900], mri_ssim_loss: [0.70523095], pet_ssim_loss: [0.78220731],  total_ssim_loss: [1.48743820] total_loss: [1.19725502]
# Epoch: [55],step: [15000], mri_ssim_loss: [0.59825516], pet_ssim_loss: [0.69130075],  total_ssim_loss: [1.28955591] total_loss: [1.04182875]
# Epoch: [55],step: [15100], mri_ssim_loss: [0.16033471], pet_ssim_loss: [0.14654034],  total_ssim_loss: [0.30687505] total_loss: [0.25352249]
# Epoch: [55],step: [15200], mri_ssim_loss: [0.63125783], pet_ssim_loss: [0.72489995],  total_ssim_loss: [1.35615778] total_loss: [1.09261143]
# Epoch: [56],step: [15300], mri_ssim_loss: [0.59945226], pet_ssim_loss: [0.72693378],  total_ssim_loss: [1.32638597] total_loss: [1.07721913]
# Epoch: [56],step: [15400], mri_ssim_loss: [0.66131681], pet_ssim_loss: [0.74702728],  total_ssim_loss: [1.40834403] total_loss: [1.13378072]
# Epoch: [56],step: [15500], mri_ssim_loss: [0.65917087], pet_ssim_loss: [0.72996712],  total_ssim_loss: [1.38913798] total_loss: [1.11686397]
# Epoch: [57],step: [15600], mri_ssim_loss: [0.55530983], pet_ssim_loss: [0.59550923],  total_ssim_loss: [1.15081906] total_loss: [0.92568278]
# Epoch: [57],step: [15700], mri_ssim_loss: [0.61645842], pet_ssim_loss: [0.68473017],  total_ssim_loss: [1.30118859] total_loss: [1.05206931]
# Epoch: [58],step: [15800], mri_ssim_loss: [0.61289996], pet_ssim_loss: [0.69766027],  total_ssim_loss: [1.31056023] total_loss: [1.05760193]
# Epoch: [58],step: [15900], mri_ssim_loss: [0.16496617], pet_ssim_loss: [0.19880128],  total_ssim_loss: [0.36376745] total_loss: [0.29553479]
# Epoch: [58],step: [16000], mri_ssim_loss: [0.65909922], pet_ssim_loss: [0.72898006],  total_ssim_loss: [1.38807929] total_loss: [1.12506878]
# Epoch: [59],step: [16100], mri_ssim_loss: [0.62599862], pet_ssim_loss: [0.70233446],  total_ssim_loss: [1.32833314] total_loss: [1.06736696]
# Epoch: [59],step: [16200], mri_ssim_loss: [0.75160259], pet_ssim_loss: [0.83799416],  total_ssim_loss: [1.58959675] total_loss: [1.27498186]
# Epoch: [59],step: [16300], mri_ssim_loss: [0.61778104], pet_ssim_loss: [0.73204100],  total_ssim_loss: [1.34982204] total_loss: [1.08911180]
# Epoch: [60],step: [16400], mri_ssim_loss: [0.31353992], pet_ssim_loss: [0.37185955],  total_ssim_loss: [0.68539947] total_loss: [0.55445188]
# Epoch: [60],step: [16500], mri_ssim_loss: [0.62989712], pet_ssim_loss: [0.75608951],  total_ssim_loss: [1.38598657] total_loss: [1.11959755]
# Epoch: [61],step: [16600], mri_ssim_loss: [0.69142401], pet_ssim_loss: [0.78902429],  total_ssim_loss: [1.48044825] total_loss: [1.18845701]
# Epoch: [61],step: [16700], mri_ssim_loss: [0.30991745], pet_ssim_loss: [0.30455261],  total_ssim_loss: [0.61447006] total_loss: [0.49613953]
# Epoch: [61],step: [16800], mri_ssim_loss: [0.59782159], pet_ssim_loss: [0.66640592],  total_ssim_loss: [1.26422751] total_loss: [1.01844251]
# Epoch: [62],step: [16900], mri_ssim_loss: [0.57061487], pet_ssim_loss: [0.66522086],  total_ssim_loss: [1.23583579] total_loss: [0.99636924]
# Epoch: [62],step: [17000], mri_ssim_loss: [0.17181003], pet_ssim_loss: [0.15858245],  total_ssim_loss: [0.33039248] total_loss: [0.27058038]
# Epoch: [62],step: [17100], mri_ssim_loss: [0.65183043], pet_ssim_loss: [0.73600858],  total_ssim_loss: [1.38783908] total_loss: [1.11947370]
# Epoch: [63],step: [17200], mri_ssim_loss: [0.57855749], pet_ssim_loss: [0.75069165],  total_ssim_loss: [1.32924914] total_loss: [1.07536042]
# Epoch: [63],step: [17300], mri_ssim_loss: [0.68171757], pet_ssim_loss: [0.80803102],  total_ssim_loss: [1.48974860] total_loss: [1.19688821]
# Epoch: [63],step: [17400], mri_ssim_loss: [0.64206326], pet_ssim_loss: [0.69309890],  total_ssim_loss: [1.33516216] total_loss: [1.07961011]
# Epoch: [64],step: [17500], mri_ssim_loss: [0.81643999], pet_ssim_loss: [0.80887049],  total_ssim_loss: [1.62531042] total_loss: [1.30634594]
# Epoch: [64],step: [17600], mri_ssim_loss: [0.61210907], pet_ssim_loss: [0.74318987],  total_ssim_loss: [1.35529900] total_loss: [1.09230113]
# Epoch: [65],step: [17700], mri_ssim_loss: [0.58356845], pet_ssim_loss: [0.69258678],  total_ssim_loss: [1.27615523] total_loss: [1.03073418]
# Epoch: [65],step: [17800], mri_ssim_loss: [0.14679062], pet_ssim_loss: [0.17320371],  total_ssim_loss: [0.31999433] total_loss: [0.26016602]
# Epoch: [65],step: [17900], mri_ssim_loss: [0.50312364], pet_ssim_loss: [0.67752111],  total_ssim_loss: [1.18064475] total_loss: [0.95426190]
# Epoch: [66],step: [18000], mri_ssim_loss: [0.52321792], pet_ssim_loss: [0.68001568],  total_ssim_loss: [1.20323360] total_loss: [0.96792954]
# Epoch: [66],step: [18100], mri_ssim_loss: [0.67539263], pet_ssim_loss: [0.80748659],  total_ssim_loss: [1.48287916] total_loss: [1.19150889]
# Epoch: [66],step: [18200], mri_ssim_loss: [0.61793196], pet_ssim_loss: [0.73140931],  total_ssim_loss: [1.34934127] total_loss: [1.08728874]
# Epoch: [67],step: [18300], mri_ssim_loss: [0.25714755], pet_ssim_loss: [0.33250988],  total_ssim_loss: [0.58965743] total_loss: [0.48473150]
# Epoch: [67],step: [18400], mri_ssim_loss: [0.76483119], pet_ssim_loss: [0.82660353],  total_ssim_loss: [1.59143472] total_loss: [1.27821016]
# Epoch: [68],step: [18500], mri_ssim_loss: [0.65454125], pet_ssim_loss: [0.73418963],  total_ssim_loss: [1.38873088] total_loss: [1.11667597]
# Epoch: [68],step: [18600], mri_ssim_loss: [0.16834944], pet_ssim_loss: [0.19112456],  total_ssim_loss: [0.35947400] total_loss: [0.29150629]
# Epoch: [68],step: [18700], mri_ssim_loss: [0.61968708], pet_ssim_loss: [0.71784407],  total_ssim_loss: [1.33753109] total_loss: [1.08192456]
# Epoch: [69],step: [18800], mri_ssim_loss: [0.59675688], pet_ssim_loss: [0.74265075],  total_ssim_loss: [1.33940768] total_loss: [1.08519018]
# Epoch: [69],step: [18900], mri_ssim_loss: [0.16277879], pet_ssim_loss: [0.16868931],  total_ssim_loss: [0.33146811] total_loss: [0.27069974]
# Epoch: [69],step: [19000], mri_ssim_loss: [0.40626597], pet_ssim_loss: [0.46434158],  total_ssim_loss: [0.87060755] total_loss: [0.70437974]
# Epoch: [70],step: [19100], mri_ssim_loss: [0.38477463], pet_ssim_loss: [0.40570682],  total_ssim_loss: [0.79048145] total_loss: [0.64818013]
# Epoch: [70],step: [19200], mri_ssim_loss: [0.66344547], pet_ssim_loss: [0.81797099],  total_ssim_loss: [1.48141646] total_loss: [1.19027853]
# Epoch: [70],step: [19300], mri_ssim_loss: [0.80198348], pet_ssim_loss: [0.83547944],  total_ssim_loss: [1.63746285] total_loss: [1.31500649]
# Epoch: [71],step: [19400], mri_ssim_loss: [0.21572024], pet_ssim_loss: [0.19489777],  total_ssim_loss: [0.41061801] total_loss: [0.33344257]
# Epoch: [71],step: [19500], mri_ssim_loss: [0.67875701], pet_ssim_loss: [0.69125050],  total_ssim_loss: [1.37000751] total_loss: [1.10771775]
# Epoch: [72],step: [19600], mri_ssim_loss: [0.53542525], pet_ssim_loss: [0.73336065],  total_ssim_loss: [1.26878595] total_loss: [1.02198732]
# Epoch: [72],step: [19700], mri_ssim_loss: [0.13714612], pet_ssim_loss: [0.14119267],  total_ssim_loss: [0.27833879] total_loss: [0.22612865]
# Epoch: [72],step: [19800], mri_ssim_loss: [0.83807236], pet_ssim_loss: [0.75292683],  total_ssim_loss: [1.59099913] total_loss: [1.27910531]
# Epoch: [73],step: [19900], mri_ssim_loss: [0.36946297], pet_ssim_loss: [0.39628637],  total_ssim_loss: [0.76574934] total_loss: [0.62134057]
# Epoch: [73],step: [20000], mri_ssim_loss: [0.66012466], pet_ssim_loss: [0.77132761],  total_ssim_loss: [1.43145227] total_loss: [1.15573120]
# Epoch: [73],step: [20100], mri_ssim_loss: [0.64874661], pet_ssim_loss: [0.73996979],  total_ssim_loss: [1.38871646] total_loss: [1.11526287]
# Epoch: [74],step: [20200], mri_ssim_loss: [0.66353226], pet_ssim_loss: [0.74269307],  total_ssim_loss: [1.40622532] total_loss: [1.14021373]
# Epoch: [74],step: [20300], mri_ssim_loss: [0.70618331], pet_ssim_loss: [0.75559849],  total_ssim_loss: [1.46178174] total_loss: [1.17701113]
# Epoch: [74],step: [20400], mri_ssim_loss: [0.74703771], pet_ssim_loss: [0.76669800],  total_ssim_loss: [1.51373577] total_loss: [1.21912825]
# Epoch: [75],step: [20500], mri_ssim_loss: [0.21080661], pet_ssim_loss: [0.17097366],  total_ssim_loss: [0.38178027] total_loss: [0.30930528]
# Epoch: [75],step: [20600], mri_ssim_loss: [0.63393378], pet_ssim_loss: [0.68866825],  total_ssim_loss: [1.32260203] total_loss: [1.06966698]
# Epoch: [76],step: [20700], mri_ssim_loss: [0.19313425], pet_ssim_loss: [0.32388091],  total_ssim_loss: [0.51701516] total_loss: [0.41821414]
# Epoch: [76],step: [20800], mri_ssim_loss: [0.14714700], pet_ssim_loss: [0.16602677],  total_ssim_loss: [0.31317377] total_loss: [0.25482842]
# Epoch: [76],step: [20900], mri_ssim_loss: [0.61578095], pet_ssim_loss: [0.77257514],  total_ssim_loss: [1.38835609] total_loss: [1.12323153]
# Epoch: [77],step: [21000], mri_ssim_loss: [0.71036220], pet_ssim_loss: [0.74480367],  total_ssim_loss: [1.45516586] total_loss: [1.17386425]
# Epoch: [77],step: [21100], mri_ssim_loss: [0.69622636], pet_ssim_loss: [0.83345795],  total_ssim_loss: [1.52968431] total_loss: [1.23079872]
# Epoch: [77],step: [21200], mri_ssim_loss: [0.65394652], pet_ssim_loss: [0.79586399],  total_ssim_loss: [1.44981050] total_loss: [1.16563725]
# Epoch: [78],step: [21300], mri_ssim_loss: [0.21084881], pet_ssim_loss: [0.22403640],  total_ssim_loss: [0.43488520] total_loss: [0.35383594]
# Epoch: [78],step: [21400], mri_ssim_loss: [0.36466354], pet_ssim_loss: [0.47963893],  total_ssim_loss: [0.84430248] total_loss: [0.69173235]
# Epoch: [79],step: [21500], mri_ssim_loss: [0.70706034], pet_ssim_loss: [0.81901944],  total_ssim_loss: [1.52607977] total_loss: [1.23339081]
# Epoch: [79],step: [21600], mri_ssim_loss: [0.17236561], pet_ssim_loss: [0.18507725],  total_ssim_loss: [0.35744286] total_loss: [0.29094532]
# Epoch: [79],step: [21700], mri_ssim_loss: [0.23675561], pet_ssim_loss: [0.28558397],  total_ssim_loss: [0.52233958] total_loss: [0.42495063]
# Epoch: [80],step: [21800], mri_ssim_loss: [0.33870411], pet_ssim_loss: [0.44514477],  total_ssim_loss: [0.78384888] total_loss: [0.63764358]
# Epoch: [80],step: [21900], mri_ssim_loss: [0.18406606], pet_ssim_loss: [0.18549591],  total_ssim_loss: [0.36956197] total_loss: [0.30401367]
# Epoch: [80],step: [22000], mri_ssim_loss: [0.22566921], pet_ssim_loss: [0.26841748],  total_ssim_loss: [0.49408668] total_loss: [0.40382719]
# Epoch: [81],step: [22100], mri_ssim_loss: [0.35893244], pet_ssim_loss: [0.42716610],  total_ssim_loss: [0.78609854] total_loss: [0.65109795]
# Epoch: [81],step: [22200], mri_ssim_loss: [0.23050958], pet_ssim_loss: [0.29301679],  total_ssim_loss: [0.52352637] total_loss: [0.42719156]
# Epoch: [81],step: [22300], mri_ssim_loss: [0.55229688], pet_ssim_loss: [0.63305712],  total_ssim_loss: [1.18535399] total_loss: [0.95573264]
# Epoch: [82],step: [22400], mri_ssim_loss: [0.17458570], pet_ssim_loss: [0.17396837],  total_ssim_loss: [0.34855407] total_loss: [0.28406435]
# Epoch: [82],step: [22500], mri_ssim_loss: [0.49938089], pet_ssim_loss: [0.57108045],  total_ssim_loss: [1.07046127] total_loss: [0.86641526]
# Epoch: [83],step: [22600], mri_ssim_loss: [0.27944922], pet_ssim_loss: [0.36268419],  total_ssim_loss: [0.64213341] total_loss: [0.52478474]
# Epoch: [83],step: [22700], mri_ssim_loss: [0.12968707], pet_ssim_loss: [0.15872490],  total_ssim_loss: [0.28841197] total_loss: [0.23521991]
# Epoch: [83],step: [22800], mri_ssim_loss: [0.52727216], pet_ssim_loss: [0.36331671],  total_ssim_loss: [0.89058888] total_loss: [0.72557104]
# Epoch: [84],step: [22900], mri_ssim_loss: [0.64819717], pet_ssim_loss: [0.74516726],  total_ssim_loss: [1.39336443] total_loss: [1.12251019]
# Epoch: [84],step: [23000], mri_ssim_loss: [0.39456189], pet_ssim_loss: [0.40978163],  total_ssim_loss: [0.80434352] total_loss: [0.64824182]
# Epoch: [84],step: [23100], mri_ssim_loss: [0.43430507], pet_ssim_loss: [0.57123244],  total_ssim_loss: [1.00553751] total_loss: [0.81718379]
# Epoch: [85],step: [23200], mri_ssim_loss: [0.26891953], pet_ssim_loss: [0.29509681],  total_ssim_loss: [0.56401634] total_loss: [0.45818177]
# Epoch: [85],step: [23300], mri_ssim_loss: [0.65558463], pet_ssim_loss: [0.68333685],  total_ssim_loss: [1.33892155] total_loss: [1.08067858]
# Epoch: [86],step: [23400], mri_ssim_loss: [0.41901362], pet_ssim_loss: [0.51450205],  total_ssim_loss: [0.93351567] total_loss: [0.75298780]
# Epoch: [86],step: [23500], mri_ssim_loss: [0.14767885], pet_ssim_loss: [0.17314923],  total_ssim_loss: [0.32082808] total_loss: [0.26122066]
# Epoch: [86],step: [23600], mri_ssim_loss: [0.55978698], pet_ssim_loss: [0.64185959],  total_ssim_loss: [1.20164657] total_loss: [0.96876103]
# Epoch: [87],step: [23700], mri_ssim_loss: [0.46835834], pet_ssim_loss: [0.71619815],  total_ssim_loss: [1.18455648] total_loss: [0.95660067]
# Epoch: [87],step: [23800], mri_ssim_loss: [0.14227736], pet_ssim_loss: [0.14861685],  total_ssim_loss: [0.29089421] total_loss: [0.23834488]
# Epoch: [87],step: [23900], mri_ssim_loss: [0.39666349], pet_ssim_loss: [0.48099852],  total_ssim_loss: [0.87766200] total_loss: [0.70918715]
# Epoch: [88],step: [24000], mri_ssim_loss: [0.52945542], pet_ssim_loss: [0.60348618],  total_ssim_loss: [1.13294160] total_loss: [0.92268604]
# Epoch: [88],step: [24100], mri_ssim_loss: [0.24522799], pet_ssim_loss: [0.35390902],  total_ssim_loss: [0.59913701] total_loss: [0.48579171]
# Epoch: [88],step: [24200], mri_ssim_loss: [0.34082073], pet_ssim_loss: [0.36270940],  total_ssim_loss: [0.70353013] total_loss: [0.57470882]
# Epoch: [89],step: [24300], mri_ssim_loss: [0.18612331], pet_ssim_loss: [0.19145572],  total_ssim_loss: [0.37757903] total_loss: [0.30813920]
# Epoch: [89],step: [24400], mri_ssim_loss: [0.24452722], pet_ssim_loss: [0.35106307],  total_ssim_loss: [0.59559029] total_loss: [0.48488054]
# Epoch: [90],step: [24500], mri_ssim_loss: [0.25680053], pet_ssim_loss: [0.42743880],  total_ssim_loss: [0.68423933] total_loss: [0.55839306]
# Epoch: [90],step: [24600], mri_ssim_loss: [0.12866426], pet_ssim_loss: [0.14861888],  total_ssim_loss: [0.27728313] total_loss: [0.22591595]
# Epoch: [90],step: [24700], mri_ssim_loss: [0.90299445], pet_ssim_loss: [0.71369159],  total_ssim_loss: [1.61668611] total_loss: [1.30273259]
# Epoch: [91],step: [24800], mri_ssim_loss: [0.27109027], pet_ssim_loss: [0.38093358],  total_ssim_loss: [0.65202385] total_loss: [0.52996200]
# Epoch: [91],step: [24900], mri_ssim_loss: [0.45697081], pet_ssim_loss: [0.52410203],  total_ssim_loss: [0.98107284] total_loss: [0.79195780]
# Epoch: [91],step: [25000], mri_ssim_loss: [0.18055820], pet_ssim_loss: [0.29570538],  total_ssim_loss: [0.47626358] total_loss: [0.39076060]
# Epoch: [92],step: [25100], mri_ssim_loss: [0.24159181], pet_ssim_loss: [0.34240919],  total_ssim_loss: [0.58400100] total_loss: [0.48422223]
# Epoch: [92],step: [25200], mri_ssim_loss: [0.15385383], pet_ssim_loss: [0.26080066],  total_ssim_loss: [0.41465449] total_loss: [0.33873489]
# Epoch: [93],step: [25300], mri_ssim_loss: [0.27666175], pet_ssim_loss: [0.37157428],  total_ssim_loss: [0.64823604] total_loss: [0.52718186]
# Epoch: [93],step: [25400], mri_ssim_loss: [0.13933307], pet_ssim_loss: [0.16564387],  total_ssim_loss: [0.30497694] total_loss: [0.24849278]
# Epoch: [93],step: [25500], mri_ssim_loss: [0.34932697], pet_ssim_loss: [0.47508538],  total_ssim_loss: [0.82441235] total_loss: [0.67372018]
# Epoch: [94],step: [25600], mri_ssim_loss: [0.25038105], pet_ssim_loss: [0.43346393],  total_ssim_loss: [0.68384498] total_loss: [0.56276774]
# Epoch: [94],step: [25700], mri_ssim_loss: [0.12740952], pet_ssim_loss: [0.15364897],  total_ssim_loss: [0.28105849] total_loss: [0.22985305]
# Epoch: [94],step: [25800], mri_ssim_loss: [0.31991726], pet_ssim_loss: [0.43683839],  total_ssim_loss: [0.75675565] total_loss: [0.61447608]
# Epoch: [95],step: [25900], mri_ssim_loss: [0.36722368], pet_ssim_loss: [0.46001065],  total_ssim_loss: [0.82723433] total_loss: [0.67955947]
# Epoch: [95],step: [26000], mri_ssim_loss: [0.15034819], pet_ssim_loss: [0.30717897],  total_ssim_loss: [0.45752716] total_loss: [0.37294984]
# Epoch: [95],step: [26100], mri_ssim_loss: [0.74019474], pet_ssim_loss: [0.77168703],  total_ssim_loss: [1.51188183] total_loss: [1.21522307]
# Epoch: [96],step: [26200], mri_ssim_loss: [0.20293576], pet_ssim_loss: [0.21906298],  total_ssim_loss: [0.42199874] total_loss: [0.34376580]
# Epoch: [96],step: [26300], mri_ssim_loss: [0.44547611], pet_ssim_loss: [0.47012323],  total_ssim_loss: [0.91559935] total_loss: [0.74422586]
# Epoch: [97],step: [26400], mri_ssim_loss: [0.61435831], pet_ssim_loss: [0.83704537],  total_ssim_loss: [1.45140362] total_loss: [1.17022693]
# Epoch: [97],step: [26500], mri_ssim_loss: [0.40860069], pet_ssim_loss: [0.43767166],  total_ssim_loss: [0.84627235] total_loss: [0.68195939]
# Epoch: [97],step: [26600], mri_ssim_loss: [0.61078995], pet_ssim_loss: [0.52777463],  total_ssim_loss: [1.13856459] total_loss: [0.91718787]
# Epoch: [98],step: [26700], mri_ssim_loss: [0.31377202], pet_ssim_loss: [0.37184769],  total_ssim_loss: [0.68561971] total_loss: [0.55713648]
# Epoch: [98],step: [26800], mri_ssim_loss: [0.61665475], pet_ssim_loss: [0.73206264],  total_ssim_loss: [1.34871745] total_loss: [1.09134960]
# Epoch: [98],step: [26900], mri_ssim_loss: [0.22692209], pet_ssim_loss: [0.32220393],  total_ssim_loss: [0.54912603] total_loss: [0.44377169]
# Epoch: [99],step: [27000], mri_ssim_loss: [0.28917438], pet_ssim_loss: [0.35197717],  total_ssim_loss: [0.64115155] total_loss: [0.53048831]
# Epoch: [99],step: [27100], mri_ssim_loss: [0.22756386], pet_ssim_loss: [0.28273052],  total_ssim_loss: [0.51029438] total_loss: [0.41670099]
# Epoch: [99],step: [27200], mri_ssim_loss: [0.32747895], pet_ssim_loss: [0.46222550],  total_ssim_loss: [0.78970444] total_loss: [0.64213455]
# Epoch: [100],step: [27300], mri_ssim_loss: [0.15890300], pet_ssim_loss: [0.18575323],  total_ssim_loss: [0.34465623] total_loss: [0.28100735]
# Epoch: [100],step: [27400], mri_ssim_loss: [0.51008576], pet_ssim_loss: [0.55641073],  total_ssim_loss: [1.06649649] total_loss: [0.86671990]
# Epoch: [101],step: [27500], mri_ssim_loss: [0.19502312], pet_ssim_loss: [0.33930725],  total_ssim_loss: [0.53433037] total_loss: [0.43552625]
# Epoch: [101],step: [27600], mri_ssim_loss: [0.12185246], pet_ssim_loss: [0.16007143],  total_ssim_loss: [0.28192389] total_loss: [0.23049417]
# Epoch: [101],step: [27700], mri_ssim_loss: [0.28343254], pet_ssim_loss: [0.65038764],  total_ssim_loss: [0.93382019] total_loss: [0.75901812]
# Epoch: [102],step: [27800], mri_ssim_loss: [0.68949115], pet_ssim_loss: [0.74038076],  total_ssim_loss: [1.42987192] total_loss: [1.15688324]
# Epoch: [102],step: [27900], mri_ssim_loss: [0.16239852], pet_ssim_loss: [0.33858544],  total_ssim_loss: [0.50098395] total_loss: [0.40968454]
# Epoch: [102],step: [28000], mri_ssim_loss: [0.36738056], pet_ssim_loss: [0.52279001],  total_ssim_loss: [0.89017057] total_loss: [0.71859431]
# Epoch: [103],step: [28100], mri_ssim_loss: [0.24279368], pet_ssim_loss: [0.26099300],  total_ssim_loss: [0.50378668] total_loss: [0.40920466]
# Epoch: [103],step: [28200], mri_ssim_loss: [0.58137012], pet_ssim_loss: [0.71071327],  total_ssim_loss: [1.29208338] total_loss: [1.05131650]
# Epoch: [104],step: [28300], mri_ssim_loss: [0.28062093], pet_ssim_loss: [0.38113451],  total_ssim_loss: [0.66175544] total_loss: [0.53844285]
# Epoch: [104],step: [28400], mri_ssim_loss: [0.14102876], pet_ssim_loss: [0.16092068],  total_ssim_loss: [0.30194944] total_loss: [0.24640037]
# Epoch: [104],step: [28500], mri_ssim_loss: [0.18542629], pet_ssim_loss: [0.27208227],  total_ssim_loss: [0.45750856] total_loss: [0.37252346]
# Epoch: [105],step: [28600], mri_ssim_loss: [0.28797436], pet_ssim_loss: [0.40529507],  total_ssim_loss: [0.69326943] total_loss: [0.56398141]
# Epoch: [105],step: [28700], mri_ssim_loss: [0.17471117], pet_ssim_loss: [0.16950953],  total_ssim_loss: [0.34422070] total_loss: [0.28395426]
# Epoch: [105],step: [28800], mri_ssim_loss: [0.23818064], pet_ssim_loss: [0.30365062],  total_ssim_loss: [0.54183125] total_loss: [0.44115296]
# Epoch: [106],step: [28900], mri_ssim_loss: [0.30096775], pet_ssim_loss: [0.38329649],  total_ssim_loss: [0.68426424] total_loss: [0.56832421]
# Epoch: [106],step: [29000], mri_ssim_loss: [0.22416919], pet_ssim_loss: [0.29384398],  total_ssim_loss: [0.51801318] total_loss: [0.42232189]
# Epoch: [106],step: [29100], mri_ssim_loss: [0.20673507], pet_ssim_loss: [0.28904885],  total_ssim_loss: [0.49578393] total_loss: [0.40444973]
# Epoch: [107],step: [29200], mri_ssim_loss: [0.16155219], pet_ssim_loss: [0.17753249],  total_ssim_loss: [0.33908468] total_loss: [0.27714556]
# Epoch: [107],step: [29300], mri_ssim_loss: [0.31610537], pet_ssim_loss: [0.41675419],  total_ssim_loss: [0.73285955] total_loss: [0.59619391]
# Epoch: [108],step: [29400], mri_ssim_loss: [0.25172311], pet_ssim_loss: [0.33036643],  total_ssim_loss: [0.58208954] total_loss: [0.47630045]
# Epoch: [108],step: [29500], mri_ssim_loss: [0.12004489], pet_ssim_loss: [0.16124338],  total_ssim_loss: [0.28128827] total_loss: [0.23002456]
# Epoch: [108],step: [29600], mri_ssim_loss: [0.29101223], pet_ssim_loss: [0.62650824],  total_ssim_loss: [0.91752046] total_loss: [0.74787056]
# Epoch: [109],step: [29700], mri_ssim_loss: [0.62868667], pet_ssim_loss: [0.70779192],  total_ssim_loss: [1.33647859] total_loss: [1.07682443]
# Epoch: [109],step: [29800], mri_ssim_loss: [0.43400979], pet_ssim_loss: [0.44575149],  total_ssim_loss: [0.87976128] total_loss: [0.70792025]
# Epoch: [109],step: [29900], mri_ssim_loss: [0.15072733], pet_ssim_loss: [0.29050130],  total_ssim_loss: [0.44122863] total_loss: [0.36395407]
# Epoch: [110],step: [30000], mri_ssim_loss: [0.38164318], pet_ssim_loss: [0.41174418],  total_ssim_loss: [0.79338735] total_loss: [0.64281136]
# Epoch: [110],step: [30100], mri_ssim_loss: [0.48618436], pet_ssim_loss: [0.58657312],  total_ssim_loss: [1.07275748] total_loss: [0.86856425]
# Epoch: [111],step: [30200], mri_ssim_loss: [0.25496954], pet_ssim_loss: [0.34948546],  total_ssim_loss: [0.60445499] total_loss: [0.49044925]
# Epoch: [111],step: [30300], mri_ssim_loss: [0.15351588], pet_ssim_loss: [0.18094122],  total_ssim_loss: [0.33445710] total_loss: [0.27285349]
# Epoch: [111],step: [30400], mri_ssim_loss: [0.51346636], pet_ssim_loss: [0.58806843],  total_ssim_loss: [1.10153484] total_loss: [0.88972980]
# Epoch: [112],step: [30500], mri_ssim_loss: [0.57873952], pet_ssim_loss: [0.64700168],  total_ssim_loss: [1.22574115] total_loss: [0.99183601]
# Epoch: [112],step: [30600], mri_ssim_loss: [0.14355803], pet_ssim_loss: [0.15455163],  total_ssim_loss: [0.29810965] total_loss: [0.24470450]
# Epoch: [112],step: [30700], mri_ssim_loss: [0.21410334], pet_ssim_loss: [0.30993026],  total_ssim_loss: [0.52403361] total_loss: [0.42633104]
# Epoch: [113],step: [30800], mri_ssim_loss: [0.30953652], pet_ssim_loss: [0.41313648],  total_ssim_loss: [0.72267300] total_loss: [0.59384555]
# Epoch: [113],step: [30900], mri_ssim_loss: [0.14130795], pet_ssim_loss: [0.29568577],  total_ssim_loss: [0.43699372] total_loss: [0.35656163]
# Epoch: [113],step: [31000], mri_ssim_loss: [0.26404721], pet_ssim_loss: [0.31640017],  total_ssim_loss: [0.58044738] total_loss: [0.47592747]
# Epoch: [114],step: [31100], mri_ssim_loss: [0.17031968], pet_ssim_loss: [0.18425256],  total_ssim_loss: [0.35457224] total_loss: [0.28993940]
# Epoch: [114],step: [31200], mri_ssim_loss: [0.24639505], pet_ssim_loss: [0.37205482],  total_ssim_loss: [0.61844987] total_loss: [0.50263840]
# Epoch: [115],step: [31300], mri_ssim_loss: [0.26678056], pet_ssim_loss: [0.39819658],  total_ssim_loss: [0.66497713] total_loss: [0.54281998]
# Epoch: [115],step: [31400], mri_ssim_loss: [0.12197942], pet_ssim_loss: [0.15881169],  total_ssim_loss: [0.28079110] total_loss: [0.22988267]
# Epoch: [115],step: [31500], mri_ssim_loss: [0.25452882], pet_ssim_loss: [0.55955708],  total_ssim_loss: [0.81408590] total_loss: [0.66105825]
# Epoch: [116],step: [31600], mri_ssim_loss: [0.26800191], pet_ssim_loss: [0.39049631],  total_ssim_loss: [0.65849823] total_loss: [0.53518462]
# Epoch: [116],step: [31700], mri_ssim_loss: [0.36112821], pet_ssim_loss: [0.45259482],  total_ssim_loss: [0.81372303] total_loss: [0.65888083]
# Epoch: [116],step: [31800], mri_ssim_loss: [0.16270322], pet_ssim_loss: [0.26871163],  total_ssim_loss: [0.43141484] total_loss: [0.35485834]
# Epoch: [117],step: [31900], mri_ssim_loss: [0.20341712], pet_ssim_loss: [0.34118730],  total_ssim_loss: [0.54460442] total_loss: [0.45170671]
# Epoch: [117],step: [32000], mri_ssim_loss: [0.13940483], pet_ssim_loss: [0.25655687],  total_ssim_loss: [0.39596170] total_loss: [0.32359365]
# Epoch: [118],step: [32100], mri_ssim_loss: [0.19005567], pet_ssim_loss: [0.28734243],  total_ssim_loss: [0.47739810] total_loss: [0.38992998]
# Epoch: [118],step: [32200], mri_ssim_loss: [0.12780601], pet_ssim_loss: [0.17157328],  total_ssim_loss: [0.29937929] total_loss: [0.24491692]
# Epoch: [118],step: [32300], mri_ssim_loss: [0.27529478], pet_ssim_loss: [0.38459015],  total_ssim_loss: [0.65988493] total_loss: [0.54040182]
# Epoch: [119],step: [32400], mri_ssim_loss: [0.36154622], pet_ssim_loss: [0.53680491],  total_ssim_loss: [0.89835113] total_loss: [0.73251355]
# Epoch: [119],step: [32500], mri_ssim_loss: [0.12573683], pet_ssim_loss: [0.15250456],  total_ssim_loss: [0.27824140] total_loss: [0.22831281]
# Epoch: [119],step: [32600], mri_ssim_loss: [0.55937320], pet_ssim_loss: [0.67580092],  total_ssim_loss: [1.23517418] total_loss: [0.99725169]
# Epoch: [120],step: [32700], mri_ssim_loss: [0.31095785], pet_ssim_loss: [0.40519094],  total_ssim_loss: [0.71614879] total_loss: [0.58955824]
# Epoch: [120],step: [32800], mri_ssim_loss: [0.16988385], pet_ssim_loss: [0.38102245],  total_ssim_loss: [0.55090630] total_loss: [0.44803891]
# Epoch: [120],step: [32900], mri_ssim_loss: [0.14217615], pet_ssim_loss: [0.17044979],  total_ssim_loss: [0.31262594] total_loss: [0.25807422]
# Epoch: [121],step: [33000], mri_ssim_loss: [0.18201441], pet_ssim_loss: [0.19592655],  total_ssim_loss: [0.37794095] total_loss: [0.30915061]
# Epoch: [121],step: [33100], mri_ssim_loss: [0.24854624], pet_ssim_loss: [0.30408013],  total_ssim_loss: [0.55262637] total_loss: [0.45478097]
# Epoch: [122],step: [33200], mri_ssim_loss: [0.53092742], pet_ssim_loss: [0.66266441],  total_ssim_loss: [1.19359183] total_loss: [0.96413720]
# Epoch: [122],step: [33300], mri_ssim_loss: [0.12664574], pet_ssim_loss: [0.15581137],  total_ssim_loss: [0.28245711] total_loss: [0.23153009]
# Epoch: [122],step: [33400], mri_ssim_loss: [0.32930899], pet_ssim_loss: [0.52446437],  total_ssim_loss: [0.85377336] total_loss: [0.69006401]
# Epoch: [123],step: [33500], mri_ssim_loss: [0.27142525], pet_ssim_loss: [0.36758244],  total_ssim_loss: [0.63900769] total_loss: [0.51936543]
# Epoch: [123],step: [33600], mri_ssim_loss: [0.39792460], pet_ssim_loss: [0.40880162],  total_ssim_loss: [0.80672622] total_loss: [0.65737480]
# Epoch: [123],step: [33700], mri_ssim_loss: [0.12427247], pet_ssim_loss: [0.24909890],  total_ssim_loss: [0.37337136] total_loss: [0.30393168]
# Epoch: [124],step: [33800], mri_ssim_loss: [0.25526661], pet_ssim_loss: [0.33699441],  total_ssim_loss: [0.59226102] total_loss: [0.49015751]
# Epoch: [124],step: [33900], mri_ssim_loss: [0.25888622], pet_ssim_loss: [0.32884747],  total_ssim_loss: [0.58773369] total_loss: [0.47882399]
# Epoch: [124],step: [34000], mri_ssim_loss: [0.28531450], pet_ssim_loss: [0.45712256],  total_ssim_loss: [0.74243706] total_loss: [0.60421938]
# ...
# Epoch: [461],step: [125600], mri_ssim_loss: [0.19396609], pet_ssim_loss: [0.28043234],  total_ssim_loss: [0.47439843] total_loss: [0.38561860]
# Epoch: [462],step: [125700], mri_ssim_loss: [0.26594996], pet_ssim_loss: [0.39370602],  total_ssim_loss: [0.65965599] total_loss: [0.53495383]
# Epoch: [462],step: [125800], mri_ssim_loss: [0.11066848], pet_ssim_loss: [0.13410968],  total_ssim_loss: [0.24477816] total_loss: [0.20716277]
# Epoch: [462],step: [125900], mri_ssim_loss: [0.15197432], pet_ssim_loss: [0.30647856],  total_ssim_loss: [0.45845288] total_loss: [0.37297672]
# Epoch: [463],step: [126000], mri_ssim_loss: [0.23501641], pet_ssim_loss: [0.40736014],  total_ssim_loss: [0.64237654] total_loss: [0.52623183]
# Epoch: [463],step: [126100], mri_ssim_loss: [0.15154457], pet_ssim_loss: [0.27832890],  total_ssim_loss: [0.42987347] total_loss: [0.34956008]
# Epoch: [463],step: [126200], mri_ssim_loss: [0.24425763], pet_ssim_loss: [0.32598740],  total_ssim_loss: [0.57024503] total_loss: [0.46503469]
# Epoch: [464],step: [126300], mri_ssim_loss: [0.16576678], pet_ssim_loss: [0.20533049],  total_ssim_loss: [0.37109727] total_loss: [0.30582678]
# Epoch: [464],step: [126400], mri_ssim_loss: [0.13619608], pet_ssim_loss: [0.28514892],  total_ssim_loss: [0.42134500] total_loss: [0.34325817]
# Epoch: [465],step: [126500], mri_ssim_loss: [0.30098253], pet_ssim_loss: [0.46596545],  total_ssim_loss: [0.76694798] total_loss: [0.62128234]
# Epoch: [465],step: [126600], mri_ssim_loss: [0.12602967], pet_ssim_loss: [0.15673494],  total_ssim_loss: [0.28276461] total_loss: [0.23561767]
# Epoch: [465],step: [126700], mri_ssim_loss: [0.51390731], pet_ssim_loss: [0.45660198],  total_ssim_loss: [0.97050929] total_loss: [0.78341031]
# Epoch: [466],step: [126800], mri_ssim_loss: [0.25842237], pet_ssim_loss: [0.31857389],  total_ssim_loss: [0.57699627] total_loss: [0.46853992]
# Epoch: [466],step: [126900], mri_ssim_loss: [0.20112252], pet_ssim_loss: [0.26246947],  total_ssim_loss: [0.46359199] total_loss: [0.37715048]
# Epoch: [466],step: [127000], mri_ssim_loss: [0.18471742], pet_ssim_loss: [0.28254896],  total_ssim_loss: [0.46726638] total_loss: [0.38180619]
# Epoch: [467],step: [127100], mri_ssim_loss: [0.17074311], pet_ssim_loss: [0.33032382],  total_ssim_loss: [0.50106692] total_loss: [0.41361305]
# Epoch: [467],step: [127200], mri_ssim_loss: [0.13623840], pet_ssim_loss: [0.24065679],  total_ssim_loss: [0.37689519] total_loss: [0.30809796]
# Epoch: [468],step: [127300], mri_ssim_loss: [0.22361034], pet_ssim_loss: [0.33124459],  total_ssim_loss: [0.55485493] total_loss: [0.45090970]
# Epoch: [468],step: [127400], mri_ssim_loss: [0.12162966], pet_ssim_loss: [0.17060202],  total_ssim_loss: [0.29223168] total_loss: [0.24221478]
# Epoch: [468],step: [127500], mri_ssim_loss: [0.22937948], pet_ssim_loss: [0.37175429],  total_ssim_loss: [0.60113376] total_loss: [0.49111313]
# Epoch: [469],step: [127600], mri_ssim_loss: [0.33260733], pet_ssim_loss: [0.48721415],  total_ssim_loss: [0.81982148] total_loss: [0.66778409]
# Epoch: [469],step: [127700], mri_ssim_loss: [0.11605918], pet_ssim_loss: [0.13717741],  total_ssim_loss: [0.25323659] total_loss: [0.21355204]
# Epoch: [469],step: [127800], mri_ssim_loss: [0.18016124], pet_ssim_loss: [0.32441306],  total_ssim_loss: [0.50457430] total_loss: [0.41186696]
# Epoch: [470],step: [127900], mri_ssim_loss: [0.26505208], pet_ssim_loss: [0.42827243],  total_ssim_loss: [0.69332451] total_loss: [0.56882566]
# Epoch: [470],step: [128000], mri_ssim_loss: [0.28357768], pet_ssim_loss: [0.42463654],  total_ssim_loss: [0.70821422] total_loss: [0.57260829]
# Epoch: [470],step: [128100], mri_ssim_loss: [0.34671825], pet_ssim_loss: [0.37188923],  total_ssim_loss: [0.71860749] total_loss: [0.58495438]
# Epoch: [471],step: [128200], mri_ssim_loss: [0.15545380], pet_ssim_loss: [0.19620502],  total_ssim_loss: [0.35165882] total_loss: [0.29032293]
# Epoch: [471],step: [128300], mri_ssim_loss: [0.20824510], pet_ssim_loss: [0.29311997],  total_ssim_loss: [0.50136507] total_loss: [0.41093621]
# Epoch: [472],step: [128400], mri_ssim_loss: [0.19255036], pet_ssim_loss: [0.37737352],  total_ssim_loss: [0.56992388] total_loss: [0.46277821]
# Epoch: [472],step: [128500], mri_ssim_loss: [0.12565404], pet_ssim_loss: [0.15318811],  total_ssim_loss: [0.27884215] total_loss: [0.23201799]
# Epoch: [472],step: [128600], mri_ssim_loss: [0.16650015], pet_ssim_loss: [0.69111705],  total_ssim_loss: [0.85761720] total_loss: [0.69249135]
# Epoch: [473],step: [128700], mri_ssim_loss: [0.26852727], pet_ssim_loss: [0.31940591],  total_ssim_loss: [0.58793318] total_loss: [0.47711682]
# Epoch: [473],step: [128800], mri_ssim_loss: [0.25149959], pet_ssim_loss: [0.32233435],  total_ssim_loss: [0.57383394] total_loss: [0.46858472]
# Epoch: [473],step: [128900], mri_ssim_loss: [0.13346237], pet_ssim_loss: [0.27103102],  total_ssim_loss: [0.40449339] total_loss: [0.32923710]
# Epoch: [474],step: [129000], mri_ssim_loss: [0.20942825], pet_ssim_loss: [0.33720481],  total_ssim_loss: [0.54663306] total_loss: [0.45060900]
# Epoch: [474],step: [129100], mri_ssim_loss: [0.16768259], pet_ssim_loss: [0.23673248],  total_ssim_loss: [0.40441507] total_loss: [0.33184862]
# Epoch: [474],step: [129200], mri_ssim_loss: [0.18416518], pet_ssim_loss: [0.45854634],  total_ssim_loss: [0.64271152] total_loss: [0.52372903]
# Epoch: [475],step: [129300], mri_ssim_loss: [0.13498062], pet_ssim_loss: [0.16972357],  total_ssim_loss: [0.30470419] total_loss: [0.25271121]
# Epoch: [475],step: [129400], mri_ssim_loss: [0.27222162], pet_ssim_loss: [0.36881757],  total_ssim_loss: [0.64103919] total_loss: [0.52233589]
# Epoch: [476],step: [129500], mri_ssim_loss: [0.17865759], pet_ssim_loss: [0.27545553],  total_ssim_loss: [0.45411313] total_loss: [0.36894685]
# Epoch: [476],step: [129600], mri_ssim_loss: [0.11342680], pet_ssim_loss: [0.15007126],  total_ssim_loss: [0.26349807] total_loss: [0.22136940]
# Epoch: [476],step: [129700], mri_ssim_loss: [0.21116090], pet_ssim_loss: [0.61067712],  total_ssim_loss: [0.82183802] total_loss: [0.66663533]
# Epoch: [477],step: [129800], mri_ssim_loss: [0.20824814], pet_ssim_loss: [0.39305454],  total_ssim_loss: [0.60130268] total_loss: [0.49046984]
# Epoch: [477],step: [129900], mri_ssim_loss: [0.15555912], pet_ssim_loss: [0.31118476],  total_ssim_loss: [0.46674389] total_loss: [0.38150704]
# Epoch: [477],step: [130000], mri_ssim_loss: [0.10997820], pet_ssim_loss: [0.23577821],  total_ssim_loss: [0.34575641] total_loss: [0.28340605]
# Epoch: [478],step: [130100], mri_ssim_loss: [0.16713613], pet_ssim_loss: [0.22836423],  total_ssim_loss: [0.39550036] total_loss: [0.32596174]
# Epoch: [478],step: [130200], mri_ssim_loss: [0.17944145], pet_ssim_loss: [0.35380518],  total_ssim_loss: [0.53324664] total_loss: [0.43831840]
# Epoch: [479],step: [130300], mri_ssim_loss: [0.23930591], pet_ssim_loss: [0.31757438],  total_ssim_loss: [0.55688030] total_loss: [0.45217511]
# Epoch: [479],step: [130400], mri_ssim_loss: [0.13205564], pet_ssim_loss: [0.15802395],  total_ssim_loss: [0.29007959] total_loss: [0.24091659]
# Epoch: [479],step: [130500], mri_ssim_loss: [0.16120225], pet_ssim_loss: [0.23754865],  total_ssim_loss: [0.39875090] total_loss: [0.32548308]
# Epoch: [480],step: [130600], mri_ssim_loss: [0.36301601], pet_ssim_loss: [0.45346928],  total_ssim_loss: [0.81648529] total_loss: [0.66073507]
# Epoch: [480],step: [130700], mri_ssim_loss: [0.09302914], pet_ssim_loss: [0.11487436],  total_ssim_loss: [0.20790350] total_loss: [0.17739928]
# Epoch: [480],step: [130800], mri_ssim_loss: [0.15931761], pet_ssim_loss: [0.26835692],  total_ssim_loss: [0.42767453] total_loss: [0.34862652]
# Epoch: [481],step: [130900], mri_ssim_loss: [0.23488986], pet_ssim_loss: [0.38248521],  total_ssim_loss: [0.61737508] total_loss: [0.51055229]
# Epoch: [481],step: [131000], mri_ssim_loss: [0.16031027], pet_ssim_loss: [0.27240384],  total_ssim_loss: [0.43271410] total_loss: [0.35303468]
# Epoch: [481],step: [131100], mri_ssim_loss: [0.32614338], pet_ssim_loss: [0.41261637],  total_ssim_loss: [0.73875976] total_loss: [0.59719706]
# Epoch: [482],step: [131200], mri_ssim_loss: [0.14424640], pet_ssim_loss: [0.17646760],  total_ssim_loss: [0.32071400] total_loss: [0.26582322]
# Epoch: [482],step: [131300], mri_ssim_loss: [0.37980253], pet_ssim_loss: [0.53555810],  total_ssim_loss: [0.91536063] total_loss: [0.74022126]
# Epoch: [483],step: [131400], mri_ssim_loss: [0.19826615], pet_ssim_loss: [0.31617343],  total_ssim_loss: [0.51443958] total_loss: [0.41882423]
# Epoch: [483],step: [131500], mri_ssim_loss: [0.12049425], pet_ssim_loss: [0.15353096],  total_ssim_loss: [0.27402520] total_loss: [0.22886243]
# Epoch: [483],step: [131600], mri_ssim_loss: [0.57352722], pet_ssim_loss: [0.33330041],  total_ssim_loss: [0.90682763] total_loss: [0.73513609]
# Epoch: [484],step: [131700], mri_ssim_loss: [0.21959400], pet_ssim_loss: [0.26569706],  total_ssim_loss: [0.48529106] total_loss: [0.39467561]
# Epoch: [484],step: [131800], mri_ssim_loss: [0.17977232], pet_ssim_loss: [0.20779377],  total_ssim_loss: [0.38756609] total_loss: [0.31736597]
# Epoch: [484],step: [131900], mri_ssim_loss: [0.18930018], pet_ssim_loss: [0.29609621],  total_ssim_loss: [0.48539639] total_loss: [0.39697438]
# Epoch: [485],step: [132000], mri_ssim_loss: [0.14366227], pet_ssim_loss: [0.20314151],  total_ssim_loss: [0.34680378] total_loss: [0.28726184]
# Epoch: [485],step: [132100], mri_ssim_loss: [0.38080877], pet_ssim_loss: [0.52745342],  total_ssim_loss: [0.90826219] total_loss: [0.73511767]
# Epoch: [486],step: [132200], mri_ssim_loss: [0.17243761], pet_ssim_loss: [0.26472121],  total_ssim_loss: [0.43715882] total_loss: [0.35498592]
# Epoch: [486],step: [132300], mri_ssim_loss: [0.13321763], pet_ssim_loss: [0.16283613],  total_ssim_loss: [0.29605377] total_loss: [0.24509060]
# Epoch: [486],step: [132400], mri_ssim_loss: [0.19117391], pet_ssim_loss: [0.28709966],  total_ssim_loss: [0.47827357] total_loss: [0.38881865]
# Epoch: [487],step: [132500], mri_ssim_loss: [0.27458191], pet_ssim_loss: [0.40243149],  total_ssim_loss: [0.67701340] total_loss: [0.54891270]
# Epoch: [487],step: [132600], mri_ssim_loss: [0.13406992], pet_ssim_loss: [0.15808171],  total_ssim_loss: [0.29215163] total_loss: [0.24464545]
# Epoch: [487],step: [132700], mri_ssim_loss: [0.15927804], pet_ssim_loss: [0.31423664],  total_ssim_loss: [0.47351468] total_loss: [0.38497883]
# Epoch: [488],step: [132800], mri_ssim_loss: [0.22519594], pet_ssim_loss: [0.40686464],  total_ssim_loss: [0.63206059] total_loss: [0.51815963]
# Epoch: [488],step: [132900], mri_ssim_loss: [0.13453192], pet_ssim_loss: [0.27167714],  total_ssim_loss: [0.40620905] total_loss: [0.33066314]
# Epoch: [488],step: [133000], mri_ssim_loss: [0.34896678], pet_ssim_loss: [0.43625319],  total_ssim_loss: [0.78521997] total_loss: [0.63699228]
# Epoch: [489],step: [133100], mri_ssim_loss: [0.14288825], pet_ssim_loss: [0.18806422],  total_ssim_loss: [0.33095247] total_loss: [0.27395216]
# Epoch: [489],step: [133200], mri_ssim_loss: [0.13106054], pet_ssim_loss: [0.28870183],  total_ssim_loss: [0.41976237] total_loss: [0.34198621]
# Epoch: [490],step: [133300], mri_ssim_loss: [0.22052044], pet_ssim_loss: [0.34434086],  total_ssim_loss: [0.56486130] total_loss: [0.45958024]
# Epoch: [490],step: [133400], mri_ssim_loss: [0.12224656], pet_ssim_loss: [0.15572578],  total_ssim_loss: [0.27797234] total_loss: [0.23168276]
# Epoch: [490],step: [133500], mri_ssim_loss: [0.26727718], pet_ssim_loss: [0.47908354],  total_ssim_loss: [0.74636072] total_loss: [0.60395622]
# Epoch: [491],step: [133600], mri_ssim_loss: [0.25855160], pet_ssim_loss: [0.31890756],  total_ssim_loss: [0.57745916] total_loss: [0.46883076]
# Epoch: [491],step: [133700], mri_ssim_loss: [0.22873724], pet_ssim_loss: [0.28453404],  total_ssim_loss: [0.51327127] total_loss: [0.41682822]
# Epoch: [491],step: [133800], mri_ssim_loss: [0.17687410], pet_ssim_loss: [0.27452421],  total_ssim_loss: [0.45139831] total_loss: [0.36909905]
# Epoch: [492],step: [133900], mri_ssim_loss: [0.16637200], pet_ssim_loss: [0.33359879],  total_ssim_loss: [0.49997079] total_loss: [0.41259006]
# Epoch: [492],step: [134000], mri_ssim_loss: [0.12428188], pet_ssim_loss: [0.25257283],  total_ssim_loss: [0.37685472] total_loss: [0.30815932]
# Epoch: [493],step: [134100], mri_ssim_loss: [0.33719403], pet_ssim_loss: [0.44670200],  total_ssim_loss: [0.78389603] total_loss: [0.63412273]
# Epoch: [493],step: [134200], mri_ssim_loss: [0.12196767], pet_ssim_loss: [0.17601651],  total_ssim_loss: [0.29798418] total_loss: [0.24689944]
# Epoch: [493],step: [134300], mri_ssim_loss: [0.48397845], pet_ssim_loss: [0.62517071],  total_ssim_loss: [1.10914922] total_loss: [0.89733469]
# Epoch: [494],step: [134400], mri_ssim_loss: [0.26608503], pet_ssim_loss: [0.50326025],  total_ssim_loss: [0.76934528] total_loss: [0.62749124]
# Epoch: [494],step: [134500], mri_ssim_loss: [0.12458014], pet_ssim_loss: [0.14758539],  total_ssim_loss: [0.27216554] total_loss: [0.22816372]
# Epoch: [494],step: [134600], mri_ssim_loss: [0.22503734], pet_ssim_loss: [0.38471156],  total_ssim_loss: [0.60974890] total_loss: [0.49607235]
# Epoch: [495],step: [134700], mri_ssim_loss: [0.25627488], pet_ssim_loss: [0.39872092],  total_ssim_loss: [0.65499580] total_loss: [0.53813177]
# Epoch: [495],step: [134800], mri_ssim_loss: [0.16044211], pet_ssim_loss: [0.35310870],  total_ssim_loss: [0.51355082] total_loss: [0.41705090]
# Epoch: [495],step: [134900], mri_ssim_loss: [0.39935130], pet_ssim_loss: [0.42416960],  total_ssim_loss: [0.82352090] total_loss: [0.66793734]
# Epoch: [496],step: [135000], mri_ssim_loss: [0.14606112], pet_ssim_loss: [0.19712496],  total_ssim_loss: [0.34318608] total_loss: [0.28356960]
# Epoch: [496],step: [135100], mri_ssim_loss: [0.22689819], pet_ssim_loss: [0.29695404],  total_ssim_loss: [0.52385223] total_loss: [0.42893514]
# Epoch: [497],step: [135200], mri_ssim_loss: [0.45546585], pet_ssim_loss: [0.61072946],  total_ssim_loss: [1.06619525] total_loss: [0.86015713]
# Epoch: [497],step: [135300], mri_ssim_loss: [0.11728281], pet_ssim_loss: [0.16137397],  total_ssim_loss: [0.27865678] total_loss: [0.23153123]
# Epoch: [497],step: [135400], mri_ssim_loss: [0.26840878], pet_ssim_loss: [0.54529399],  total_ssim_loss: [0.81370276] total_loss: [0.65730685]
# Epoch: [498],step: [135500], mri_ssim_loss: [0.28146756], pet_ssim_loss: [0.33405662],  total_ssim_loss: [0.61552417] total_loss: [0.49930763]
# Epoch: [498],step: [135600], mri_ssim_loss: [0.37326735], pet_ssim_loss: [0.49918890],  total_ssim_loss: [0.87245625] total_loss: [0.70762557]
# Epoch: [498],step: [135700], mri_ssim_loss: [0.10171008], pet_ssim_loss: [0.25357771],  total_ssim_loss: [0.35528779] total_loss: [0.28987107]
# Epoch: [499],step: [135800], mri_ssim_loss: [0.21705174], pet_ssim_loss: [0.34057200],  total_ssim_loss: [0.55762374] total_loss: [0.45962849]
# Epoch: [499],step: [135900], mri_ssim_loss: [0.16429633], pet_ssim_loss: [0.23587644],  total_ssim_loss: [0.40017277] total_loss: [0.32847220]
# Epoch: [499],step: [136000], mri_ssim_loss: [0.18253791], pet_ssim_loss: [0.47500634],  total_ssim_loss: [0.65754426] total_loss: [0.53560203]
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\torch\serialization.py:250: UserWarning: Couldn't retrieve source code for container of type DeepFuse. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\torch\serialization.py:250: UserWarning: Couldn't retrieve source code for container of type ConvLayer_DeepFuse. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\torch\serialization.py:250: UserWarning: Couldn't retrieve source code for container of type FusionLayer. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "

# %%
l1 = np.asarray(ep_mri_ssim_loss)
l2 = np.asarray(ep_pet_ssim_loss)
l3 = np.asarray(ep_l2_loss)

# %%
plt.plot(l3)

# %%
plt.plot(l3)
plt.xlabel('epoch')
plt.ylabel('L2 Loss')
plt.title('DeepFuse')
plt.savefig('C:/Users/horan/Desktop/FuseVis/Loss curves/DeepFuse/Loss curves/L2_loss.png', bbox_inches = 'tight', pad_inches = 0, dpi=100)
plt.close()

# %%
h5f = h5py.File('C:/Users/horan/Desktop/FuseVis/Loss curves/DeepFuse/H5 Files/Loss_L2.h5', 'w')
h5f.create_dataset('L2_dataset', data=l3)
h5f.close()

# %%
#load the test input MRI dataset
filenames = os.listdir('C:/Users/horan/Desktop/FuseVis/MRI/')
dataset = os.path.join(os.getcwd(), 'C:/Users/horan/Desktop/FuseVis/MRI/')
data = glob.glob(os.path.join(dataset, "*.gif"))
data = natsort.natsorted(data,reverse=False)
test_mri = np.zeros((len(data), image_width,image_length))
for i in range(len(data)):
    test_mri[i,:,:] =(imageio.imread(data[i]))
    test_mri[i,:,:] =(test_mri[i,:,:] - np.min(test_mri[i,:,:])) / (np.max(test_mri[i,:,:]) - np.min(test_mri[i,:,:]))
    test_mri[i,:,:] = np.float32(test_mri[i,:,:])

# %%
#expand dimension to add the channel
test_mri = np.expand_dims(test_mri,axis=1)
#verify the shape matches the pytorch standard
test_mri.shape
# Out:
# (1, 1, 256, 256)

# %%
#verify the test mri image
#test_mri = test_mri[0,:,:,:]
#test_mri = np.expand_dims(test_mri,axis=0)
plt.imshow(test_mri[0,0,:,:],'gray')
#plt.savefig('MRI.png', bbox_inches = 'tight',pad_inches = 0,dpi=200)

# %%
#convert the MRI Testing data to pytorch tensor
test_mri_tensor = torch.from_numpy(test_mri).float()
print(test_mri_tensor.shape)
test_mri_tensor.requires_grad =True
# Out:
# torch.Size([1, 1, 256, 256])

# %%
#load the test input PET dataset
filenames = os.listdir('C:/Users/horan/Desktop/FuseVis/PET/')
dataset = os.path.join(os.getcwd(), 'C:/Users/horan/Desktop/FuseVis/PET/')
data = glob.glob(os.path.join(dataset, "*.png"))
data = natsort.natsorted(data,reverse=False)
test_pet = np.zeros((len(data), image_width,image_length))
for i in range(len(data)):
    test_pet[i,:,:] =(imageio.imread(data[i]))
    test_pet[i,:,:] =(test_pet[i,:,:] - np.min(test_pet[i,:,:])) / (np.max(test_pet[i,:,:]) - np.min(test_pet[i,:,:]))
    test_pet[i,:,:] = np.float32(test_pet[i,:,:])

# %%
#expand dimension to add the channel
test_pet = np.expand_dims(test_pet,axis=1)
#verify the shape matches the pytorch standard
test_pet.shape
# Out:
# (1, 1, 256, 256)

# %%
#verify the test pet image
plt.imshow(test_pet[0,0,:,:],'gray')
#plt.savefig('PET.png', bbox_inches = 'tight',pad_inches = 0,dpi=200)

# %%
#convert the MRI Testing data to pytorch tensor
test_pet_tensor = torch.from_numpy(test_pet).float()
print(test_pet_tensor.shape)
test_pet_tensor.requires_grad =True
# Out:
# torch.Size([1, 1, 256, 256])

# %%
#load the model
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
cnn =torch.load('C:/Users/horan/Desktop/FuseVis/.ipynb_checkpoints/DeepFuse/checkpoint.pth')
cnn.eval().to(device)
# Out:
# DeepFuse(
#   (layer1): ConvLayer_DeepFuse(
#     (main): Sequential(
#       (0): Conv2d(1, 16, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.01)
#     )
#   )
#   (layer2): ConvLayer_DeepFuse(
#     (main): Sequential(
#       (0): Conv2d(16, 32, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#   )
#   (layer3): FusionLayer()
#   (layer4): ConvLayer_DeepFuse(
#     (main): Sequential(
#       (0): Conv2d(32, 32, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.01)
#     )
#   )
#   (layer5): ConvLayer_DeepFuse(
#     (main): Sequential(
#       (0): Conv2d(32, 16, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.01)
#     )
#   )
#   (layer6): ConvLayer_DeepFuse(
#     (main): Sequential(
#       (0): Conv2d(16, 1, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (1): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): Tanh()
#     )
#   )
# )

# %%
#predicted the fused image
cnn.setInput(test_mri_tensor.to(device), test_pet_tensor.to(device))          # cnn output
fused = cnn.forward()
fused_numpy = fused.data.cpu().numpy()

# %%
fused.shape
# Out:
# torch.Size([1, 1, 256, 256])

# %%
#verify the output image
plt.imshow(fused_numpy[0,0,:,:],'gray')
#plt.savefig('Fused.png', bbox_inches = 'tight',pad_inches = 0,dpi=200)

# %%
imageio.imwrite('C:/Users/horan/Desktop/FuseVis/Fused/DeepFuse/Fused.png',np.uint8(cv2.normalize(fused_numpy[0,0,:,:], None, alpha=0, beta=255, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_32F)))

# %%
#calculate the guidance image for MRI and PET wrt to the fused image
time1 = time.time()
count = 0 
guide_fuse_mri = np.zeros((256,256),dtype=float)
guide_fuse_pet = np.zeros((256,256),dtype=float)

for y_coord in range(0,256):
    for x_coord in range(0,256):
        jacob_fuse_mri = torch.autograd.grad(fused[0,0,y_coord,x_coord], test_mri_tensor, retain_graph=True, create_graph=True)[0]
        jacob_numpy_mri = np.squeeze(jacob_fuse_mri.data.cpu().numpy())  
        guide_fuse_mri[y_coord,x_coord] = jacob_numpy_mri[y_coord,x_coord]
        jacob_fuse_pet = torch.autograd.grad(fused[0,0,y_coord,x_coord], test_pet_tensor, retain_graph=True, create_graph=True)[0]
        jacob_numpy_pet = np.squeeze(jacob_fuse_pet.data.cpu().numpy())  
        guide_fuse_pet[y_coord,x_coord] = jacob_numpy_pet[y_coord,x_coord]
        count += 1
        if count % 1000 == 0:
            print('Count is %d' %count)
time2 = time.time()
print('Time taken to compute is %d seconds' %(time2-time1))
# Out:
# Count is 1000
# Count is 2000
# Count is 3000
# Count is 4000
# Count is 5000
# Count is 6000
# Count is 7000
# Count is 8000
# Count is 9000
# Count is 10000
# Count is 11000
# Count is 12000
# Count is 13000
# Count is 14000
# Count is 15000
# Count is 16000
# Count is 17000
# Count is 18000
# Count is 19000
# Count is 20000
# Count is 21000
# Count is 22000
# Count is 23000
# Count is 24000
# Count is 25000
# Count is 26000
# Count is 27000
# Count is 28000
# Count is 29000
# Count is 30000
# Count is 31000
# Count is 32000
# Count is 33000
# Count is 34000
# Count is 35000
# Count is 36000
# Count is 37000
# Count is 38000
# Count is 39000
# Count is 40000
# Count is 41000
# Count is 42000
# Count is 43000
# Count is 44000
# Count is 45000
# Count is 46000
# Count is 47000
# Count is 48000
# Count is 49000
# Count is 50000
# Count is 51000
# Count is 52000
# Count is 53000
# Count is 54000
# Count is 55000
# Count is 56000
# Count is 57000
# Count is 58000
# Count is 59000
# Count is 60000
# Count is 61000
# Count is 62000
# Count is 63000
# Count is 64000
# Count is 65000
# Time taken to compute is 1787 seconds

# %%
h5f = h5py.File('C:/Users/horan/Desktop/FuseVis/Guidance images/DeepFuse/H5 Files/Jacobian_PET.h5', 'w')
h5f.create_dataset('Jacob_PET_dataset', data=guide_fuse_pet)
h5f.close()

# %%
plt.imshow(guide_fuse_mri,cmap='viridis')
plt.colorbar()
plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/DeepFuse/Resultant images/Guide_Fused_MRI_DPI.png', bbox_inches = 'tight',pad_inches = 0,dpi=200)

# %%
#h5f = h5py.File('C:/Users/horan/Desktop/FuseVis/Guidance images/DeepFuse/H5 Files/Jacobian_PET.h5', 'w')
#h5f.create_dataset('Jacob_PET_dataset', data=guide_fuse_pet)
#h5f.close()

# %%
plt.imshow(guide_fuse_pet,cmap='viridis')
plt.colorbar()
plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/DeepFuse/Resultant images/Guide_Fused_PET_DPI.png', bbox_inches = 'tight',pad_inches = 0,dpi=200)

# %%
#define overlay images
fused_RGB = np.zeros((256,256,3),dtype=float)
mri_RGB   = np.zeros((256,256,3),dtype=float)
pet_RGB   = np.zeros((256,256,3),dtype=float)

# %%
fused_RGB[:,:,0]  = guide_fuse_mri 
fused_RGB[:,:,1]  = guide_fuse_pet 
fused_RGB[:,:,2]  = fused_numpy[0,0,:,:]

# %%
plt.imshow(fused_RGB)
plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/DeepFuse/Resultant images/Fused_RGB_DPI.png', bbox_inches = 'tight',pad_inches = 0,dpi=200)

# %%
mri_RGB[:,:,0]  = guide_fuse_mri
mri_RGB[:,:,1]  = guide_fuse_pet 
mri_RGB[:,:,2]  = test_mri[0,0,:,:]

# %%
plt.imshow(mri_RGB)
plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/DeepFuse/Resultant images/MRI_RGB_DPI.png', bbox_inches = 'tight',pad_inches = 0,dpi=200)

# %%
pet_RGB[:,:,0]  = guide_fuse_mri
pet_RGB[:,:,1]  = guide_fuse_pet 
pet_RGB[:,:,2]  = test_pet[0,0,:,:]

# %%
plt.imshow(pet_RGB)
plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/DeepFuse/Resultant images/PET_RGB_DPI.png', bbox_inches = 'tight',pad_inches = 0,dpi=200)

# %%
#define the window
root = Tk()  
root.title('Visualisation of fusion networks')
root.configure(background='white')


#Label the images
#fontStyle = tkFont.Font(family="Lucida Grande", size=15)
#w1 = tk.Label(root, bg='white', font=fontStyle, text="Fused Image")
#w1.grid(row=0, column=1)
#w1.pack()

#define the frame
canvasframe = Frame(root)  # define Input and output frame
buttonframe = Frame(root)  # define button frame
canvasframe.pack()  # pack the Input and Output frame
buttonframe.pack()  # pack the button frame


#define the canvas
canvas = Canvas(canvasframe, width=1800, height=920, bg = 'white')
canvas.grid(row=0, column=0)

#Insert fused image to the canvas
img_fused = ImageTk.PhotoImage(file ="C:/Users/horan/Desktop/FuseVis/Fused/DeepFuse/Fused.png") # load the image
canvas.create_image(0, 0, image=img_fused, anchor=NW)

#Insert MRI image to the canvas
img_mri = ImageTk.PhotoImage(file ="C:/Users/horan/Desktop/FuseVis/MRI/MRI.gif") # load the image
canvas.create_image(600, 0, image=img_mri, anchor=NW)

#Insert PET image to the canvas
img_pet = ImageTk.PhotoImage(file ="C:/Users/horan/Desktop/FuseVis/PET/3.png") # load the image
canvas.create_image(1200, 0, image=img_pet, anchor=NW)

def start_mouseover():  # function called when user clicks the button 
    # link the function to the left-mouse-click event
    canvas.bind("<B1-Motion>", Coordinates)

def Coordinates(event): # function called when left-mouse-button is clicked with a mouseover
    x_coord = event.x  # save x and y coordinates selected by the user   
    y_coord = event.y
    print('mouse position is at' + '(' + str(y_coord) + ',' + str(x_coord) + ')', end='\r')
    #display the output MRI Jacobian image
    #img_MR_out = ImageTk.PhotoImage(file ='C:/Users/cgvadmin/Desktop/FuseVis/Fused_MRI/im_' + str(y_coord) + '_' + str(x_coord) + '.png') # load the image
    jacobian_fuse_mri = torch.autograd.grad(fused[0,0,y_coord,x_coord], test_mri_tensor, retain_graph=True, create_graph=True)[0]
    jacobian_fuse_pet = torch.autograd.grad(fused[0,0,y_coord,x_coord], test_pet_tensor, retain_graph=True, create_graph=True)[0]
    
    jacob_val_mri = np.squeeze(jacobian_fuse_mri.data.cpu().numpy())    
    jacob_val_pet = np.squeeze(jacobian_fuse_pet.data.cpu().numpy())
    
    x_mri = np.asarray(np.where(np.any(jacob_val_mri, axis = 0)))
    y_mri = np.asarray(np.where(np.any(jacob_val_mri, axis = 1)))
    minx_mri, maxx_mri, miny_mri, maxy_mri = np.min(x_mri), np.max(x_mri), np.min(y_mri), np.max(y_mri)  #return min and max coordinates
    zoom_im_mri = jacob_val_mri[miny_mri:maxy_mri,minx_mri:maxx_mri] 
    
    x_pet = np.asarray(np.where(np.any(jacob_val_pet, axis = 0)))
    y_pet = np.asarray(np.where(np.any(jacob_val_pet, axis = 1)))
    minx_pet, maxx_pet, miny_pet, maxy_pet = np.min(x_pet), np.max(x_pet), np.min(y_pet), np.max(y_pet)  #return min and max coordinates
    zoom_im_pet = jacob_val_pet[miny_pet:maxy_pet,minx_pet:maxx_pet] 
    
    plt.imshow(fused_numpy[0,0,miny_mri:maxy_mri,minx_mri:maxx_mri], cmap = 'gray', aspect ='equal')
    plt.title('Zoom Fused')
    plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/DeepFuse/Resultant images/Zoom_Fused.png', bbox_inches = 'tight',pad_inches = 0)
    plt.close()
    im_out11 = ImageTk.PhotoImage(file ='C:/Users/horan/Desktop/FuseVis/Guidance images/DeepFuse/Resultant images/Zoom_Fused.png')
    canvas.create_image(300,5,image=im_out11,anchor=NW)
    canvas.image11 = im_out11
    plt.tight_layout()
    
    plt.imshow(test_mri[0,0,miny_mri:maxy_mri,minx_mri:maxx_mri], cmap = 'gray', aspect ='equal')
    plt.title('Zoom MRI')
    plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/DeepFuse/Resultant images/Zoom_MRI.png', bbox_inches = 'tight',pad_inches = 0)
    plt.close()
    im_out12 = ImageTk.PhotoImage(file ='C:/Users/horan/Desktop/FuseVis/Guidance images/DeepFuse/Resultant images/Zoom_MRI.png')
    canvas.create_image(900,5,image=im_out12,anchor=NW)
    canvas.image12 = im_out12
    plt.tight_layout()
    
    plt.imshow(test_pet[0,0,miny_mri:maxy_mri,minx_mri:maxx_mri], cmap = 'gray', aspect ='equal')
    plt.title('Zoom PET')
    plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/DeepFuse/Resultant images/Zoom_PET.png', bbox_inches = 'tight',pad_inches = 0)
    plt.close()
    im_out13 = ImageTk.PhotoImage(file ='C:/Users/horan/Desktop/FuseVis/Guidance images/DeepFuse/Resultant images/Zoom_PET.png')
    canvas.create_image(1500,5,image=im_out13,anchor=NW)
    canvas.image13 = im_out13
    plt.tight_layout()
    
    plt.imshow(jacob_val_mri,cmap='viridis', aspect ='equal')
    plt.title('Jacobian (Fused wrt MRI)')
    plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/DeepFuse/Resultant images/Jacob_Fused_MRI.png', bbox_inches = 'tight',pad_inches = 0)
    plt.close()
    im_out1 = ImageTk.PhotoImage(file ='C:/Users/horan/Desktop/FuseVis/Guidance images/DeepFuse/Resultant images/Jacob_Fused_MRI.png')
    canvas.create_image(40,320,image=im_out1,anchor=NW)
    canvas.image1 = im_out1
    #plt.tight_layout()
    
    #f.add_subplot(1,5,2)
    plt.imshow(zoom_im_mri,cmap='viridis',aspect ='equal')
    plt.title('Zoom Jacobian (Fused wrt MRI)')
    plt.colorbar()
    plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/DeepFuse/Resultant images/Zoom_Jacob_MRI.png', bbox_inches = 'tight',pad_inches = 0)
    plt.close()
    im_out2 = ImageTk.PhotoImage(file ='C:/Users/horan/Desktop/FuseVis/Guidance images/DeepFuse/Resultant images/Zoom_Jacob_MRI.png')
    canvas.create_image(380,320,image=im_out2,anchor=NW)
    canvas.image2 = im_out2
    
    #f.add_subplot(1,5,3)
    plt.xlim(0,0.7)
    plt.ylim(0,0.7)
    plt.plot(jacob_val_mri[y_coord,x_coord],jacob_val_pet[y_coord,x_coord],'-ro')
    plt.xlabel('MRI pixel score (Fused wrt MRI)')
    plt.ylabel('PET pixel score (Fused wrt PET)')
    plt.title('Mouse position at: (' + str(y_coord) + ',' + str(x_coord) + ')')
    plt.gca().set_aspect('equal', adjustable='box')
    plt.draw()
    plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/DeepFuse/Resultant images/Pixel_intensities.png', bbox_inches = 'tight',pad_inches = 0.1)
    plt.close()
    im_out3 = ImageTk.PhotoImage(file ='C:/Users/horan/Desktop/FuseVis/Guidance images/DeepFuse/Resultant images/Pixel_intensities.png')
    canvas.create_image(750,320,image=im_out3,anchor=NW)
    canvas.image3 = im_out3
    
    #f.add_subplot(1,5,4)
    plt.imshow(jacob_val_pet,cmap='viridis',aspect ='equal')
    plt.title('Jacobian (Fused wrt PET)')
    plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/DeepFuse/Resultant images/Jacob_Fused_PET.png', bbox_inches = 'tight',pad_inches = 0)
    plt.close()
    im_out4 = ImageTk.PhotoImage(file ='C:/Users/horan/Desktop/FuseVis/Guidance images/DeepFuse/Resultant images/Jacob_Fused_PET.png')
    canvas.create_image(1110,320,image=im_out4,anchor=NW)
    canvas.image4 = im_out4
    #plt.tight_layout()
    
    #f.add_subplot(1,5,5)
    plt.imshow(zoom_im_pet,cmap='viridis',aspect ='equal')
    plt.title('Zoomed Jacobian (Fused wrt PET)')
    plt.colorbar()
    plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/DeepFuse/Resultant images/Zoom_Jacob_PET.png', bbox_inches = 'tight',pad_inches = 0)
    plt.close()
    im_out5 = ImageTk.PhotoImage(file ='C:/Users/horan/Desktop/FuseVis/Guidance images/DeepFuse/Resultant images/Zoom_Jacob_PET.png')
    canvas.create_image(1450,320,image=im_out5,anchor=NW)
    canvas.image5 = im_out5

    plt.imshow(guide_fuse_mri,cmap='viridis')
    plt.title('Guidance (Fused wrt MRI)')
    plt.colorbar()
    plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/DeepFuse/Resultant images/Guide_Fused_MRI.png', bbox_inches = 'tight',pad_inches = 0)
    plt.close()
    im_out6 = ImageTk.PhotoImage(file ='C:/Users/horan/Desktop/FuseVis/Guidance images/DeepFuse/Resultant images/Guide_Fused_MRI.png')
    canvas.create_image(100,650,image=im_out6,anchor=NW)
    canvas.image6 = im_out6
    
    plt.imshow(fused_RGB)
    plt.title('R=I1 G=I2 B=Fused')
    plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/DeepFuse/Resultant images/Fused_RGB.png', bbox_inches = 'tight',pad_inches = 0)
    plt.close()
    im_out8 = ImageTk.PhotoImage(file ='C:/Users/horan/Desktop/FuseVis/Guidance images/DeepFuse/Resultant images/Fused_RGB.png')
    canvas.create_image(420,650,image=im_out8,anchor=NW)
    canvas.image8 = im_out8
    
    plt.imshow(mri_RGB)
    plt.title('R=I1 G=I2 B=MRI')
    plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/DeepFuse/Resultant images/MRI_RGB.png', bbox_inches = 'tight',pad_inches = 0)
    plt.close()
    im_out9 = ImageTk.PhotoImage(file ='C:/Users/horan/Desktop/FuseVis/Guidance images/DeepFuse/Resultant images/MRI_RGB.png')
    canvas.create_image(740,650,image=im_out9,anchor=NW)
    canvas.image9 = im_out9
    
    plt.imshow(pet_RGB)
    plt.title('R=I1 G=I2 B=PET')
    plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/DeepFuse/Resultant images/PET_RGB.png', bbox_inches = 'tight',pad_inches = 0)
    plt.close()
    im_out10 = ImageTk.PhotoImage(file ='C:/Users/horan/Desktop/FuseVis/Guidance images/DeepFuse/Resultant images/PET_RGB.png')
    canvas.create_image(1100,650,image=im_out10,anchor=NW)
    canvas.image10 = im_out10
    
    plt.imshow(guide_fuse_pet,cmap='viridis')
    plt.title('Guidance (Fused wrt PET)')
    plt.colorbar()
    plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/DeepFuse/Resultant images/Guide_Fused_PET.png', bbox_inches = 'tight',pad_inches = 0)
    plt.close()
    im_out7 = ImageTk.PhotoImage(file ='C:/Users/horan/Desktop/FuseVis/Guidance images/DeepFuse/Resultant images/Guide_Fused_PET.png')
    canvas.create_image(1400,650,image=im_out7,anchor=NW)
    canvas.image7 = im_out7
    
    radius = 5
    i = canvas.create_oval(x_coord-radius, y_coord-radius, x_coord+radius, y_coord+radius, fill = 'red')
    canvas.after(20,canvas.delete,i)

# insert button to the middleframe and link it to "Start Mouseover"
button_start_mouseover = Button(buttonframe, text="Start Mouseover",command=start_mouseover)
button_start_mouseover.grid(row=1, column=0, pady=0)


root.mainloop()  #keep the GUI open
