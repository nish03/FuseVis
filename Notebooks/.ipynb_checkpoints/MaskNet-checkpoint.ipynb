# %% [markdown]
# # This is the pytorch implementation of the deep learning model proposed in the paper 'A Deep Model for Multi-Focus Image Fusion Based on Gradients and Connected Regions'

# %%
#Import packages
import time
import torch.nn as nn
import torch
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import torchvision.datasets as datasets
import numpy as np
from torchvision import transforms
from torch.autograd import Variable
from PIL import Image
import torchvision.transforms.functional as TF
from torchvision.models.vgg import vgg19
import torch.nn as nn
import torch.nn.functional as F
import torch
from skimage import img_as_ubyte
import torch.nn as nn
import torch.utils.data as Data
import torchvision      # dataset
import matplotlib.pyplot as plt
import scipy
import numpy as np
import argparse
import glob
import imageio
from skimage import color
import numpy
import natsort
import scipy
from pytorch_msssim import ssim, ms_ssim, SSIM, MS_SSIM
import pprint
from scipy.ndimage import correlate
from scipy.ndimage.filters import gaussian_gradient_magnitude
import torchvision.datasets as dset
import torch.utils.data as data
import os
import os.path
from tkinter import *
import tkinter as tk
import tkinter.font as tkFont
from PIL import ImageTk, Image
import pylab
import cv2
import h5py
from mpl_toolkits.axes_grid1 import make_axes_locatable
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(torch.cuda.get_device_properties(0).total_memory)
# Out:
# 11811160064

# %%
import multiprocessing
multiprocessing.cpu_count()
# Out:
# 12

# %%
#define the hyperparameters
image_length = 256
image_width  = 256
mr_channels  = 1
gray_channels = 1
pet_channels = 4    
rgb_channels = 3     
batch_size   = 1
EPOCH = 100
learning_rate = 0.0002

# %%
#load the train mri data
filenames = os.listdir('C:/Users/horan/Desktop/FuseVis/Training/MRI')
dataset = os.path.join(os.getcwd(), 'C:/Users/horan/Desktop/FuseVis/Training/MRI')
data = glob.glob(os.path.join(dataset, "*.gif"))
data = natsort.natsorted(data,reverse=False)
train_mri = np.zeros((len(data), image_width,image_length))
for i in range(len(data)):
    train_mri[i,:,:] =(imageio.imread(data[i]))
    train_mri[i,:,:] =(train_mri[i,:,:] - np.min(train_mri[i,:,:])) / (np.max(train_mri[i,:,:]) - np.min(train_mri[i,:,:]))
    train_mri[i,:,:] = np.float32(train_mri[i,:,:])

# %%
#expand dimension to add the channel
train_mri = np.expand_dims(train_mri,axis=1)

# %%
#verify the shape matches the pytorch standard
train_mri.shape
# Out:
# (272, 1, 256, 256)

# %%
#convert the MRI training data to pytorch tensor
train_mri_tensor = torch.from_numpy(train_mri).float()
train_mri_tensor.shape
# Out:
# torch.Size([272, 1, 256, 256])

# %%
#load the train pet data
filenames = os.listdir('C:/Users/horan/Desktop/FuseVis/Training/PET')
dataset = os.path.join(os.getcwd(), 'C:/Users/horan/Desktop/FuseVis/Training/PET')
data = glob.glob(os.path.join(dataset, "*.gif"))
data = natsort.natsorted(data,reverse=False)
train_other = np.zeros((len(data),image_width,image_length,pet_channels),dtype=float)
train_pet = np.zeros((len(data),image_width,image_length),dtype=float)
for i in range(len(data)):
    train_other[i,:,:,:] =(imageio.imread(data[i]))
    train_pet[i,:,:] = 0.2989 * train_other[i,:,:,0] + 0.5870 *  train_other[i,:,:,1]  + 0.1140 * train_other[i,:,:,2]
    train_pet[i,:,:] =(train_pet[i,:,:] - np.min(train_pet[i,:,:])) / (np.max(train_pet[i,:,:]) - np.min(train_pet[i,:,:]))

# %%
#expand the dimension to add the channel
train_pet = np.expand_dims(train_pet,axis=1)

# %%
#verify the shape matches the pytorch standard
train_pet.shape
# Out:
# (272, 1, 256, 256)

# %%
#convert the PET training data to pytorch tensor
train_pet_tensor = torch.from_numpy(train_pet).float()
train_pet_tensor.shape
# Out:
# torch.Size([272, 1, 256, 256])

# %%
#define the Mask-Net network
class MaskNet(nn.Module):
    def  __init__(self):
        super(MaskNet, self).__init__()
        #####encoder layer 1#####
        self.layer1 = nn.Sequential(  #input shape (,2,256,256)
                         nn.Conv2d(in_channels=2, out_channels=48, kernel_size=3, stride=1, padding=1),
                         nn.BatchNorm2d(48),
                         nn.LeakyReLU(0.2,inplace=True)) #output shape (,48,256,256)   
        #####encoder layer 2#####
        self.layer2 = nn.Sequential(  #input shape (,48,256,256)
                         nn.Conv2d(in_channels = 48, out_channels = 48, kernel_size  = 3, stride= 1, padding = 1),
                         nn.BatchNorm2d(48),
                         nn.LeakyReLU(0.2,inplace=True))  #output shape (,48,256,256)
        #####encoder layer 3#####
        self.layer3 = nn.Sequential(  #input shape (,96,256,256)
                         nn.Conv2d(in_channels = 96, out_channels = 48, kernel_size  = 3, stride= 1, padding = 1),
                         nn.BatchNorm2d(48),
                         nn.LeakyReLU(0.2,inplace=True))  #output shape (,48,256,256)     
        #####encoder layer 4#####
        self.layer4 = nn.Sequential(  #input shape (,144,256,256)
                         nn.Conv2d(in_channels = 144, out_channels = 48, kernel_size  = 3, stride= 1, padding = 1),
                         nn.BatchNorm2d(48),
                         nn.LeakyReLU(0.2,inplace=True))  #output shape (,48,256,256) 
        #####decoder layer 1#####
        self.layer5 = nn.Sequential(  #input shape (,192,256,256)
                         nn.Conv2d(in_channels = 192, out_channels = 192, kernel_size  = 3, stride= 1, padding = 1),
                         nn.BatchNorm2d(192),
                         nn.LeakyReLU(0.2,inplace=True))  #output shape (,192,256,256)    
        #####decoder layer 2#####
        self.layer6 = nn.Sequential(  #input shape (,192,256,256)
                         nn.Conv2d(in_channels = 192, out_channels = 128, kernel_size  = 3, stride= 1, padding = 1),
                         nn.BatchNorm2d(128),
                         nn.LeakyReLU(0.2,inplace=True))  #output shape (,128,256,256)    
        #####decoder layer 3#####
        self.layer7 = nn.Sequential(  #input shape (,128,256,256)
                         nn.Conv2d(in_channels = 128, out_channels = 64, kernel_size  = 3, stride= 1, padding = 1),
                         nn.BatchNorm2d(64),
                         nn.LeakyReLU(0.2,inplace=True))  #output shape (,64,256,256)  
        #####decoder layer 4#####
        self.layer8 = nn.Sequential(  #input shape (,64,256,256)
                         nn.Conv2d(in_channels = 64, out_channels = 1, kernel_size  = 3, stride= 1, padding = 1),
                         nn.BatchNorm2d(1),
                         nn.LeakyReLU(0.2,inplace=True))  #output shape (,1,256,256)          
 
    def forward(self, x, y):
        #encoder layer 1
        en1 = self.layer1(torch.cat((x,y),dim=1))
        #encoder layer 2
        en2 = self.layer2(en1)
        #concat layer 1
        concat1 = torch.cat((en1,en2),dim=1)
        #encoder layer 3
        en3 = self.layer3(concat1)
        #concat layer 2
        concat2 = torch.cat((concat1,en3),dim=1)
        #encoder layer 4
        en4 = self.layer4(concat2)
        #concat layer 3
        concat3 = torch.cat((concat2,en4),dim=1)
        #decoder layer 1
        dec1 = self.layer5(concat3)
        #decoder layer 2
        dec2 = self.layer6(dec1)
        #decoder layer 3
        dec3 = self.layer7(dec2)
        #decoder layer 4
        dec4 = self.layer8(dec3)
        #tanh layer
        fused = torch.tanh(dec4)      
        return fused
        #execute the network

cnn = MaskNet().to(device)
cnn = cnn.float()
print(cnn)
# Out:
# MaskNet(
#   (layer1): Sequential(
#     (0): Conv2d(2, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.2, inplace)
#   )
#   (layer2): Sequential(
#     (0): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.2, inplace)
#   )
#   (layer3): Sequential(
#     (0): Conv2d(96, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.2, inplace)
#   )
#   (layer4): Sequential(
#     (0): Conv2d(144, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.2, inplace)
#   )
#   (layer5): Sequential(
#     (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.2, inplace)
#   )
#   (layer6): Sequential(
#     (0): Conv2d(192, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.2, inplace)
#   )
#   (layer7): Sequential(
#     (0): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.2, inplace)
#   )
#   (layer8): Sequential(
#     (0): Conv2d(64, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.2, inplace)
#   )
# )

# %%
#define the optimizers and loss functions 
optimizer = torch.optim.Adam(cnn.parameters(), lr=learning_rate)   #optimize all cnn parameters
MSE_loss   = nn.MSELoss()                                           #MSEloss

# %%
# perform the training
counter = 0
start_time = time.time()
lamda = 1
ep_ssim_mri_loss = []
ep_ssim_pet_loss = []
for epoch in range(EPOCH):
    ssim_mri_Loss = []
    ssim_pet_Loss   = []
    #run batch images
    batch_idxs = 272 // batch_size
    for idx in range(0, batch_idxs):
        #reconstruct mri
        b_x = train_mri_tensor[idx*batch_size : (idx+1)*batch_size,:,:,:].to(device)
        b_y = train_pet_tensor[idx*batch_size : (idx+1)*batch_size,:,:,:].to(device)
        counter += 1
        #encoder
        output = cnn(b_x,b_y) 
        #loss        
        ssim_mri_loss = 1 - ssim(output, b_x,data_range=1)
        ssim_pet_loss = 1 - ssim(output, b_y,data_range=1)
        loss_total = ssim_mri_loss + ssim_pet_loss
        optimizer.zero_grad()              # clear gradients for this training step
        loss_total.backward()              # backpropagation, compute gradients
        optimizer.step()                   # apply gradients
                
        ssim_mri_Loss.append(ssim_mri_loss.item())
        ssim_pet_Loss.append(ssim_pet_loss.item())
        
        if counter % 100 == 0:
            print("Epoch: [%2d],step: [%2d], ssim_mri_loss: [%.8f], ssim_pet_loss: [%.8f], total_loss: [%.8f]" 
                   %(epoch, counter, ssim_mri_loss, ssim_pet_loss, loss_total))
    
    av_ssim_mri_loss = np.average(ssim_mri_Loss)
    ep_ssim_mri_loss.append(av_ssim_mri_loss)
    
    av_ssim_pet_loss = np.average(ssim_pet_Loss)
    ep_ssim_pet_loss.append(av_ssim_pet_loss)
    
    if(epoch == EPOCH -1):
        #Save a checkpoint
        torch.save(cnn, 'C:/Users/horan/Desktop/FuseVis/.ipynb_checkpoints/MaskNet/checkpoint.pth')
# Out:
# Epoch: [ 0],step: [100], ssim_mri_loss: [0.76242858], ssim_pet_loss: [0.84742671], total_loss: [1.60985529]
# Epoch: [ 0],step: [200], ssim_mri_loss: [0.62235236], ssim_pet_loss: [0.84575826], total_loss: [1.46811056]
# Epoch: [ 1],step: [300], ssim_mri_loss: [0.31582934], ssim_pet_loss: [0.46395159], total_loss: [0.77978092]
# Epoch: [ 1],step: [400], ssim_mri_loss: [0.85793459], ssim_pet_loss: [0.86844409], total_loss: [1.72637868]
# Epoch: [ 1],step: [500], ssim_mri_loss: [0.72362995], ssim_pet_loss: [0.73702627], total_loss: [1.46065617]
# Epoch: [ 2],step: [600], ssim_mri_loss: [0.57293594], ssim_pet_loss: [0.79068565], total_loss: [1.36362159]
# Epoch: [ 2],step: [700], ssim_mri_loss: [0.73962855], ssim_pet_loss: [0.71527791], total_loss: [1.45490646]
# Epoch: [ 2],step: [800], ssim_mri_loss: [0.77601725], ssim_pet_loss: [0.76567084], total_loss: [1.54168808]
# Epoch: [ 3],step: [900], ssim_mri_loss: [0.73561585], ssim_pet_loss: [0.87053895], total_loss: [1.60615480]
# Epoch: [ 3],step: [1000], ssim_mri_loss: [0.56440741], ssim_pet_loss: [0.72059995], total_loss: [1.28500736]
# Epoch: [ 4],step: [1100], ssim_mri_loss: [0.75623226], ssim_pet_loss: [0.73577660], total_loss: [1.49200892]
# Epoch: [ 4],step: [1200], ssim_mri_loss: [0.78110462], ssim_pet_loss: [0.81454110], total_loss: [1.59564567]
# Epoch: [ 4],step: [1300], ssim_mri_loss: [0.70558560], ssim_pet_loss: [0.72380233], total_loss: [1.42938793]
# Epoch: [ 5],step: [1400], ssim_mri_loss: [0.57239205], ssim_pet_loss: [0.66826630], total_loss: [1.24065828]
# Epoch: [ 5],step: [1500], ssim_mri_loss: [0.80657887], ssim_pet_loss: [0.89091194], total_loss: [1.69749081]
# Epoch: [ 5],step: [1600], ssim_mri_loss: [0.62720656], ssim_pet_loss: [0.74723887], total_loss: [1.37444544]
# Epoch: [ 6],step: [1700], ssim_mri_loss: [0.61691970], ssim_pet_loss: [0.78054595], total_loss: [1.39746571]
# Epoch: [ 6],step: [1800], ssim_mri_loss: [0.67703772], ssim_pet_loss: [0.77171677], total_loss: [1.44875455]
# Epoch: [ 6],step: [1900], ssim_mri_loss: [0.63550711], ssim_pet_loss: [0.77445424], total_loss: [1.40996134]
# Epoch: [ 7],step: [2000], ssim_mri_loss: [0.21247756], ssim_pet_loss: [0.30338687], total_loss: [0.51586443]
# Epoch: [ 7],step: [2100], ssim_mri_loss: [0.40674889], ssim_pet_loss: [0.56276923], total_loss: [0.96951813]
# Epoch: [ 8],step: [2200], ssim_mri_loss: [0.56777620], ssim_pet_loss: [0.82866323], total_loss: [1.39643943]
# Epoch: [ 8],step: [2300], ssim_mri_loss: [0.18970102], ssim_pet_loss: [0.29334700], total_loss: [0.48304802]
# Epoch: [ 8],step: [2400], ssim_mri_loss: [0.86740279], ssim_pet_loss: [0.59538680], total_loss: [1.46278954]
# Epoch: [ 9],step: [2500], ssim_mri_loss: [0.14615166], ssim_pet_loss: [0.43919480], total_loss: [0.58534646]
# Epoch: [ 9],step: [2600], ssim_mri_loss: [0.38777274], ssim_pet_loss: [0.42320669], total_loss: [0.81097943]
# Epoch: [ 9],step: [2700], ssim_mri_loss: [0.26453096], ssim_pet_loss: [0.40125573], total_loss: [0.66578668]
# Epoch: [10],step: [2800], ssim_mri_loss: [0.16305375], ssim_pet_loss: [0.28408247], total_loss: [0.44713622]
# Epoch: [10],step: [2900], ssim_mri_loss: [0.48361456], ssim_pet_loss: [0.63817394], total_loss: [1.12178850]
# Epoch: [11],step: [3000], ssim_mri_loss: [0.41827291], ssim_pet_loss: [0.55415499], total_loss: [0.97242790]
# Epoch: [11],step: [3100], ssim_mri_loss: [0.12751025], ssim_pet_loss: [0.22196281], total_loss: [0.34947306]
# Epoch: [11],step: [3200], ssim_mri_loss: [0.32336026], ssim_pet_loss: [0.47704244], total_loss: [0.80040270]
# Epoch: [12],step: [3300], ssim_mri_loss: [0.33519214], ssim_pet_loss: [0.55360484], total_loss: [0.88879699]
# Epoch: [12],step: [3400], ssim_mri_loss: [0.09572524], ssim_pet_loss: [0.16326255], total_loss: [0.25898778]
# Epoch: [12],step: [3500], ssim_mri_loss: [0.27138281], ssim_pet_loss: [0.35351783], total_loss: [0.62490064]
# Epoch: [13],step: [3600], ssim_mri_loss: [0.30322254], ssim_pet_loss: [0.52037263], total_loss: [0.82359517]
# Epoch: [13],step: [3700], ssim_mri_loss: [0.20744723], ssim_pet_loss: [0.34850562], total_loss: [0.55595285]
# Epoch: [13],step: [3800], ssim_mri_loss: [0.38388485], ssim_pet_loss: [0.51312757], total_loss: [0.89701241]
# Epoch: [14],step: [3900], ssim_mri_loss: [0.14206660], ssim_pet_loss: [0.25955707], total_loss: [0.40162367]
# Epoch: [14],step: [4000], ssim_mri_loss: [0.22082865], ssim_pet_loss: [0.36511463], total_loss: [0.58594328]
# Epoch: [15],step: [4100], ssim_mri_loss: [0.25334936], ssim_pet_loss: [0.51914877], total_loss: [0.77249813]
# Epoch: [15],step: [4200], ssim_mri_loss: [0.09699774], ssim_pet_loss: [0.19638813], total_loss: [0.29338586]
# Epoch: [15],step: [4300], ssim_mri_loss: [0.75850224], ssim_pet_loss: [0.56821990], total_loss: [1.32672215]
# Epoch: [16],step: [4400], ssim_mri_loss: [0.18008125], ssim_pet_loss: [0.57891273], total_loss: [0.75899398]
# Epoch: [16],step: [4500], ssim_mri_loss: [0.21446079], ssim_pet_loss: [0.44280469], total_loss: [0.65726548]
# Epoch: [16],step: [4600], ssim_mri_loss: [0.17083538], ssim_pet_loss: [0.36299944], total_loss: [0.53383482]
# Epoch: [17],step: [4700], ssim_mri_loss: [0.20902741], ssim_pet_loss: [0.44285768], total_loss: [0.65188509]
# Epoch: [17],step: [4800], ssim_mri_loss: [0.32466269], ssim_pet_loss: [0.52891439], total_loss: [0.85357708]
# Epoch: [26],step: [7300], ssim_mri_loss: [0.41982341], ssim_pet_loss: [0.61166120], total_loss: [1.03148460]
# Epoch: [27],step: [7400], ssim_mri_loss: [0.33980721], ssim_pet_loss: [0.52686125], total_loss: [0.86666846]
# Epoch: [27],step: [7500], ssim_mri_loss: [0.13920856], ssim_pet_loss: [0.40296036], total_loss: [0.54216892]
# Epoch: [27],step: [7600], ssim_mri_loss: [0.19687420], ssim_pet_loss: [0.42465544], total_loss: [0.62152964]
# Epoch: [28],step: [7700], ssim_mri_loss: [0.13140434], ssim_pet_loss: [0.28104359], total_loss: [0.41244793]
# Epoch: [28],step: [7800], ssim_mri_loss: [0.24929428], ssim_pet_loss: [0.45151538], total_loss: [0.70080966]
# Epoch: [29],step: [7900], ssim_mri_loss: [0.11289299], ssim_pet_loss: [0.31234396], total_loss: [0.42523694]
# Epoch: [29],step: [8000], ssim_mri_loss: [0.08712125], ssim_pet_loss: [0.20735520], total_loss: [0.29447645]
# Epoch: [29],step: [8100], ssim_mri_loss: [0.13644356], ssim_pet_loss: [0.35415250], total_loss: [0.49059606]
# Epoch: [30],step: [8200], ssim_mri_loss: [0.18556362], ssim_pet_loss: [0.53305519], total_loss: [0.71861881]
# Epoch: [30],step: [8300], ssim_mri_loss: [0.04986328], ssim_pet_loss: [0.14119345], total_loss: [0.19105673]
# Epoch: [30],step: [8400], ssim_mri_loss: [0.18801636], ssim_pet_loss: [0.32002956], total_loss: [0.50804591]
# Epoch: [31],step: [8500], ssim_mri_loss: [0.25921732], ssim_pet_loss: [0.47147381], total_loss: [0.73069113]
# Epoch: [31],step: [8600], ssim_mri_loss: [0.15811324], ssim_pet_loss: [0.32553393], total_loss: [0.48364717]
# Epoch: [31],step: [8700], ssim_mri_loss: [0.23498547], ssim_pet_loss: [0.41222620], total_loss: [0.64721167]
# Epoch: [32],step: [8800], ssim_mri_loss: [0.08877224], ssim_pet_loss: [0.23070669], total_loss: [0.31947893]
# Epoch: [32],step: [8900], ssim_mri_loss: [0.18988562], ssim_pet_loss: [0.49866223], total_loss: [0.68854785]
# Epoch: [33],step: [9000], ssim_mri_loss: [0.24220628], ssim_pet_loss: [0.49473798], total_loss: [0.73694426]
# Epoch: [33],step: [9100], ssim_mri_loss: [0.06485981], ssim_pet_loss: [0.19450271], total_loss: [0.25936252]
# Epoch: [33],step: [9200], ssim_mri_loss: [0.33592016], ssim_pet_loss: [0.57227445], total_loss: [0.90819460]
# Epoch: [34],step: [9300], ssim_mri_loss: [0.09403431], ssim_pet_loss: [0.47809011], total_loss: [0.57212442]
# Epoch: [34],step: [9400], ssim_mri_loss: [0.14059448], ssim_pet_loss: [0.30164170], total_loss: [0.44223619]
# Epoch: [34],step: [9500], ssim_mri_loss: [0.14804429], ssim_pet_loss: [0.30997753], total_loss: [0.45802182]
# Epoch: [35],step: [9600], ssim_mri_loss: [0.12285107], ssim_pet_loss: [0.26821542], total_loss: [0.39106649]
# Epoch: [35],step: [9700], ssim_mri_loss: [0.19213533], ssim_pet_loss: [0.42557049], total_loss: [0.61770582]
# Epoch: [36],step: [9800], ssim_mri_loss: [0.17701489], ssim_pet_loss: [0.35460210], total_loss: [0.53161699]
# Epoch: [36],step: [9900], ssim_mri_loss: [0.08154827], ssim_pet_loss: [0.20612735], total_loss: [0.28767562]
# Epoch: [36],step: [10000], ssim_mri_loss: [0.29319251], ssim_pet_loss: [0.50363207], total_loss: [0.79682457]
# Epoch: [37],step: [10100], ssim_mri_loss: [0.17404455], ssim_pet_loss: [0.54355019], total_loss: [0.71759474]
# Epoch: [37],step: [10200], ssim_mri_loss: [0.06587726], ssim_pet_loss: [0.17521298], total_loss: [0.24109024]
# Epoch: [37],step: [10300], ssim_mri_loss: [0.16743499], ssim_pet_loss: [0.35082436], total_loss: [0.51825935]
# Epoch: [38],step: [10400], ssim_mri_loss: [0.25553334], ssim_pet_loss: [0.47339416], total_loss: [0.72892749]
# Epoch: [38],step: [10500], ssim_mri_loss: [0.12849510], ssim_pet_loss: [0.34280086], total_loss: [0.47129595]
# Epoch: [38],step: [10600], ssim_mri_loss: [0.27353203], ssim_pet_loss: [0.44327480], total_loss: [0.71680683]
# Epoch: [39],step: [10700], ssim_mri_loss: [0.10779077], ssim_pet_loss: [0.23734456], total_loss: [0.34513533]
# Epoch: [39],step: [10800], ssim_mri_loss: [0.12538809], ssim_pet_loss: [0.34676248], total_loss: [0.47215056]
# Epoch: [40],step: [10900], ssim_mri_loss: [0.17153770], ssim_pet_loss: [0.46724135], total_loss: [0.63877904]
# Epoch: [40],step: [11000], ssim_mri_loss: [0.07719147], ssim_pet_loss: [0.18082553], total_loss: [0.25801700]
# Epoch: [40],step: [11100], ssim_mri_loss: [0.31874943], ssim_pet_loss: [0.54708576], total_loss: [0.86583519]
# Epoch: [41],step: [11200], ssim_mri_loss: [0.14507324], ssim_pet_loss: [0.52763063], total_loss: [0.67270386]
# Epoch: [41],step: [11300], ssim_mri_loss: [0.26994419], ssim_pet_loss: [0.42930013], total_loss: [0.69924432]
# Epoch: [41],step: [11400], ssim_mri_loss: [0.17760760], ssim_pet_loss: [0.35385209], total_loss: [0.53145969]
# Epoch: [42],step: [11500], ssim_mri_loss: [0.18781686], ssim_pet_loss: [0.39832109], total_loss: [0.58613795]
# Epoch: [42],step: [11600], ssim_mri_loss: [0.12669313], ssim_pet_loss: [0.30036378], total_loss: [0.42705691]
# Epoch: [43],step: [11700], ssim_mri_loss: [0.14726108], ssim_pet_loss: [0.33427989], total_loss: [0.48154098]
# Epoch: [43],step: [11800], ssim_mri_loss: [0.07665461], ssim_pet_loss: [0.21271223], total_loss: [0.28936684]
# Epoch: [43],step: [11900], ssim_mri_loss: [0.25821459], ssim_pet_loss: [0.52866542], total_loss: [0.78688002]
# Epoch: [44],step: [12000], ssim_mri_loss: [0.17563772], ssim_pet_loss: [0.50109196], total_loss: [0.67672968]
# Epoch: [44],step: [12100], ssim_mri_loss: [0.09995371], ssim_pet_loss: [0.20024526], total_loss: [0.30019897]
# Epoch: [44],step: [12200], ssim_mri_loss: [0.28495997], ssim_pet_loss: [0.48854810], total_loss: [0.77350807]
# Epoch: [45],step: [12300], ssim_mri_loss: [0.25145018], ssim_pet_loss: [0.46631646], total_loss: [0.71776664]
# Epoch: [45],step: [12400], ssim_mri_loss: [0.14343113], ssim_pet_loss: [0.39038897], total_loss: [0.53382009]
# Epoch: [45],step: [12500], ssim_mri_loss: [0.15977311], ssim_pet_loss: [0.17784029], total_loss: [0.33761340]
# Epoch: [46],step: [12600], ssim_mri_loss: [0.11605656], ssim_pet_loss: [0.23458546], total_loss: [0.35064203]
# Epoch: [46],step: [12700], ssim_mri_loss: [0.20665950], ssim_pet_loss: [0.37694591], total_loss: [0.58360541]
# Epoch: [47],step: [12800], ssim_mri_loss: [0.13427734], ssim_pet_loss: [0.47396004], total_loss: [0.60823739]
# Epoch: [47],step: [12900], ssim_mri_loss: [0.08211493], ssim_pet_loss: [0.17646313], total_loss: [0.25857806]
# Epoch: [47],step: [13000], ssim_mri_loss: [0.28789735], ssim_pet_loss: [0.59416509], total_loss: [0.88206244]
# Epoch: [48],step: [13100], ssim_mri_loss: [0.10252392], ssim_pet_loss: [0.51053256], total_loss: [0.61305648]
# Epoch: [48],step: [13200], ssim_mri_loss: [0.18748832], ssim_pet_loss: [0.43976074], total_loss: [0.62724906]
# Epoch: [48],step: [13300], ssim_mri_loss: [0.14217639], ssim_pet_loss: [0.29962975], total_loss: [0.44180614]
# Epoch: [49],step: [13400], ssim_mri_loss: [0.20808214], ssim_pet_loss: [0.39578700], total_loss: [0.60386914]
# Epoch: [49],step: [13500], ssim_mri_loss: [0.11470085], ssim_pet_loss: [0.29055858], total_loss: [0.40525943]
# Epoch: [49],step: [13600], ssim_mri_loss: [0.23890615], ssim_pet_loss: [0.52179468], total_loss: [0.76070082]
# Epoch: [50],step: [13700], ssim_mri_loss: [0.09908175], ssim_pet_loss: [0.20491832], total_loss: [0.30400008]
# Epoch: [50],step: [13800], ssim_mri_loss: [0.19226062], ssim_pet_loss: [0.45507157], total_loss: [0.64733219]
# Epoch: [51],step: [13900], ssim_mri_loss: [0.10621476], ssim_pet_loss: [0.36800039], total_loss: [0.47421515]
# Epoch: [51],step: [14000], ssim_mri_loss: [0.07557464], ssim_pet_loss: [0.17409694], total_loss: [0.24967158]
# Epoch: [51],step: [14100], ssim_mri_loss: [0.26618487], ssim_pet_loss: [0.66961503], total_loss: [0.93579990]
# Epoch: [52],step: [14200], ssim_mri_loss: [0.20862073], ssim_pet_loss: [0.45981950], total_loss: [0.66844022]
# Epoch: [52],step: [14300], ssim_mri_loss: [0.17786252], ssim_pet_loss: [0.42620671], total_loss: [0.60406923]
# Epoch: [52],step: [14400], ssim_mri_loss: [0.10334724], ssim_pet_loss: [0.28792745], total_loss: [0.39127469]
# Epoch: [53],step: [14500], ssim_mri_loss: [0.09368616], ssim_pet_loss: [0.25261027], total_loss: [0.34629643]
# Epoch: [53],step: [14600], ssim_mri_loss: [0.19413674], ssim_pet_loss: [0.39436138], total_loss: [0.58849812]
# Epoch: [81],step: [22100], ssim_mri_loss: [0.18997025], ssim_pet_loss: [0.40721667], total_loss: [0.59718692]
# Epoch: [81],step: [22200], ssim_mri_loss: [0.11628717], ssim_pet_loss: [0.29212099], total_loss: [0.40840816]
# Epoch: [81],step: [22300], ssim_mri_loss: [0.10551226], ssim_pet_loss: [0.29766911], total_loss: [0.40318137]
# Epoch: [82],step: [22400], ssim_mri_loss: [0.09362519], ssim_pet_loss: [0.20250022], total_loss: [0.29612541]
# Epoch: [82],step: [22500], ssim_mri_loss: [0.10134554], ssim_pet_loss: [0.49263841], total_loss: [0.59398395]
# Epoch: [83],step: [22600], ssim_mri_loss: [0.11839533], ssim_pet_loss: [0.36365283], total_loss: [0.48204815]
# Epoch: [83],step: [22700], ssim_mri_loss: [0.10303360], ssim_pet_loss: [0.14845407], total_loss: [0.25148767]
# Epoch: [83],step: [22800], ssim_mri_loss: [0.32682711], ssim_pet_loss: [0.46142143], total_loss: [0.78824854]
# Epoch: [84],step: [22900], ssim_mri_loss: [0.06582415], ssim_pet_loss: [0.39278352], total_loss: [0.45860767]
# Epoch: [84],step: [23000], ssim_mri_loss: [0.07373196], ssim_pet_loss: [0.22251487], total_loss: [0.29624683]
# Epoch: [84],step: [23100], ssim_mri_loss: [0.10575306], ssim_pet_loss: [0.26993614], total_loss: [0.37568921]
# Epoch: [85],step: [23200], ssim_mri_loss: [0.09456050], ssim_pet_loss: [0.24637842], total_loss: [0.34093893]
# Epoch: [85],step: [23300], ssim_mri_loss: [0.14628679], ssim_pet_loss: [0.41800404], total_loss: [0.56429082]
# Epoch: [86],step: [23400], ssim_mri_loss: [0.09700799], ssim_pet_loss: [0.29047292], total_loss: [0.38748091]
# Epoch: [86],step: [23500], ssim_mri_loss: [0.08651942], ssim_pet_loss: [0.18896681], total_loss: [0.27548623]
# Epoch: [86],step: [23600], ssim_mri_loss: [0.10202897], ssim_pet_loss: [0.34101653], total_loss: [0.44304550]
# Epoch: [87],step: [23700], ssim_mri_loss: [0.15685976], ssim_pet_loss: [0.62536508], total_loss: [0.78222483]
# Epoch: [87],step: [23800], ssim_mri_loss: [0.09896219], ssim_pet_loss: [0.13205230], total_loss: [0.23101449]
# Epoch: [87],step: [23900], ssim_mri_loss: [0.12018687], ssim_pet_loss: [0.33154595], total_loss: [0.45173281]
# Epoch: [88],step: [24000], ssim_mri_loss: [0.18738896], ssim_pet_loss: [0.44749200], total_loss: [0.63488096]
# Epoch: [88],step: [24100], ssim_mri_loss: [0.12146115], ssim_pet_loss: [0.33474278], total_loss: [0.45620394]
# Epoch: [88],step: [24200], ssim_mri_loss: [0.14528304], ssim_pet_loss: [0.35894525], total_loss: [0.50422829]
# Epoch: [89],step: [24300], ssim_mri_loss: [0.08494109], ssim_pet_loss: [0.22138697], total_loss: [0.30632806]
# Epoch: [89],step: [24400], ssim_mri_loss: [0.08663833], ssim_pet_loss: [0.31601536], total_loss: [0.40265369]
# Epoch: [99],step: [27000], ssim_mri_loss: [0.17568588], ssim_pet_loss: [0.35567015], total_loss: [0.53135604]
# Epoch: [99],step: [27100], ssim_mri_loss: [0.08695585], ssim_pet_loss: [0.30230439], total_loss: [0.38926023]
# Epoch: [99],step: [27200], ssim_mri_loss: [0.14772594], ssim_pet_loss: [0.51091683], total_loss: [0.65864277]
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\torch\serialization.py:250: UserWarning: Couldn't retrieve source code for container of type MaskNet. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "

# %%
l1 = np.asarray(ep_ssim_mri_loss)
l2 = np.asarray(ep_ssim_pet_loss)

# %%
h5f = h5py.File('C:/Users/horan/Desktop/FuseVis/Loss curves/MaskNet/H5 Files/Loss_SSIM_PET.h5', 'w')
h5f.create_dataset('PET_dataset', data=l2)
h5f.close()

# %%
plt.plot(l2)
plt.xlabel('epoch')
plt.ylabel('1-SSIM (PET)')
plt.title('MaskNet')
plt.savefig('C:/Users/horan/Desktop/FuseVis/Loss curves/MaskNet/Loss curves/SSIM_PET_loss.png', bbox_inches = 'tight',pad_inches = 0, dpi=200)

# %%
#load the test input MRI dataset
filenames = os.listdir('C:/Users/horan/Desktop/FuseVis/MRI/')
dataset = os.path.join(os.getcwd(), 'C:/Users/horan/Desktop/FuseVis/MRI/')
data = glob.glob(os.path.join(dataset, "*.gif"))
data = natsort.natsorted(data,reverse=False)
test_mri = np.zeros((len(data), image_width,image_length))
for i in range(len(data)):
    test_mri[i,:,:] =(imageio.imread(data[i]))
    test_mri[i,:,:] =(test_mri[i,:,:] - np.min(test_mri[i,:,:])) / (np.max(test_mri[i,:,:]) - np.min(test_mri[i,:,:]))
    test_mri[i,:,:] = np.float32(test_mri[i,:,:])

# %%
#expand dimension to add the channel
test_mri = np.expand_dims(test_mri,axis=1)
#verify the shape matches the pytorch standard
test_mri.shape
# Out:
# (1, 1, 256, 256)

# %%
#verify the test mri image
#test_mri = test_mri[0,:,:,:]
#test_mri = np.expand_dims(test_mri,axis=0)
plt.imshow(test_mri[0,0,:,:],'gray')
#plt.savefig('MRI.png', bbox_inches = 'tight',pad_inches = 0,dpi=200)

# %%
#convert the MRI Testing data to pytorch tensor
test_mri_tensor = torch.from_numpy(test_mri).float()
test_mri_tensor = test_mri_tensor.to(device)
print(test_mri_tensor.shape)
test_mri_tensor.requires_grad =True
# Out:
# torch.Size([1, 1, 256, 256])

# %%
#load the test input PET dataset
filenames = os.listdir('C:/Users/horan/Desktop/FuseVis/PET/')
dataset = os.path.join(os.getcwd(), 'C:/Users/horan/Desktop/FuseVis/PET/')
data = glob.glob(os.path.join(dataset, "*.png"))
data = natsort.natsorted(data,reverse=False)
test_pet = np.zeros((len(data), image_width,image_length))
for i in range(len(data)):
    test_pet[i,:,:] =(imageio.imread(data[i]))
    test_pet[i,:,:] =(test_pet[i,:,:] - np.min(test_pet[i,:,:])) / (np.max(test_pet[i,:,:]) - np.min(test_pet[i,:,:]))
    test_pet[i,:,:] = np.float32(test_pet[i,:,:])

# %%
#expand dimension to add the channel
test_pet = np.expand_dims(test_pet,axis=1)
#verify the shape matches the pytorch standard
test_pet.shape
# Out:
# (1, 1, 256, 256)

# %%
plt.imshow(test_pet[0,0,:,:],'gray')
#plt.savefig('PET.png', bbox_inches = 'tight',pad_inches = 0,dpi=200)

# %%
#convert the MRI Testing data to pytorch tensor
test_pet_tensor = torch.from_numpy(test_pet).float()
test_pet_tensor = test_pet_tensor.to(device)
print(test_pet_tensor.shape)
test_pet_tensor.requires_grad =True
# Out:
# torch.Size([1, 1, 256, 256])

# %%
#load the model
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
cnn =torch.load('C:/Users/horan/Desktop/FuseVis/.ipynb_checkpoints/MaskNet/checkpoint.pth')
cnn.eval()
# Out:
# MaskNet(
#   (layer1): Sequential(
#     (0): Conv2d(2, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.2, inplace)
#   )
#   (layer2): Sequential(
#     (0): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.2, inplace)
#   )
#   (layer3): Sequential(
#     (0): Conv2d(96, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.2, inplace)
#   )
#   (layer4): Sequential(
#     (0): Conv2d(144, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.2, inplace)
#   )
#   (layer5): Sequential(
#     (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.2, inplace)
#   )
#   (layer6): Sequential(
#     (0): Conv2d(192, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.2, inplace)
#   )
#   (layer7): Sequential(
#     (0): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.2, inplace)
#   )
#   (layer8): Sequential(
#     (0): Conv2d(64, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.2, inplace)
#   )
# )

# %%
#predicted the fused image
fuse_test = cnn(test_mri_tensor.to(device),test_pet_tensor.to(device))
fused_numpy = fuse_test.data.cpu().numpy()

# %%
fuse_test.shape
# Out:
# torch.Size([1, 1, 256, 256])

# %%
fused_numpy
# Out:
# array([[[[ 0.02783226,  0.00130833,  0.00435426, ...,  0.02621504,
#            0.06972316, -0.00841843],
#          [ 0.00739587, -0.00575113, -0.00352883, ...,  0.02611536,
#            0.06567213, -0.03614342],
#          [ 0.01030671, -0.00386333, -0.001676  , ...,  0.04021078,
#            0.02369185, -0.07019519],
#          ...,
#          [ 0.19902849,  0.09612747,  0.04414961, ..., -0.02092931,
#           -0.06187404, -0.15791124],
#          [ 0.2993433 ,  0.03990789, -0.01955156, ..., -0.07663933,
#           -0.12159378, -0.18361   ],
#          [-0.1577368 , -0.379692  , -0.516394  , ..., -0.5976772 ,
#           -0.54090136, -0.3905139 ]]]], dtype=float32)

# %%
#verify the output image
plt.imshow(fused_numpy[0,0,:,:],'gray')
#plt.savefig('Fused.png', bbox_inches = 'tight',pad_inches = 0,dpi=200)

# %%
imageio.imwrite('C:/Users/horan/Desktop/FuseVis/Fused/MaskNet/Fused.png',np.uint8(cv2.normalize(fused_numpy[0,0,:,:], None, alpha=0, beta=255, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_32F)))

# %%
#calculate the guidance image for MRI and PET wrt to the fused image
time1 = time.time()
count = 0 
guide_fuse_mri = np.zeros((256,256),dtype=float)
guide_fuse_pet = np.zeros((256,256),dtype=float)

for y_coord in range(0,256):
    for x_coord in range(0,256):
        jacob_fuse_mri = torch.autograd.grad(fuse_test[0,0,y_coord,x_coord], test_mri_tensor, retain_graph=True, create_graph=True)[0]
        jacob_numpy_mri = np.squeeze(jacob_fuse_mri.data.cpu().numpy())  
        guide_fuse_mri[y_coord,x_coord] = jacob_numpy_mri[y_coord,x_coord]
        jacob_fuse_pet = torch.autograd.grad(fuse_test[0,0,y_coord,x_coord], test_pet_tensor, retain_graph=True, create_graph=True)[0]
        jacob_numpy_pet = np.squeeze(jacob_fuse_pet.data.cpu().numpy())  
        guide_fuse_pet[y_coord,x_coord] = jacob_numpy_pet[y_coord,x_coord]
        count += 1
        if count % 1000 == 0:
            print('Count is %d' %count)
time2 = time.time()
print('Time taken to compute is %d seconds' %(time2-time1))
# Out:
# Count is 1000
# Count is 2000
# Count is 3000
# Count is 4000
# Count is 5000
# Count is 6000
# Count is 7000
# Count is 8000
# Count is 9000
# Count is 10000
# Count is 11000
# Count is 12000
# Count is 13000
# Count is 14000
# Count is 15000
# Count is 16000
# Count is 17000
# Count is 18000
# Count is 19000
# Count is 20000
# Count is 21000
# Count is 22000
# Count is 23000
# Count is 24000
# Count is 25000
# Count is 26000
# Count is 27000
# Count is 28000
# Count is 29000
# Count is 30000
# Count is 31000
# Count is 32000
# Count is 33000
# Count is 34000
# Count is 35000
# Count is 36000
# Count is 37000
# Count is 38000
# Count is 39000
# Count is 40000
# Count is 41000
# Count is 42000
# Count is 43000
# Count is 44000
# Count is 45000
# Count is 46000
# Count is 47000
# Count is 48000
# Count is 49000
# Count is 50000
# Count is 51000
# Count is 52000
# Count is 53000
# Count is 54000
# Count is 55000
# Count is 56000
# Count is 57000
# Count is 58000
# Count is 59000
# Count is 60000
# Count is 61000
# Count is 62000
# Count is 63000
# Count is 64000
# Count is 65000
# Time taken to compute is 8292 seconds

# %%
h5f = h5py.File('C:/Users/horan/Desktop/FuseVis/Guidance images/MaskNet/H5 Files/Jacobian_MRI.h5', 'w')
h5f.create_dataset('Jacob_MRI_dataset', data=guide_fuse_mri)
h5f.close()

# %%
plt.imshow(guide_fuse_mri,cmap='viridis')
plt.colorbar()
plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/MaskNet/Resultant images/Guide_Fused_MRI_DPI.png', bbox_inches = 'tight',pad_inches = 0,dpi=200)

# %%
h5f = h5py.File('C:/Users/horan/Desktop/FuseVis/Guidance images/MaskNet/H5 Files/Jacobian_PET.h5', 'w')
h5f.create_dataset('Jacob_PET_dataset', data=guide_fuse_pet)
h5f.close()

# %%
plt.imshow(guide_fuse_pet,cmap='viridis')
plt.colorbar()
plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/MaskNet/Resultant images/Guide_Fused_PET_DPI.png', bbox_inches = 'tight',pad_inches = 0,dpi=200)

# %%
#define overlay images
fused_RGB = np.zeros((256,256,3),dtype=float)
mri_RGB   = np.zeros((256,256,3),dtype=float)
pet_RGB   = np.zeros((256,256,3),dtype=float)

# %%
fused_RGB[:,:,0]  = guide_fuse_mri 
fused_RGB[:,:,1]  = guide_fuse_pet 
fused_RGB[:,:,2]  = fused_numpy[0,0,:,:]

# %%
plt.imshow(fused_RGB)
plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/MaskNet/Resultant images/Fused_RGB_DPI.png', bbox_inches = 'tight',pad_inches = 0,dpi=200)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
mri_RGB[:,:,0]  = guide_fuse_mri
mri_RGB[:,:,1]  = guide_fuse_pet 
mri_RGB[:,:,2]  = test_mri[0,0,:,:]

# %%
plt.imshow(mri_RGB)
plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/MaskNet/Resultant images/MRI_RGB_DPI.png', bbox_inches = 'tight',pad_inches = 0,dpi=200)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
pet_RGB[:,:,0]  = guide_fuse_mri
pet_RGB[:,:,1]  = guide_fuse_pet 
pet_RGB[:,:,2]  = test_pet[0,0,:,:]

# %%
plt.imshow(pet_RGB)
plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/MaskNet/Resultant images/PET_RGB_DPI.png', bbox_inches = 'tight',pad_inches = 0,dpi=200)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
#define the window
root = Tk()  
root.title('Visualisation of fusion networks')
root.configure(background='white')


#Label the images
#fontStyle = tkFont.Font(family="Lucida Grande", size=15)
#w1 = tk.Label(root, bg='white', font=fontStyle, text="Fused Image")
#w1.grid(row=0, column=1)
#w1.pack()

#define the frame
canvasframe = Frame(root)  # define Input and output frame
buttonframe = Frame(root)  # define button frame
canvasframe.pack()  # pack the Input and Output frame
buttonframe.pack()  # pack the button frame


#define the canvas
canvas = Canvas(canvasframe, width=1800, height=920, bg = 'white')
canvas.grid(row=0, column=0)

#Insert fused image to the canvas
img_fused = ImageTk.PhotoImage(file ="C:/Users/horan/Desktop/FuseVis/Fused/MaskNet/Fused.png") # load the image
canvas.create_image(0, 0, image=img_fused, anchor=NW)

#Insert MRI image to the canvas
img_mri = ImageTk.PhotoImage(file ="C:/Users/horan/Desktop/FuseVis/MRI/MRI.gif") # load the image
canvas.create_image(600, 0, image=img_mri, anchor=NW)

#Insert PET image to the canvas
img_pet = ImageTk.PhotoImage(file ="C:/Users/horan/Desktop/FuseVis/PET/3.png") # load the image
canvas.create_image(1200, 0, image=img_pet, anchor=NW)

def start_mouseover():  # function called when user clicks the button 
    # link the function to the left-mouse-click event
    canvas.bind("<B1-Motion>", Coordinates)

def Coordinates(event): # function called when left-mouse-button is clicked with a mouseover
    x_coord = event.x  # save x and y coordinates selected by the user   
    y_coord = event.y
    print('mouse position is at' + '(' + str(y_coord) + ',' + str(x_coord) + ')', end='\r')
    #display the output MRI Jacobian image
    #img_MR_out = ImageTk.PhotoImage(file ='C:/Users/cgvadmin/Desktop/FuseVis/Fused_MRI/im_' + str(y_coord) + '_' + str(x_coord) + '.png') # load the image
    jacobian_fuse_mri = torch.autograd.grad(fuse_test[0,0,y_coord,x_coord], test_mri_tensor, retain_graph=True, create_graph=True)[0]
    jacobian_fuse_pet = torch.autograd.grad(fuse_test[0,0,y_coord,x_coord], test_pet_tensor, retain_graph=True, create_graph=True)[0]
    
    jacob_val_mri = np.squeeze(jacobian_fuse_mri.data.cpu().numpy())    
    jacob_val_pet = np.squeeze(jacobian_fuse_pet.data.cpu().numpy())
    
    x_mri = np.asarray(np.where(np.any(jacob_val_mri, axis = 0)))
    y_mri = np.asarray(np.where(np.any(jacob_val_mri, axis = 1)))
    minx_mri, maxx_mri, miny_mri, maxy_mri = np.min(x_mri), np.max(x_mri), np.min(y_mri), np.max(y_mri)  #return min and max coordinates
    zoom_im_mri = jacob_val_mri[miny_mri:maxy_mri,minx_mri:maxx_mri] 
    
    x_pet = np.asarray(np.where(np.any(jacob_val_pet, axis = 0)))
    y_pet = np.asarray(np.where(np.any(jacob_val_pet, axis = 1)))
    minx_pet, maxx_pet, miny_pet, maxy_pet = np.min(x_pet), np.max(x_pet), np.min(y_pet), np.max(y_pet)  #return min and max coordinates
    zoom_im_pet = jacob_val_pet[miny_pet:maxy_pet,minx_pet:maxx_pet] 
    
    plt.imshow(fused_numpy[0,0,miny_mri:maxy_mri,minx_mri:maxx_mri], cmap = 'gray', aspect ='equal')
    plt.title('Zoom Fused')
    plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/MaskNet/Resultant images/Zoom_Fused.png', bbox_inches = 'tight',pad_inches = 0)
    plt.close()
    im_out11 = ImageTk.PhotoImage(file ='C:/Users/horan/Desktop/FuseVis/Guidance images/MaskNet/Resultant images/Zoom_Fused.png')
    canvas.create_image(300,5,image=im_out11,anchor=NW)
    canvas.image11 = im_out11
    plt.tight_layout()
    
    plt.imshow(test_mri[0,0,miny_mri:maxy_mri,minx_mri:maxx_mri], cmap = 'gray', aspect ='equal')
    plt.title('Zoom MRI')
    plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/MaskNet/Resultant images/Zoom_MRI.png', bbox_inches = 'tight',pad_inches = 0)
    plt.close()
    im_out12 = ImageTk.PhotoImage(file ='C:/Users/horan/Desktop/FuseVis/Guidance images/MaskNet/Resultant images/Zoom_MRI.png')
    canvas.create_image(900,5,image=im_out12,anchor=NW)
    canvas.image12 = im_out12
    plt.tight_layout()
    
    plt.imshow(test_pet[0,0,miny_mri:maxy_mri,minx_mri:maxx_mri], cmap = 'gray', aspect ='equal')
    plt.title('Zoom PET')
    plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/MaskNet/Resultant images/Zoom_PET.png', bbox_inches = 'tight',pad_inches = 0)
    plt.close()
    im_out13 = ImageTk.PhotoImage(file ='C:/Users/horan/Desktop/FuseVis/Guidance images/MaskNet/Resultant images/Zoom_PET.png')
    canvas.create_image(1500,5,image=im_out13,anchor=NW)
    canvas.image13 = im_out13
    plt.tight_layout()
    
    plt.imshow(jacob_val_mri,cmap='viridis', aspect ='equal')
    plt.title('Jacobian (Fused wrt MRI)')
    plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/MaskNet/Resultant images/Jacob_Fused_MRI.png', bbox_inches = 'tight',pad_inches = 0)
    plt.close()
    im_out1 = ImageTk.PhotoImage(file ='C:/Users/horan/Desktop/FuseVis/Guidance images/MaskNet/Resultant images/Jacob_Fused_MRI.png')
    canvas.create_image(40,320,image=im_out1,anchor=NW)
    canvas.image1 = im_out1
    #plt.tight_layout()
    
    #f.add_subplot(1,5,2)
    plt.imshow(zoom_im_mri,cmap='viridis',aspect ='equal')
    plt.title('Zoom Jacobian (Fused wrt MRI)')
    plt.colorbar()
    plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/MaskNet/Resultant images/Zoom_Jacob_MRI.png', bbox_inches = 'tight',pad_inches = 0)
    plt.close()
    im_out2 = ImageTk.PhotoImage(file ='C:/Users/horan/Desktop/FuseVis/Guidance images/MaskNet/Resultant images/Zoom_Jacob_MRI.png')
    canvas.create_image(380,320,image=im_out2,anchor=NW)
    canvas.image2 = im_out2
    
    #f.add_subplot(1,5,3)
    plt.xlim(0,0.7)
    plt.ylim(0,0.7)
    plt.plot(jacob_val_mri[y_coord,x_coord],jacob_val_pet[y_coord,x_coord],'-ro')
    plt.xlabel('MRI pixel score (Fused wrt MRI)')
    plt.ylabel('PET pixel score (Fused wrt PET)')
    plt.title('Mouse position at: (' + str(y_coord) + ',' + str(x_coord) + ')')
    plt.gca().set_aspect('equal', adjustable='box')
    plt.draw()
    plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/MaskNet/Resultant images/Pixel_intensities.png', bbox_inches = 'tight',pad_inches = 0.1)
    plt.close()
    im_out3 = ImageTk.PhotoImage(file ='C:/Users/horan/Desktop/FuseVis/Guidance images/MaskNet/Resultant images/Pixel_intensities.png')
    canvas.create_image(750,320,image=im_out3,anchor=NW)
    canvas.image3 = im_out3
    
    #f.add_subplot(1,5,4)
    plt.imshow(jacob_val_pet,cmap='viridis',aspect ='equal')
    plt.title('Jacobian (Fused wrt PET)')
    plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/MaskNet/Resultant images/Jacob_Fused_PET.png', bbox_inches = 'tight',pad_inches = 0)
    plt.close()
    im_out4 = ImageTk.PhotoImage(file ='C:/Users/horan/Desktop/FuseVis/Guidance images/MaskNet/Resultant images/Jacob_Fused_PET.png')
    canvas.create_image(1110,320,image=im_out4,anchor=NW)
    canvas.image4 = im_out4
    #plt.tight_layout()
    
    #f.add_subplot(1,5,5)
    plt.imshow(zoom_im_pet,cmap='viridis',aspect ='equal')
    plt.title('Zoomed Jacobian (Fused wrt PET)')
    plt.colorbar()
    plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/MaskNet/Resultant images/Zoom_Jacob_PET.png', bbox_inches = 'tight',pad_inches = 0)
    plt.close()
    im_out5 = ImageTk.PhotoImage(file ='C:/Users/horan/Desktop/FuseVis/Guidance images/MaskNet/Resultant images/Zoom_Jacob_PET.png')
    canvas.create_image(1450,320,image=im_out5,anchor=NW)
    canvas.image5 = im_out5

    plt.imshow(guide_fuse_mri,cmap='viridis')
    plt.title('Guidance (Fused wrt MRI)')
    plt.colorbar()
    plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/MaskNet/Resultant images/Guide_Fused_MRI.png', bbox_inches = 'tight',pad_inches = 0)
    plt.close()
    im_out6 = ImageTk.PhotoImage(file ='C:/Users/horan/Desktop/FuseVis/Guidance images/MaskNet/Resultant images/Guide_Fused_MRI.png')
    canvas.create_image(100,650,image=im_out6,anchor=NW)
    canvas.image6 = im_out6
    
    plt.imshow(fused_RGB)
    plt.title('R=I1 G=I2 B=Fused')
    plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/MaskNet/Resultant images/Fused_RGB.png', bbox_inches = 'tight',pad_inches = 0)
    plt.close()
    im_out8 = ImageTk.PhotoImage(file ='C:/Users/horan/Desktop/FuseVis/Guidance images/MaskNet/Resultant images/Fused_RGB.png')
    canvas.create_image(420,650,image=im_out8,anchor=NW)
    canvas.image8 = im_out8
    
    plt.imshow(mri_RGB)
    plt.title('R=I1 G=I2 B=MRI')
    plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/MaskNet/Resultant images/MRI_RGB.png', bbox_inches = 'tight',pad_inches = 0)
    plt.close()
    im_out9 = ImageTk.PhotoImage(file ='C:/Users/horan/Desktop/FuseVis/Guidance images/MaskNet/Resultant images/MRI_RGB.png')
    canvas.create_image(740,650,image=im_out9,anchor=NW)
    canvas.image9 = im_out9
    
    plt.imshow(pet_RGB)
    plt.title('R=I1 G=I2 B=PET')
    plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/MaskNet/Resultant images/PET_RGB.png', bbox_inches = 'tight',pad_inches = 0)
    plt.close()
    im_out10 = ImageTk.PhotoImage(file ='C:/Users/horan/Desktop/FuseVis/Guidance images/MaskNet/Resultant images/PET_RGB.png')
    canvas.create_image(1100,650,image=im_out10,anchor=NW)
    canvas.image10 = im_out10
    
    plt.imshow(guide_fuse_pet,cmap='viridis')
    plt.title('Guidance (Fused wrt PET)')
    plt.colorbar()
    plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/MaskNet/Resultant images/Guide_Fused_PET.png', bbox_inches = 'tight',pad_inches = 0)
    plt.close()
    im_out7 = ImageTk.PhotoImage(file ='C:/Users/horan/Desktop/FuseVis/Guidance images/MaskNet/Resultant images/Guide_Fused_PET.png')
    canvas.create_image(1400,650,image=im_out7,anchor=NW)
    canvas.image7 = im_out7
    
    radius = 5
    i = canvas.create_oval(x_coord-radius, y_coord-radius, x_coord+radius, y_coord+radius, fill = 'red')
    canvas.after(20,canvas.delete,i)

# insert button to the middleframe and link it to "Start Mouseover"
button_start_mouseover = Button(buttonframe, text="Start Mouseover",command=start_mouseover)
button_start_mouseover.grid(row=1, column=0, pady=0)


root.mainloop()  #keep the GUI open
# Out:
# mouse position is at(86,108)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# mouse position is at(322,282)
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\tkinter\__init__.py", line 1702, in __call__
#     return self.func(*args)
#   File "<ipython-input-57-8459d1c8544b>", line 46, in Coordinates
#     jacobian_fuse_mri = torch.autograd.grad(fuse_test[0,0,y_coord,x_coord], test_mri_tensor, retain_graph=True, create_graph=True)[0]
# IndexError: index 322 is out of bounds for dimension 0 with size 256
# mouse position is at(127,141)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# mouse position is at(154,141)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# mouse position is at(154,140)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# mouse position is at(138,105)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# mouse position is at(118,112)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# mouse position is at(133,102)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# mouse position is at(136,106)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# mouse position is at(138,117)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
