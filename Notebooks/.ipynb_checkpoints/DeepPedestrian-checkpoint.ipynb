# %% [markdown]
# # This is the pytorch implementation of the deep learning model proposed in the paper 'Deep Visible and Thermal Image Fusion for Enhanced pedestrian visibility'

# %%
#Import packages
import time
import torch.nn as nn
import torch
from torch.utils.data import Dataset, DataLoader
import torchvision.datasets as datasets
from torch.optim.lr_scheduler import StepLR, ReduceLROnPlateau
import numpy as np
from torchvision import transforms
from torch.autograd import Variable
from PIL import Image
import torchvision.transforms.functional as TF
from torchvision.models.vgg import vgg19
import torch.nn as nn
import torch.nn.functional as F
import torch
from skimage import img_as_ubyte
import torch.nn as nn
import torch.utils.data as Data
import torchvision      # dataset
import matplotlib.pyplot as plt
import scipy
import numpy as np
import argparse
import glob
import imageio
from skimage import color
import numpy
import natsort
import scipy
from pytorch_msssim import ssim, ms_ssim, SSIM, MS_SSIM
import pprint
from scipy.ndimage import correlate
from scipy.ndimage.filters import gaussian_gradient_magnitude
import torchvision.datasets as dset
import torch.utils.data as data
import os
import os.path
from tkinter import *
import tkinter as tk
import tkinter.font as tkFont
from PIL import ImageTk, Image
import pylab
import cv2
import h5py
from mpl_toolkits.axes_grid1 import make_axes_locatable
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(torch.cuda.get_device_properties(0).total_memory)
# Out:
# 11811160064

# %%
import multiprocessing

multiprocessing.cpu_count()
# Out:
# 12

# %%
#define the hyperparameters
image_length = 256
image_width  = 256
mr_channels  = 1
gray_channels = 1
pet_channels = 4    
rgb_channels = 3     
batch_size   = 1
EPOCH = 100
learning_rate = 0.00002

# %%
#load the train mri data
filenames = os.listdir('C:/Users/horan/Desktop/FuseVis/Training/MRI')
dataset = os.path.join(os.getcwd(), 'C:/Users/horan/Desktop/FuseVis/Training/MRI')
data = glob.glob(os.path.join(dataset, "*.gif"))
data = natsort.natsorted(data,reverse=False)
train_mri = np.zeros((len(data), image_width,image_length))
for i in range(len(data)):
    train_mri[i,:,:] =(imageio.imread(data[i]))
    train_mri[i,:,:] =(train_mri[i,:,:] - np.min(train_mri[i,:,:])) / (np.max(train_mri[i,:,:]) - np.min(train_mri[i,:,:]))
    train_mri[i,:,:] = np.float32(train_mri[i,:,:])

# %%
#expand dimension to add the channel
train_mri = np.expand_dims(train_mri,axis=1)

# %%
#verify the shape matches the pytorch standard
train_mri.shape
# Out:
# (272, 1, 256, 256)

# %%
#convert the MRI training data to pytorch tensor
train_mri_tensor = torch.from_numpy(train_mri).float()
train_mri_tensor.shape
# Out:
# torch.Size([272, 1, 256, 256])

# %%
#load the train pet data
filenames = os.listdir('C:/Users/horan/Desktop/FuseVis/Training/PET')
dataset = os.path.join(os.getcwd(), 'C:/Users/horan/Desktop/FuseVis/Training/PET')
data = glob.glob(os.path.join(dataset, "*.gif"))
data = natsort.natsorted(data,reverse=False)
train_other = np.zeros((len(data),image_width,image_length,pet_channels),dtype=float)
train_pet = np.zeros((len(data),image_width,image_length),dtype=float)
for i in range(len(data)):
    train_other[i,:,:,:] =(imageio.imread(data[i]))
    train_pet[i,:,:] = 0.2989 * train_other[i,:,:,0] + 0.5870 *  train_other[i,:,:,1]  + 0.1140 * train_other[i,:,:,2]
    train_pet[i,:,:] =(train_pet[i,:,:] - np.min(train_pet[i,:,:])) / (np.max(train_pet[i,:,:]) - np.min(train_pet[i,:,:]))

# %%
#expand the dimension to add the channel
train_pet = np.expand_dims(train_pet,axis=1)

# %%
#verify the shape matches the pytorch standard
train_pet.shape
# Out:
# (272, 1, 256, 256)

# %%
#convert the PET training data to pytorch tensor
train_pet_tensor = torch.from_numpy(train_pet).float()
train_pet_tensor.shape
# Out:
# torch.Size([272, 1, 256, 256])

# %%
#define the fusion network
#define the network
class DeepPedestrian(nn.Module):
    def  __init__(self):
        super(DeepPedestrian, self).__init__()
        #####layer 1#####
        self.conv1 = nn.Sequential(                             #input shape  (,2,256,256)
                         nn.Conv2d(in_channels=2, out_channels=48, kernel_size=3, stride=1, padding=1),
                         nn.ReLU(),
                         nn.Conv2d(in_channels = 48, out_channels = 48, kernel_size  = 3, stride= 1, padding = 1),
                         nn.ReLU(),
                         nn.Conv2d(in_channels = 48, out_channels = 48, kernel_size  = 3, stride= 1, padding = 1),
                         nn.ReLU(),
                         nn.Conv2d(in_channels = 48, out_channels = 48, kernel_size  = 3, stride= 1, padding = 1)
                         )                                     #output shape (,48,256,256)   
        #####layer 2#####
        self.conv2 = nn.Sequential(                            #input shape  (,48,256,256)
                         nn.ReLU(),
                         nn.Conv2d(in_channels=48, out_channels=48, kernel_size=3, stride=1, padding=1),
                         nn.ReLU(),
                         nn.Conv2d(in_channels = 48, out_channels = 48, kernel_size  = 3, stride= 1, padding = 1),
                         nn.ReLU(),
                         nn.Conv2d(in_channels = 48, out_channels = 48, kernel_size  = 3, stride= 1, padding = 1),
                         nn.ReLU(),
                         nn.Conv2d(in_channels = 48, out_channels = 48, kernel_size  = 3, stride= 1, padding = 1)
                         )                                     #output shape (,48,256,256)   
        #####layer 3#####
        self.conv3 = nn.Sequential(                            #input shape  (,48,256,256)
                         nn.ReLU(), 
                         nn.Conv2d(in_channels = 48, out_channels = 48, kernel_size=3, stride=1, padding=1),
                         nn.ReLU(),
                         nn.Conv2d(in_channels = 48, out_channels = 48, kernel_size  = 3, stride= 1, padding = 1),
                         nn.ReLU(),
                         nn.Conv2d(in_channels = 48, out_channels = 48, kernel_size  = 3, stride= 1, padding = 1),
                         nn.ReLU(),
                         nn.Conv2d(in_channels = 48, out_channels = 48, kernel_size  = 3, stride= 1, padding = 1)
                         )                                     #output shape (,48,256,256)     
        #####layer 4#####
        self.conv4 = nn.Sequential(                            #input shape  (,48,256,256)
                         nn.ReLU(), 
                         nn.Conv2d(in_channels = 48, out_channels = 48, kernel_size=3, stride=1, padding=1),
                         nn.ReLU(),
                         nn.Conv2d(in_channels = 48, out_channels = 48, kernel_size  = 3, stride= 1, padding = 1),
                         nn.ReLU(),
                         nn.Conv2d(in_channels = 48, out_channels = 48, kernel_size  = 3, stride= 1, padding = 1),
                         nn.ReLU(),
                         nn.Conv2d(in_channels = 48, out_channels = 48, kernel_size  = 3, stride= 1, padding = 1)
                         )                                      #output shape (,48,256,256)  
        #####layer 5#####
        self.conv5 = nn.Sequential(                             #input shape (, 48, 256, 256)
                          nn.ReLU(),
                          nn.Conv2d(in_channels  = 48,  out_channels = 1, kernel_size  = 3, stride = 1, padding = 1)) 
                                                                #output shape (,1, 256, 256)
        
    def forward(self, x, y):
        #layer 1
        x1 = self.conv1(torch.cat((x,y),dim=1))
        #layer 2
        x2 = self.conv2(x1)
        #residual layer
        x3 = x1+x2
        #layer 3
        x4 = self.conv3(x3)
        #layer 4
        x5 = self.conv4(x4)
        #residual layer
        x6 = x4 + x5
        #layer 5
        fused = self.conv5(x6)
        return fused
        #execute the network

cnn = DeepPedestrian().to(device)
cnn = cnn.float()
print(cnn)
# Out:
# DeepPedestrian(
#   (conv1): Sequential(
#     (0): Conv2d(2, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU()
#     (6): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (conv2): Sequential(
#     (0): ReLU()
#     (1): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (2): ReLU()
#     (3): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU()
#     (5): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU()
#     (7): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (conv3): Sequential(
#     (0): ReLU()
#     (1): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (2): ReLU()
#     (3): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU()
#     (5): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU()
#     (7): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (conv4): Sequential(
#     (0): ReLU()
#     (1): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (2): ReLU()
#     (3): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU()
#     (5): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU()
#     (7): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (conv5): Sequential(
#     (0): ReLU()
#     (1): Conv2d(48, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
# )

# %%
#define the optimizers and loss functions 
optimizer = torch.optim.Adam(cnn.parameters(), lr=learning_rate)   # optimize all cnn parameters
#gamma = decaying factor
scheduler = StepLR(optimizer, step_size=25, gamma=0.1)
#loss function
l2_loss   = nn.MSELoss() #MSEloss

# %%
# perform the training
counter = 0
start_time = time.time()
lamda = 0.8
ep_mri_ssim_loss = []
ep_pet_ssim_loss = []
ep_total_l2_loss = []
for epoch in range(EPOCH):
    mri_ssim_Loss = []
    pet_ssim_Loss = []
    l2_Loss       = []
    #run batch images
    batch_idxs = 272 // batch_size
    for idx in range(0, batch_idxs):
        b_x = train_mri_tensor[idx*batch_size : (idx+1)*batch_size,:,:,:].to(device)
        b_y = train_pet_tensor[idx*batch_size : (idx+1)*batch_size,:,:,:].to(device)
        counter += 1
        output = cnn(b_x, b_y)             # cnn output
        ssim_loss_mri = 1 - ssim(output, b_x,data_range=1)
        ssim_loss_pet = 1 - ssim(output, b_y,data_range=1)
        ssim_total = ssim_loss_mri + ssim_loss_pet
        l2_total = l2_loss(output,b_x) + l2_loss(output,b_y)
        loss_total = lamda*ssim_total + (1-lamda)*l2_total 
        optimizer.zero_grad()              # clear gradients for this training step
        loss_total.backward()              # backpropagation, compute gradients
        optimizer.step()                   # apply gradients
        
        mri_ssim_Loss.append(ssim_loss_mri.item())
        pet_ssim_Loss.append(ssim_loss_pet.item())
        l2_Loss.append(l2_total.item())
        
        if counter % 100 == 0:
            print("Epoch: [%2d],step: [%2d], mri_ssim_loss: [%.8f], pet_ssim_loss: [%.8f],  total_ssim_loss: [%.8f], total_l2_loss: [%.8f], total_loss: [%.8f]" 
                   %(epoch, counter, ssim_loss_mri, ssim_loss_pet, ssim_total, l2_total, loss_total))
            
    #learning schedule
    scheduler.step()
    
    av_mri_ssim_loss = np.average(mri_ssim_Loss)
    ep_mri_ssim_loss.append(av_mri_ssim_loss)
    
    av_pet_ssim_loss = np.average(pet_ssim_Loss)
    ep_pet_ssim_loss.append(av_pet_ssim_loss)
    
    av_total_l2_loss = np.average(l2_Loss)
    ep_total_l2_loss.append(av_total_l2_loss)
    
    if(epoch == EPOCH -1):
        #Save a checkpoint
        torch.save(cnn, 'C:/Users/horan/Desktop/FuseVis/.ipynb_checkpoints/DeepPedestrian/checkpoint.pth')
# Out:
# Epoch: [ 0],step: [100], mri_ssim_loss: [0.32226294], pet_ssim_loss: [0.31858701],  total_ssim_loss: [0.64084995], total_l2_loss: [0.09634849], total_loss: [0.53194970]
# Epoch: [ 0],step: [200], mri_ssim_loss: [0.44820666], pet_ssim_loss: [0.36280608],  total_ssim_loss: [0.81101274], total_l2_loss: [0.04468511], total_loss: [0.65774721]
# Epoch: [ 1],step: [300], mri_ssim_loss: [0.36055255], pet_ssim_loss: [0.13786352],  total_ssim_loss: [0.49841607], total_l2_loss: [0.01541023], total_loss: [0.40181491]
# Epoch: [ 1],step: [400], mri_ssim_loss: [0.22606438], pet_ssim_loss: [0.05993468],  total_ssim_loss: [0.28599906], total_l2_loss: [0.02432878], total_loss: [0.23366500]
# Epoch: [ 1],step: [500], mri_ssim_loss: [0.71072686], pet_ssim_loss: [0.14924288],  total_ssim_loss: [0.85996974], total_l2_loss: [0.02720406], total_loss: [0.69341666]
# Epoch: [ 2],step: [600], mri_ssim_loss: [0.53625906], pet_ssim_loss: [0.07413089],  total_ssim_loss: [0.61038995], total_l2_loss: [0.04127506], total_loss: [0.49656698]
# Epoch: [ 2],step: [700], mri_ssim_loss: [0.39954853], pet_ssim_loss: [0.05747801],  total_ssim_loss: [0.45702654], total_l2_loss: [0.03373562], total_loss: [0.37236837]
# Epoch: [ 2],step: [800], mri_ssim_loss: [0.29321164], pet_ssim_loss: [0.06241214],  total_ssim_loss: [0.35562378], total_l2_loss: [0.02394553], total_loss: [0.28928813]
# Epoch: [ 3],step: [900], mri_ssim_loss: [0.29396302], pet_ssim_loss: [0.07337636],  total_ssim_loss: [0.36733937], total_l2_loss: [0.03451010], total_loss: [0.30077350]
# Epoch: [ 3],step: [1000], mri_ssim_loss: [0.46452773], pet_ssim_loss: [0.07177663],  total_ssim_loss: [0.53630435], total_l2_loss: [0.03514370], total_loss: [0.43607223]
# Epoch: [ 4],step: [1100], mri_ssim_loss: [0.29479724], pet_ssim_loss: [0.08837903],  total_ssim_loss: [0.38317627], total_l2_loss: [0.01934532], total_loss: [0.31041008]
# Epoch: [ 4],step: [1200], mri_ssim_loss: [0.24151105], pet_ssim_loss: [0.05791473],  total_ssim_loss: [0.29942578], total_l2_loss: [0.02076586], total_loss: [0.24369380]
# Epoch: [ 4],step: [1300], mri_ssim_loss: [0.35309982], pet_ssim_loss: [0.06484264],  total_ssim_loss: [0.41794246], total_l2_loss: [0.02254371], total_loss: [0.33886272]
# Epoch: [ 5],step: [1400], mri_ssim_loss: [0.48560941], pet_ssim_loss: [0.15956128],  total_ssim_loss: [0.64517069], total_l2_loss: [0.02465057], total_loss: [0.52106673]
# Epoch: [ 5],step: [1500], mri_ssim_loss: [0.15528762], pet_ssim_loss: [0.03171659],  total_ssim_loss: [0.18700421], total_l2_loss: [0.02520036], total_loss: [0.15464343]
# Epoch: [ 5],step: [1600], mri_ssim_loss: [0.35974330], pet_ssim_loss: [0.08658296],  total_ssim_loss: [0.44632626], total_l2_loss: [0.02401788], total_loss: [0.36186457]
# Epoch: [ 6],step: [1700], mri_ssim_loss: [0.43096769], pet_ssim_loss: [0.13596255],  total_ssim_loss: [0.56693023], total_l2_loss: [0.04863966], total_loss: [0.46327212]
# Epoch: [ 6],step: [1800], mri_ssim_loss: [0.33053625], pet_ssim_loss: [0.09157163],  total_ssim_loss: [0.42210788], total_l2_loss: [0.02663399], total_loss: [0.34301311]
# Epoch: [ 6],step: [1900], mri_ssim_loss: [0.29312783], pet_ssim_loss: [0.12468952],  total_ssim_loss: [0.41781735], total_l2_loss: [0.01754919], total_loss: [0.33776373]
# Epoch: [ 7],step: [2000], mri_ssim_loss: [0.23418045], pet_ssim_loss: [0.08891249],  total_ssim_loss: [0.32309294], total_l2_loss: [0.02336105], total_loss: [0.26314655]
# Epoch: [ 7],step: [2100], mri_ssim_loss: [0.47254622], pet_ssim_loss: [0.12833804],  total_ssim_loss: [0.60088426], total_l2_loss: [0.03724277], total_loss: [0.48815596]
# Epoch: [ 8],step: [2200], mri_ssim_loss: [0.26598239], pet_ssim_loss: [0.22062546],  total_ssim_loss: [0.48660785], total_l2_loss: [0.01642003], total_loss: [0.39257029]
# Epoch: [ 8],step: [2300], mri_ssim_loss: [0.17869508], pet_ssim_loss: [0.08499175],  total_ssim_loss: [0.26368684], total_l2_loss: [0.01998703], total_loss: [0.21494687]
# Epoch: [ 8],step: [2400], mri_ssim_loss: [0.52699238], pet_ssim_loss: [0.24282670],  total_ssim_loss: [0.76981908], total_l2_loss: [0.03677785], total_loss: [0.62321085]
# Epoch: [ 9],step: [2500], mri_ssim_loss: [0.28429157], pet_ssim_loss: [0.18705517],  total_ssim_loss: [0.47134674], total_l2_loss: [0.01765362], total_loss: [0.38060811]
# Epoch: [ 9],step: [2600], mri_ssim_loss: [0.20858318], pet_ssim_loss: [0.06743288],  total_ssim_loss: [0.27601606], total_l2_loss: [0.01681624], total_loss: [0.22417609]
# Epoch: [ 9],step: [2700], mri_ssim_loss: [0.25824875], pet_ssim_loss: [0.13112575],  total_ssim_loss: [0.38937449], total_l2_loss: [0.02994375], total_loss: [0.31748834]
# Epoch: [10],step: [2800], mri_ssim_loss: [0.20864594], pet_ssim_loss: [0.13751340],  total_ssim_loss: [0.34615934], total_l2_loss: [0.03441757], total_loss: [0.28381097]
# Epoch: [10],step: [2900], mri_ssim_loss: [0.39188218], pet_ssim_loss: [0.09707898],  total_ssim_loss: [0.48896116], total_l2_loss: [0.03842676], total_loss: [0.39885429]
# Epoch: [11],step: [3000], mri_ssim_loss: [0.24707848], pet_ssim_loss: [0.14331812],  total_ssim_loss: [0.39039660], total_l2_loss: [0.01165735], total_loss: [0.31464875]
# Epoch: [11],step: [3100], mri_ssim_loss: [0.17569578], pet_ssim_loss: [0.09900844],  total_ssim_loss: [0.27470422], total_l2_loss: [0.01762431], total_loss: [0.22328824]
# Epoch: [11],step: [3200], mri_ssim_loss: [0.30543810], pet_ssim_loss: [0.12447220],  total_ssim_loss: [0.42991030], total_l2_loss: [0.01507470], total_loss: [0.34694320]
# Epoch: [12],step: [3300], mri_ssim_loss: [0.37070262], pet_ssim_loss: [0.26290250],  total_ssim_loss: [0.63360512], total_l2_loss: [0.01967667], total_loss: [0.51081944]
# Epoch: [12],step: [3400], mri_ssim_loss: [0.14610815], pet_ssim_loss: [0.06825298],  total_ssim_loss: [0.21436113], total_l2_loss: [0.02143592], total_loss: [0.17577609]
# Epoch: [12],step: [3500], mri_ssim_loss: [0.35015482], pet_ssim_loss: [0.12121415],  total_ssim_loss: [0.47136897], total_l2_loss: [0.01961834], total_loss: [0.38101885]
# Epoch: [13],step: [3600], mri_ssim_loss: [0.35613644], pet_ssim_loss: [0.23158675],  total_ssim_loss: [0.58772320], total_l2_loss: [0.04839483], total_loss: [0.47985753]
# Epoch: [13],step: [3700], mri_ssim_loss: [0.25770050], pet_ssim_loss: [0.13386464],  total_ssim_loss: [0.39156514], total_l2_loss: [0.01451235], total_loss: [0.31615460]
# Epoch: [13],step: [3800], mri_ssim_loss: [0.34307641], pet_ssim_loss: [0.14876509],  total_ssim_loss: [0.49184150], total_l2_loss: [0.03623352], total_loss: [0.40071991]
# Epoch: [14],step: [3900], mri_ssim_loss: [0.20412827], pet_ssim_loss: [0.11389285],  total_ssim_loss: [0.31802112], total_l2_loss: [0.02403048], total_loss: [0.25922301]
# Epoch: [14],step: [4000], mri_ssim_loss: [0.28879941], pet_ssim_loss: [0.10362697],  total_ssim_loss: [0.39242637], total_l2_loss: [0.01456123], total_loss: [0.31685334]
# Epoch: [15],step: [4100], mri_ssim_loss: [0.30426323], pet_ssim_loss: [0.23020971],  total_ssim_loss: [0.53447294], total_l2_loss: [0.02310604], total_loss: [0.43219957]
# Epoch: [15],step: [4200], mri_ssim_loss: [0.16256225], pet_ssim_loss: [0.08632314],  total_ssim_loss: [0.24888539], total_l2_loss: [0.01756945], total_loss: [0.20262221]
# Epoch: [15],step: [4300], mri_ssim_loss: [0.49565423], pet_ssim_loss: [0.23808873],  total_ssim_loss: [0.73374295], total_l2_loss: [0.01705680], total_loss: [0.59040570]
# Epoch: [16],step: [4400], mri_ssim_loss: [0.34143496], pet_ssim_loss: [0.21317363],  total_ssim_loss: [0.55460858], total_l2_loss: [0.02012641], total_loss: [0.44771215]
# Epoch: [16],step: [4500], mri_ssim_loss: [0.28506553], pet_ssim_loss: [0.12531883],  total_ssim_loss: [0.41038436], total_l2_loss: [0.01695227], total_loss: [0.33169794]
# Epoch: [16],step: [4600], mri_ssim_loss: [0.25019598], pet_ssim_loss: [0.14107132],  total_ssim_loss: [0.39126730], total_l2_loss: [0.03162669], total_loss: [0.31933919]
# Epoch: [17],step: [4700], mri_ssim_loss: [0.25862986], pet_ssim_loss: [0.18942785],  total_ssim_loss: [0.44805771], total_l2_loss: [0.03449545], total_loss: [0.36534527]
# Epoch: [17],step: [4800], mri_ssim_loss: [0.23444492], pet_ssim_loss: [0.12123269],  total_ssim_loss: [0.35567760], total_l2_loss: [0.02079298], total_loss: [0.28870067]
# Epoch: [18],step: [4900], mri_ssim_loss: [0.27176708], pet_ssim_loss: [0.14600921],  total_ssim_loss: [0.41777629], total_l2_loss: [0.02655727], total_loss: [0.33953249]
# Epoch: [18],step: [5000], mri_ssim_loss: [0.16482693], pet_ssim_loss: [0.10753167],  total_ssim_loss: [0.27235860], total_l2_loss: [0.01931661], total_loss: [0.22175020]
# Epoch: [18],step: [5100], mri_ssim_loss: [0.36551082], pet_ssim_loss: [0.16319680],  total_ssim_loss: [0.52870762], total_l2_loss: [0.02507677], total_loss: [0.42798144]
# Epoch: [19],step: [5200], mri_ssim_loss: [0.35684925], pet_ssim_loss: [0.22584981],  total_ssim_loss: [0.58269906], total_l2_loss: [0.03429921], total_loss: [0.47301909]
# Epoch: [19],step: [5300], mri_ssim_loss: [0.14278603], pet_ssim_loss: [0.08642721],  total_ssim_loss: [0.22921324], total_l2_loss: [0.02114774], total_loss: [0.18760014]
# Epoch: [19],step: [5400], mri_ssim_loss: [0.41288853], pet_ssim_loss: [0.15267962],  total_ssim_loss: [0.56556815], total_l2_loss: [0.03949854], total_loss: [0.46035424]
# Epoch: [20],step: [5500], mri_ssim_loss: [0.32134575], pet_ssim_loss: [0.26400781],  total_ssim_loss: [0.58535355], total_l2_loss: [0.04651590], total_loss: [0.47758603]
# Epoch: [20],step: [5600], mri_ssim_loss: [0.25696647], pet_ssim_loss: [0.14232159],  total_ssim_loss: [0.39928806], total_l2_loss: [0.01480049], total_loss: [0.32239053]
# Epoch: [20],step: [5700], mri_ssim_loss: [0.12456512], pet_ssim_loss: [0.03858823],  total_ssim_loss: [0.16315335], total_l2_loss: [0.00743352], total_loss: [0.13200939]
# Epoch: [21],step: [5800], mri_ssim_loss: [0.19687939], pet_ssim_loss: [0.13279444],  total_ssim_loss: [0.32967383], total_l2_loss: [0.02598981], total_loss: [0.26893705]
# Epoch: [21],step: [5900], mri_ssim_loss: [0.33500195], pet_ssim_loss: [0.12162483],  total_ssim_loss: [0.45662677], total_l2_loss: [0.02948746], total_loss: [0.37119892]
# Epoch: [22],step: [6000], mri_ssim_loss: [0.29359722], pet_ssim_loss: [0.25534207],  total_ssim_loss: [0.54893929], total_l2_loss: [0.01922139], total_loss: [0.44299573]
# Epoch: [22],step: [6100], mri_ssim_loss: [0.15847367], pet_ssim_loss: [0.09152567],  total_ssim_loss: [0.24999934], total_l2_loss: [0.01642453], total_loss: [0.20328438]
# Epoch: [22],step: [6200], mri_ssim_loss: [0.67081678], pet_ssim_loss: [0.14326382],  total_ssim_loss: [0.81408060], total_l2_loss: [0.02046704], total_loss: [0.65535790]
# Epoch: [23],step: [6300], mri_ssim_loss: [0.33834314], pet_ssim_loss: [0.22134972],  total_ssim_loss: [0.55969286], total_l2_loss: [0.01838114], total_loss: [0.45143053]
# Epoch: [23],step: [6400], mri_ssim_loss: [0.34503365], pet_ssim_loss: [0.17606854],  total_ssim_loss: [0.52110219], total_l2_loss: [0.02574431], total_loss: [0.42203063]
# Epoch: [23],step: [6500], mri_ssim_loss: [0.23588043], pet_ssim_loss: [0.12162018],  total_ssim_loss: [0.35750061], total_l2_loss: [0.01370481], total_loss: [0.28874144]
# Epoch: [24],step: [6600], mri_ssim_loss: [0.26707041], pet_ssim_loss: [0.20792061],  total_ssim_loss: [0.47499102], total_l2_loss: [0.03740244], total_loss: [0.38747332]
# Epoch: [24],step: [6700], mri_ssim_loss: [0.24348766], pet_ssim_loss: [0.13863188],  total_ssim_loss: [0.38211954], total_l2_loss: [0.03211593], total_loss: [0.31211880]
# Epoch: [24],step: [6800], mri_ssim_loss: [0.46981287], pet_ssim_loss: [0.08409429],  total_ssim_loss: [0.55390716], total_l2_loss: [0.05402444], total_loss: [0.45393062]
# Epoch: [25],step: [6900], mri_ssim_loss: [0.17644006], pet_ssim_loss: [0.10624999],  total_ssim_loss: [0.28269005], total_l2_loss: [0.02121611], total_loss: [0.23039527]
# Epoch: [25],step: [7000], mri_ssim_loss: [0.36086917], pet_ssim_loss: [0.20369595],  total_ssim_loss: [0.56456512], total_l2_loss: [0.04151967], total_loss: [0.45995605]
# Epoch: [26],step: [7100], mri_ssim_loss: [0.18128020], pet_ssim_loss: [0.24414891],  total_ssim_loss: [0.42542911], total_l2_loss: [0.01210158], total_loss: [0.34276360]
# Epoch: [26],step: [7200], mri_ssim_loss: [0.13886982], pet_ssim_loss: [0.09698564],  total_ssim_loss: [0.23585546], total_l2_loss: [0.01864234], total_loss: [0.19241284]
# Epoch: [26],step: [7300], mri_ssim_loss: [0.62251759], pet_ssim_loss: [0.15975904],  total_ssim_loss: [0.78227663], total_l2_loss: [0.02336398], total_loss: [0.63049412]
# Epoch: [27],step: [7400], mri_ssim_loss: [0.31504208], pet_ssim_loss: [0.23621553],  total_ssim_loss: [0.55125761], total_l2_loss: [0.03181241], total_loss: [0.44736856]
# Epoch: [27],step: [7500], mri_ssim_loss: [0.28659588], pet_ssim_loss: [0.12033701],  total_ssim_loss: [0.40693289], total_l2_loss: [0.02676407], total_loss: [0.33089915]
# Epoch: [27],step: [7600], mri_ssim_loss: [0.21413809], pet_ssim_loss: [0.10365921],  total_ssim_loss: [0.31779730], total_l2_loss: [0.01678064], total_loss: [0.25759399]
# Epoch: [28],step: [7700], mri_ssim_loss: [0.18744880], pet_ssim_loss: [0.14607197],  total_ssim_loss: [0.33352077], total_l2_loss: [0.02762806], total_loss: [0.27234223]
# Epoch: [28],step: [7800], mri_ssim_loss: [0.34929752], pet_ssim_loss: [0.12041748],  total_ssim_loss: [0.46971500], total_l2_loss: [0.02814123], total_loss: [0.38140026]
# Epoch: [29],step: [7900], mri_ssim_loss: [0.22522569], pet_ssim_loss: [0.11919206],  total_ssim_loss: [0.34441775], total_l2_loss: [0.01717416], total_loss: [0.27896905]
# Epoch: [29],step: [8000], mri_ssim_loss: [0.16489661], pet_ssim_loss: [0.09899431],  total_ssim_loss: [0.26389092], total_l2_loss: [0.01672128], total_loss: [0.21445699]
# Epoch: [29],step: [8100], mri_ssim_loss: [0.29042292], pet_ssim_loss: [0.08607489],  total_ssim_loss: [0.37649781], total_l2_loss: [0.01880725], total_loss: [0.30495968]
# Epoch: [30],step: [8200], mri_ssim_loss: [0.35434729], pet_ssim_loss: [0.24724799],  total_ssim_loss: [0.60159528], total_l2_loss: [0.01964412], total_loss: [0.48520505]
# Epoch: [30],step: [8300], mri_ssim_loss: [0.12141466], pet_ssim_loss: [0.05299366],  total_ssim_loss: [0.17440832], total_l2_loss: [0.02145026], total_loss: [0.14381671]
# Epoch: [30],step: [8400], mri_ssim_loss: [0.30740213], pet_ssim_loss: [0.11480153],  total_ssim_loss: [0.42220366], total_l2_loss: [0.01908954], total_loss: [0.34158084]
# Epoch: [31],step: [8500], mri_ssim_loss: [0.30577677], pet_ssim_loss: [0.21591276],  total_ssim_loss: [0.52168953], total_l2_loss: [0.04208323], total_loss: [0.42576829]
# Epoch: [31],step: [8600], mri_ssim_loss: [0.23045969], pet_ssim_loss: [0.16789079],  total_ssim_loss: [0.39835048], total_l2_loss: [0.02151346], total_loss: [0.32298306]
# Epoch: [31],step: [8700], mri_ssim_loss: [0.25973427], pet_ssim_loss: [0.12345409],  total_ssim_loss: [0.38318837], total_l2_loss: [0.01695214], total_loss: [0.30994114]
# Epoch: [32],step: [8800], mri_ssim_loss: [0.17973363], pet_ssim_loss: [0.11406910],  total_ssim_loss: [0.29380274], total_l2_loss: [0.02073289], total_loss: [0.23918878]
# Epoch: [32],step: [8900], mri_ssim_loss: [0.41165549], pet_ssim_loss: [0.16118276],  total_ssim_loss: [0.57283825], total_l2_loss: [0.03585022], total_loss: [0.46544066]
# Epoch: [33],step: [9000], mri_ssim_loss: [0.23908198], pet_ssim_loss: [0.22275221],  total_ssim_loss: [0.46183419], total_l2_loss: [0.01542084], total_loss: [0.37255153]
# Epoch: [33],step: [9100], mri_ssim_loss: [0.15272230], pet_ssim_loss: [0.09570664],  total_ssim_loss: [0.24842894], total_l2_loss: [0.01878564], total_loss: [0.20250028]
# Epoch: [33],step: [9200], mri_ssim_loss: [0.55660820], pet_ssim_loss: [0.20728534],  total_ssim_loss: [0.76389354], total_l2_loss: [0.03351969], total_loss: [0.61781877]
# Epoch: [34],step: [9300], mri_ssim_loss: [0.27389687], pet_ssim_loss: [0.18454576],  total_ssim_loss: [0.45844263], total_l2_loss: [0.01821815], total_loss: [0.37039775]
# Epoch: [34],step: [9400], mri_ssim_loss: [0.19026113], pet_ssim_loss: [0.07829911],  total_ssim_loss: [0.26856023], total_l2_loss: [0.01624731], total_loss: [0.21809766]
# Epoch: [34],step: [9500], mri_ssim_loss: [0.22764689], pet_ssim_loss: [0.13801199],  total_ssim_loss: [0.36565888], total_l2_loss: [0.02837662], total_loss: [0.29820243]
# Epoch: [35],step: [9600], mri_ssim_loss: [0.19073206], pet_ssim_loss: [0.14010161],  total_ssim_loss: [0.33083367], total_l2_loss: [0.03371039], total_loss: [0.27140903]
# Epoch: [35],step: [9700], mri_ssim_loss: [0.37089276], pet_ssim_loss: [0.10561651],  total_ssim_loss: [0.47650927], total_l2_loss: [0.03826550], total_loss: [0.38886052]
# Epoch: [36],step: [9800], mri_ssim_loss: [0.22204733], pet_ssim_loss: [0.15894276],  total_ssim_loss: [0.38099009], total_l2_loss: [0.01095014], total_loss: [0.30698210]
# Epoch: [36],step: [9900], mri_ssim_loss: [0.16043437], pet_ssim_loss: [0.10573179],  total_ssim_loss: [0.26616615], total_l2_loss: [0.01718980], total_loss: [0.21637090]
# Epoch: [36],step: [10000], mri_ssim_loss: [0.28123981], pet_ssim_loss: [0.14163238],  total_ssim_loss: [0.42287219], total_l2_loss: [0.01472594], total_loss: [0.34124294]
# Epoch: [37],step: [10100], mri_ssim_loss: [0.35452670], pet_ssim_loss: [0.27139121],  total_ssim_loss: [0.62591791], total_l2_loss: [0.01904549], total_loss: [0.50454342]
# Epoch: [37],step: [10200], mri_ssim_loss: [0.13533467], pet_ssim_loss: [0.07580698],  total_ssim_loss: [0.21114165], total_l2_loss: [0.02083674], total_loss: [0.17308067]
# Epoch: [37],step: [10300], mri_ssim_loss: [0.31834632], pet_ssim_loss: [0.13344383],  total_ssim_loss: [0.45179015], total_l2_loss: [0.01927993], total_loss: [0.36528811]
# Epoch: [38],step: [10400], mri_ssim_loss: [0.31143749], pet_ssim_loss: [0.26941907],  total_ssim_loss: [0.58085656], total_l2_loss: [0.04559743], total_loss: [0.47380474]
# Epoch: [38],step: [10500], mri_ssim_loss: [0.22539872], pet_ssim_loss: [0.16276568],  total_ssim_loss: [0.38816440], total_l2_loss: [0.01371754], total_loss: [0.31327504]
# Epoch: [38],step: [10600], mri_ssim_loss: [0.32617164], pet_ssim_loss: [0.15679735],  total_ssim_loss: [0.48296899], total_l2_loss: [0.03660166], total_loss: [0.39369553]
# Epoch: [39],step: [10700], mri_ssim_loss: [0.18685633], pet_ssim_loss: [0.12498492],  total_ssim_loss: [0.31184125], total_l2_loss: [0.02332297], total_loss: [0.25413761]
# Epoch: [39],step: [10800], mri_ssim_loss: [0.26792258], pet_ssim_loss: [0.12113470],  total_ssim_loss: [0.38905728], total_l2_loss: [0.01431340], total_loss: [0.31410852]
# Epoch: [40],step: [10900], mri_ssim_loss: [0.28272057], pet_ssim_loss: [0.24579519],  total_ssim_loss: [0.52851576], total_l2_loss: [0.02200057], total_loss: [0.42721272]
# Epoch: [40],step: [11000], mri_ssim_loss: [0.15097159], pet_ssim_loss: [0.09453601],  total_ssim_loss: [0.24550760], total_l2_loss: [0.01714579], total_loss: [0.19983524]
# Epoch: [40],step: [11100], mri_ssim_loss: [0.55959368], pet_ssim_loss: [0.18785000],  total_ssim_loss: [0.74744368], total_l2_loss: [0.01689773], total_loss: [0.60133445]
# Epoch: [41],step: [11200], mri_ssim_loss: [0.33199042], pet_ssim_loss: [0.21914804],  total_ssim_loss: [0.55113846], total_l2_loss: [0.01911483], total_loss: [0.44473374]
# Epoch: [41],step: [11300], mri_ssim_loss: [0.26144290], pet_ssim_loss: [0.14553875],  total_ssim_loss: [0.40698165], total_l2_loss: [0.01621721], total_loss: [0.32882878]
# Epoch: [41],step: [11400], mri_ssim_loss: [0.23466229], pet_ssim_loss: [0.15493131],  total_ssim_loss: [0.38959360], total_l2_loss: [0.03181372], total_loss: [0.31803763]
# Epoch: [42],step: [11500], mri_ssim_loss: [0.24395823], pet_ssim_loss: [0.20194882],  total_ssim_loss: [0.44590706], total_l2_loss: [0.03407631], total_loss: [0.36354092]
# Epoch: [42],step: [11600], mri_ssim_loss: [0.21518147], pet_ssim_loss: [0.13861072],  total_ssim_loss: [0.35379219], total_l2_loss: [0.02021036], total_loss: [0.28707582]
# Epoch: [43],step: [11700], mri_ssim_loss: [0.26232785], pet_ssim_loss: [0.14499611],  total_ssim_loss: [0.40732396], total_l2_loss: [0.02599154], total_loss: [0.33105746]
# Epoch: [43],step: [11800], mri_ssim_loss: [0.15690184], pet_ssim_loss: [0.11246443],  total_ssim_loss: [0.26936626], total_l2_loss: [0.01911182], total_loss: [0.21931538]
# Epoch: [43],step: [11900], mri_ssim_loss: [0.34497952], pet_ssim_loss: [0.18054837],  total_ssim_loss: [0.52552789], total_l2_loss: [0.02444039], total_loss: [0.42531040]
# Epoch: [44],step: [12000], mri_ssim_loss: [0.34625351], pet_ssim_loss: [0.23339069],  total_ssim_loss: [0.57964420], total_l2_loss: [0.03252650], total_loss: [0.47022069]
# Epoch: [44],step: [12100], mri_ssim_loss: [0.13586044], pet_ssim_loss: [0.09227043],  total_ssim_loss: [0.22813088], total_l2_loss: [0.02078706], total_loss: [0.18666211]
# Epoch: [44],step: [12200], mri_ssim_loss: [0.36993873], pet_ssim_loss: [0.13444823],  total_ssim_loss: [0.50438696], total_l2_loss: [0.03888931], total_loss: [0.41128746]
# Epoch: [45],step: [12300], mri_ssim_loss: [0.31314617], pet_ssim_loss: [0.26719528],  total_ssim_loss: [0.58034146], total_l2_loss: [0.04624504], total_loss: [0.47352219]
# Epoch: [45],step: [12400], mri_ssim_loss: [0.24586630], pet_ssim_loss: [0.15187436],  total_ssim_loss: [0.39774066], total_l2_loss: [0.01497369], total_loss: [0.32118729]
# Epoch: [45],step: [12500], mri_ssim_loss: [0.12332004], pet_ssim_loss: [0.03708541],  total_ssim_loss: [0.16040546], total_l2_loss: [0.00751700], total_loss: [0.12982777]
# Epoch: [46],step: [12600], mri_ssim_loss: [0.19154346], pet_ssim_loss: [0.13555372],  total_ssim_loss: [0.32709718], total_l2_loss: [0.02580388], total_loss: [0.26683852]
# Epoch: [46],step: [12700], mri_ssim_loss: [0.31696784], pet_ssim_loss: [0.13830280],  total_ssim_loss: [0.45527065], total_l2_loss: [0.02874088], total_loss: [0.36996472]
# Epoch: [47],step: [12800], mri_ssim_loss: [0.30099672], pet_ssim_loss: [0.24404341],  total_ssim_loss: [0.54504013], total_l2_loss: [0.01947303], total_loss: [0.43992671]
# Epoch: [47],step: [12900], mri_ssim_loss: [0.15450317], pet_ssim_loss: [0.09397358],  total_ssim_loss: [0.24847674], total_l2_loss: [0.01633941], total_loss: [0.20204929]
# Epoch: [47],step: [13000], mri_ssim_loss: [0.65093517], pet_ssim_loss: [0.15729046],  total_ssim_loss: [0.80822563], total_l2_loss: [0.02019856], total_loss: [0.65062022]
# Epoch: [48],step: [13100], mri_ssim_loss: [0.33603966], pet_ssim_loss: [0.22293603],  total_ssim_loss: [0.55897570], total_l2_loss: [0.01746349], total_loss: [0.45067328]
# Epoch: [48],step: [13200], mri_ssim_loss: [0.33292276], pet_ssim_loss: [0.18659329],  total_ssim_loss: [0.51951605], total_l2_loss: [0.02539882], total_loss: [0.42069262]
# Epoch: [48],step: [13300], mri_ssim_loss: [0.22565317], pet_ssim_loss: [0.11051768],  total_ssim_loss: [0.33617085], total_l2_loss: [0.01362545], total_loss: [0.27166179]
# Epoch: [49],step: [13400], mri_ssim_loss: [0.26576382], pet_ssim_loss: [0.20819783],  total_ssim_loss: [0.47396165], total_l2_loss: [0.03774606], total_loss: [0.38671851]
# Epoch: [49],step: [13500], mri_ssim_loss: [0.23268622], pet_ssim_loss: [0.14968747],  total_ssim_loss: [0.38237369], total_l2_loss: [0.03179146], total_loss: [0.31225726]
# Epoch: [49],step: [13600], mri_ssim_loss: [0.47159463], pet_ssim_loss: [0.07985252],  total_ssim_loss: [0.55144715], total_l2_loss: [0.05451177], total_loss: [0.45206007]
# Epoch: [50],step: [13700], mri_ssim_loss: [0.17594135], pet_ssim_loss: [0.10547149],  total_ssim_loss: [0.28141284], total_l2_loss: [0.02107608], total_loss: [0.22934549]
# Epoch: [50],step: [13800], mri_ssim_loss: [0.34945506], pet_ssim_loss: [0.21466011],  total_ssim_loss: [0.56411517], total_l2_loss: [0.04138771], total_loss: [0.45956966]
# Epoch: [51],step: [13900], mri_ssim_loss: [0.18396521], pet_ssim_loss: [0.24000317],  total_ssim_loss: [0.42396837], total_l2_loss: [0.01222744], total_loss: [0.34162021]
# Epoch: [51],step: [14000], mri_ssim_loss: [0.14186448], pet_ssim_loss: [0.09302765],  total_ssim_loss: [0.23489213], total_l2_loss: [0.01892837], total_loss: [0.19169937]
# Epoch: [51],step: [14100], mri_ssim_loss: [0.64159852], pet_ssim_loss: [0.14994413],  total_ssim_loss: [0.79154265], total_l2_loss: [0.02345023], total_loss: [0.63792419]
# Epoch: [52],step: [14200], mri_ssim_loss: [0.31410313], pet_ssim_loss: [0.23535079],  total_ssim_loss: [0.54945391], total_l2_loss: [0.03165321], total_loss: [0.44589376]
# Epoch: [52],step: [14300], mri_ssim_loss: [0.28602451], pet_ssim_loss: [0.11942941],  total_ssim_loss: [0.40545392], total_l2_loss: [0.02653160], total_loss: [0.32966948]
# Epoch: [52],step: [14400], mri_ssim_loss: [0.21343488], pet_ssim_loss: [0.10220557],  total_ssim_loss: [0.31564045], total_l2_loss: [0.01739217], total_loss: [0.25599080]
# Epoch: [53],step: [14500], mri_ssim_loss: [0.18873310], pet_ssim_loss: [0.14370233],  total_ssim_loss: [0.33243543], total_l2_loss: [0.02777099], total_loss: [0.27150255]
# Epoch: [53],step: [14600], mri_ssim_loss: [0.34823966], pet_ssim_loss: [0.12069660],  total_ssim_loss: [0.46893626], total_l2_loss: [0.02828480], total_loss: [0.38080597]
# Epoch: [54],step: [14700], mri_ssim_loss: [0.22249985], pet_ssim_loss: [0.12126821],  total_ssim_loss: [0.34376806], total_l2_loss: [0.01688508], total_loss: [0.27839148]
# Epoch: [54],step: [14800], mri_ssim_loss: [0.16567254], pet_ssim_loss: [0.09794271],  total_ssim_loss: [0.26361525], total_l2_loss: [0.01667825], total_loss: [0.21422786]
# Epoch: [54],step: [14900], mri_ssim_loss: [0.28789395], pet_ssim_loss: [0.08845955],  total_ssim_loss: [0.37635350], total_l2_loss: [0.01842738], total_loss: [0.30476829]
# Epoch: [55],step: [15000], mri_ssim_loss: [0.35491508], pet_ssim_loss: [0.24684125],  total_ssim_loss: [0.60175633], total_l2_loss: [0.01946944], total_loss: [0.48529896]
# Epoch: [55],step: [15100], mri_ssim_loss: [0.12157935], pet_ssim_loss: [0.05213177],  total_ssim_loss: [0.17371112], total_l2_loss: [0.02141523], total_loss: [0.14325194]
# Epoch: [55],step: [15200], mri_ssim_loss: [0.29644316], pet_ssim_loss: [0.10201979],  total_ssim_loss: [0.39846295], total_l2_loss: [0.01948726], total_loss: [0.32266784]
# Epoch: [56],step: [15300], mri_ssim_loss: [0.30285990], pet_ssim_loss: [0.21750760],  total_ssim_loss: [0.52036750], total_l2_loss: [0.04144040], total_loss: [0.42458209]
# Epoch: [56],step: [15400], mri_ssim_loss: [0.22683334], pet_ssim_loss: [0.17066294],  total_ssim_loss: [0.39749628], total_l2_loss: [0.02142595], total_loss: [0.32228222]
# Epoch: [56],step: [15500], mri_ssim_loss: [0.25528604], pet_ssim_loss: [0.12763709],  total_ssim_loss: [0.38292313], total_l2_loss: [0.01643543], total_loss: [0.30962560]
# Epoch: [57],step: [15600], mri_ssim_loss: [0.17997938], pet_ssim_loss: [0.11329925],  total_ssim_loss: [0.29327863], total_l2_loss: [0.02078584], total_loss: [0.23878008]
# Epoch: [57],step: [15700], mri_ssim_loss: [0.40809637], pet_ssim_loss: [0.16406149],  total_ssim_loss: [0.57215786], total_l2_loss: [0.03583260], total_loss: [0.46489280]
# Epoch: [58],step: [15800], mri_ssim_loss: [0.23719591], pet_ssim_loss: [0.22513419],  total_ssim_loss: [0.46233010], total_l2_loss: [0.01535200], total_loss: [0.37293449]
# Epoch: [58],step: [15900], mri_ssim_loss: [0.15373486], pet_ssim_loss: [0.09462422],  total_ssim_loss: [0.24835908], total_l2_loss: [0.01882871], total_loss: [0.20245302]
# Epoch: [58],step: [16000], mri_ssim_loss: [0.50686514], pet_ssim_loss: [0.23459947],  total_ssim_loss: [0.74146461], total_l2_loss: [0.03343413], total_loss: [0.59985852]
# Epoch: [59],step: [16100], mri_ssim_loss: [0.27386212], pet_ssim_loss: [0.18478537],  total_ssim_loss: [0.45864749], total_l2_loss: [0.01712434], total_loss: [0.37034288]
# Epoch: [59],step: [16200], mri_ssim_loss: [0.19126832], pet_ssim_loss: [0.07705921],  total_ssim_loss: [0.26832753], total_l2_loss: [0.01622533], total_loss: [0.21790710]
# Epoch: [59],step: [16300], mri_ssim_loss: [0.22437906], pet_ssim_loss: [0.13982785],  total_ssim_loss: [0.36420691], total_l2_loss: [0.02832406], total_loss: [0.29703036]
# Epoch: [60],step: [16400], mri_ssim_loss: [0.18976659], pet_ssim_loss: [0.14003724],  total_ssim_loss: [0.32980382], total_l2_loss: [0.03364435], total_loss: [0.27057192]
# Epoch: [60],step: [16500], mri_ssim_loss: [0.36903256], pet_ssim_loss: [0.10668427],  total_ssim_loss: [0.47571683], total_l2_loss: [0.03834857], total_loss: [0.38824320]
# Epoch: [61],step: [16600], mri_ssim_loss: [0.21631718], pet_ssim_loss: [0.16410112],  total_ssim_loss: [0.38041830], total_l2_loss: [0.01074174], total_loss: [0.30648300]
# Epoch: [61],step: [16700], mri_ssim_loss: [0.16059291], pet_ssim_loss: [0.10526603],  total_ssim_loss: [0.26585895], total_l2_loss: [0.01718762], total_loss: [0.21612468]
# Epoch: [61],step: [16800], mri_ssim_loss: [0.27931720], pet_ssim_loss: [0.14367658],  total_ssim_loss: [0.42299378], total_l2_loss: [0.01464722], total_loss: [0.34132448]
# Epoch: [62],step: [16900], mri_ssim_loss: [0.35089356], pet_ssim_loss: [0.27449387],  total_ssim_loss: [0.62538743], total_l2_loss: [0.01895119], total_loss: [0.50410020]
# Epoch: [62],step: [17000], mri_ssim_loss: [0.13611072], pet_ssim_loss: [0.07489139],  total_ssim_loss: [0.21100211], total_l2_loss: [0.02086245], total_loss: [0.17297418]
# Epoch: [62],step: [17100], mri_ssim_loss: [0.31028759], pet_ssim_loss: [0.12811589],  total_ssim_loss: [0.43840349], total_l2_loss: [0.01891607], total_loss: [0.35450602]
# Epoch: [63],step: [17200], mri_ssim_loss: [0.30800098], pet_ssim_loss: [0.27207738],  total_ssim_loss: [0.58007836], total_l2_loss: [0.04557049], total_loss: [0.47317678]
# Epoch: [63],step: [17300], mri_ssim_loss: [0.22298324], pet_ssim_loss: [0.16421711],  total_ssim_loss: [0.38720036], total_l2_loss: [0.01365232], total_loss: [0.31249076]
# Epoch: [63],step: [17400], mri_ssim_loss: [0.32101274], pet_ssim_loss: [0.16080093],  total_ssim_loss: [0.48181367], total_l2_loss: [0.03636975], total_loss: [0.39272487]
# Epoch: [64],step: [17500], mri_ssim_loss: [0.18726277], pet_ssim_loss: [0.12416941],  total_ssim_loss: [0.31143218], total_l2_loss: [0.02333434], total_loss: [0.25381261]
# Epoch: [64],step: [17600], mri_ssim_loss: [0.26681805], pet_ssim_loss: [0.12210125],  total_ssim_loss: [0.38891929], total_l2_loss: [0.01449180], total_loss: [0.31403381]
# Epoch: [65],step: [17700], mri_ssim_loss: [0.28021663], pet_ssim_loss: [0.24856108],  total_ssim_loss: [0.52877772], total_l2_loss: [0.02179143], total_loss: [0.42738047]
# Epoch: [65],step: [17800], mri_ssim_loss: [0.15155965], pet_ssim_loss: [0.09384930],  total_ssim_loss: [0.24540895], total_l2_loss: [0.01715503], total_loss: [0.19975817]
# Epoch: [65],step: [17900], mri_ssim_loss: [0.50658286], pet_ssim_loss: [0.21368074],  total_ssim_loss: [0.72026360], total_l2_loss: [0.01657671], total_loss: [0.57952625]
# Epoch: [66],step: [18000], mri_ssim_loss: [0.33063227], pet_ssim_loss: [0.22056037],  total_ssim_loss: [0.55119264], total_l2_loss: [0.01861721], total_loss: [0.44467756]
# Epoch: [66],step: [18100], mri_ssim_loss: [0.26228410], pet_ssim_loss: [0.14446712],  total_ssim_loss: [0.40675122], total_l2_loss: [0.01613327], total_loss: [0.32862765]
# Epoch: [66],step: [18200], mri_ssim_loss: [0.23054081], pet_ssim_loss: [0.15695244],  total_ssim_loss: [0.38749325], total_l2_loss: [0.03059274], total_loss: [0.31611314]
# Epoch: [67],step: [18300], mri_ssim_loss: [0.24256712], pet_ssim_loss: [0.20294237],  total_ssim_loss: [0.44550949], total_l2_loss: [0.03420816], total_loss: [0.36324924]
# Epoch: [67],step: [18400], mri_ssim_loss: [0.21272075], pet_ssim_loss: [0.14029366],  total_ssim_loss: [0.35301441], total_l2_loss: [0.02019918], total_loss: [0.28645137]
# Epoch: [68],step: [18500], mri_ssim_loss: [0.25881737], pet_ssim_loss: [0.14777821],  total_ssim_loss: [0.40659559], total_l2_loss: [0.02575898], total_loss: [0.33042827]
# Epoch: [68],step: [18600], mri_ssim_loss: [0.15773249], pet_ssim_loss: [0.11141157],  total_ssim_loss: [0.26914406], total_l2_loss: [0.01913420], total_loss: [0.21914209]
# Epoch: [68],step: [18700], mri_ssim_loss: [0.34278917], pet_ssim_loss: [0.18264049],  total_ssim_loss: [0.52542967], total_l2_loss: [0.02444650], total_loss: [0.42523304]
# Epoch: [69],step: [18800], mri_ssim_loss: [0.34569901], pet_ssim_loss: [0.23344421],  total_ssim_loss: [0.57914323], total_l2_loss: [0.03223210], total_loss: [0.46976101]
# Epoch: [69],step: [18900], mri_ssim_loss: [0.13690084], pet_ssim_loss: [0.09129769],  total_ssim_loss: [0.22819853], total_l2_loss: [0.02085253], total_loss: [0.18672933]
# Epoch: [69],step: [19000], mri_ssim_loss: [0.35908979], pet_ssim_loss: [0.10932726],  total_ssim_loss: [0.46841705], total_l2_loss: [0.03903652], total_loss: [0.38254097]
# Epoch: [70],step: [19100], mri_ssim_loss: [0.31011909], pet_ssim_loss: [0.26857919],  total_ssim_loss: [0.57869828], total_l2_loss: [0.04592349], total_loss: [0.47214332]
# Epoch: [70],step: [19200], mri_ssim_loss: [0.24356484], pet_ssim_loss: [0.15307653],  total_ssim_loss: [0.39664137], total_l2_loss: [0.01477381], total_loss: [0.32026786]
# Epoch: [70],step: [19300], mri_ssim_loss: [0.12108266], pet_ssim_loss: [0.03813827],  total_ssim_loss: [0.15922093], total_l2_loss: [0.00744855], total_loss: [0.12886646]
# Epoch: [71],step: [19400], mri_ssim_loss: [0.19225091], pet_ssim_loss: [0.13419646],  total_ssim_loss: [0.32644737], total_l2_loss: [0.02580655], total_loss: [0.26631922]
# Epoch: [71],step: [19500], mri_ssim_loss: [0.31600529], pet_ssim_loss: [0.13940471],  total_ssim_loss: [0.45541000], total_l2_loss: [0.02886306], total_loss: [0.37010062]
# Epoch: [72],step: [19600], mri_ssim_loss: [0.29892743], pet_ssim_loss: [0.24587160],  total_ssim_loss: [0.54479903], total_l2_loss: [0.01934531], total_loss: [0.43970829]
# Epoch: [72],step: [19700], mri_ssim_loss: [0.15548736], pet_ssim_loss: [0.09292060],  total_ssim_loss: [0.24840796], total_l2_loss: [0.01635467], total_loss: [0.20199731]
# Epoch: [72],step: [19800], mri_ssim_loss: [0.59791076], pet_ssim_loss: [0.18603969],  total_ssim_loss: [0.78395045], total_l2_loss: [0.02017221], total_loss: [0.63119483]
# Epoch: [73],step: [19900], mri_ssim_loss: [0.33676869], pet_ssim_loss: [0.22283208],  total_ssim_loss: [0.55960077], total_l2_loss: [0.01725793], total_loss: [0.45113221]
# Epoch: [73],step: [20000], mri_ssim_loss: [0.33490092], pet_ssim_loss: [0.18402493],  total_ssim_loss: [0.51892585], total_l2_loss: [0.02532590], total_loss: [0.42020586]
# Epoch: [73],step: [20100], mri_ssim_loss: [0.22219521], pet_ssim_loss: [0.11150420],  total_ssim_loss: [0.33369941], total_l2_loss: [0.01334489], total_loss: [0.26962849]
# Epoch: [74],step: [20200], mri_ssim_loss: [0.26596946], pet_ssim_loss: [0.20747483],  total_ssim_loss: [0.47344428], total_l2_loss: [0.03766810], total_loss: [0.38628903]
# Epoch: [74],step: [20300], mri_ssim_loss: [0.23219746], pet_ssim_loss: [0.14955485],  total_ssim_loss: [0.38175231], total_l2_loss: [0.03192110], total_loss: [0.31178609]
# Epoch: [74],step: [20400], mri_ssim_loss: [0.46878791], pet_ssim_loss: [0.08140826],  total_ssim_loss: [0.55019617], total_l2_loss: [0.05430396], total_loss: [0.45101774]
# Epoch: [75],step: [20500], mri_ssim_loss: [0.17744136], pet_ssim_loss: [0.10396659],  total_ssim_loss: [0.28140795], total_l2_loss: [0.02113257], total_loss: [0.22935289]
# Epoch: [75],step: [20600], mri_ssim_loss: [0.34721047], pet_ssim_loss: [0.21588069],  total_ssim_loss: [0.56309116], total_l2_loss: [0.04139283], total_loss: [0.45875150]
# Epoch: [76],step: [20700], mri_ssim_loss: [0.18203068], pet_ssim_loss: [0.24208128],  total_ssim_loss: [0.42411196], total_l2_loss: [0.01201084], total_loss: [0.34169173]
# Epoch: [76],step: [20800], mri_ssim_loss: [0.14108980], pet_ssim_loss: [0.09375459],  total_ssim_loss: [0.23484439], total_l2_loss: [0.01876226], total_loss: [0.19162796]
# Epoch: [76],step: [20900], mri_ssim_loss: [0.60281366], pet_ssim_loss: [0.16708654],  total_ssim_loss: [0.76990020], total_l2_loss: [0.02310723], total_loss: [0.62054163]
# Epoch: [77],step: [21000], mri_ssim_loss: [0.31105530], pet_ssim_loss: [0.23706394],  total_ssim_loss: [0.54811925], total_l2_loss: [0.03163492], total_loss: [0.44482237]
# Epoch: [77],step: [21100], mri_ssim_loss: [0.28303695], pet_ssim_loss: [0.12029314],  total_ssim_loss: [0.40333009], total_l2_loss: [0.02652641], total_loss: [0.32796937]
# Epoch: [77],step: [21200], mri_ssim_loss: [0.21225822], pet_ssim_loss: [0.10245025],  total_ssim_loss: [0.31470847], total_l2_loss: [0.01712361], total_loss: [0.25519150]
# Epoch: [78],step: [21300], mri_ssim_loss: [0.18843895], pet_ssim_loss: [0.14373696],  total_ssim_loss: [0.33217591], total_l2_loss: [0.02779656], total_loss: [0.27130005]
# Epoch: [78],step: [21400], mri_ssim_loss: [0.34809148], pet_ssim_loss: [0.12075311],  total_ssim_loss: [0.46884459], total_l2_loss: [0.02835857], total_loss: [0.38074738]
# Epoch: [79],step: [21500], mri_ssim_loss: [0.22209483], pet_ssim_loss: [0.12148261],  total_ssim_loss: [0.34357744], total_l2_loss: [0.01701118], total_loss: [0.27826419]
# Epoch: [79],step: [21600], mri_ssim_loss: [0.16554147], pet_ssim_loss: [0.09799790],  total_ssim_loss: [0.26353937], total_l2_loss: [0.01667494], total_loss: [0.21416649]
# Epoch: [79],step: [21700], mri_ssim_loss: [0.28751391], pet_ssim_loss: [0.08867687],  total_ssim_loss: [0.37619078], total_l2_loss: [0.01843816], total_loss: [0.30464026]
# Epoch: [80],step: [21800], mri_ssim_loss: [0.35276949], pet_ssim_loss: [0.24855852],  total_ssim_loss: [0.60132802], total_l2_loss: [0.01947366], total_loss: [0.48495716]
# Epoch: [80],step: [21900], mri_ssim_loss: [0.12168080], pet_ssim_loss: [0.05200130],  total_ssim_loss: [0.17368209], total_l2_loss: [0.02139825], total_loss: [0.14322533]
# Epoch: [80],step: [22000], mri_ssim_loss: [0.29555297], pet_ssim_loss: [0.10166687],  total_ssim_loss: [0.39721984], total_l2_loss: [0.01937880], total_loss: [0.32165164]
# Epoch: [81],step: [22100], mri_ssim_loss: [0.30219871], pet_ssim_loss: [0.21777683],  total_ssim_loss: [0.51997554], total_l2_loss: [0.04132621], total_loss: [0.42424569]
# Epoch: [81],step: [22200], mri_ssim_loss: [0.22627181], pet_ssim_loss: [0.17089051],  total_ssim_loss: [0.39716232], total_l2_loss: [0.02137905], total_loss: [0.32200566]
# Epoch: [81],step: [22300], mri_ssim_loss: [0.25466782], pet_ssim_loss: [0.12801641],  total_ssim_loss: [0.38268423], total_l2_loss: [0.01649667], total_loss: [0.30944672]
# Epoch: [82],step: [22400], mri_ssim_loss: [0.17988819], pet_ssim_loss: [0.11334872],  total_ssim_loss: [0.29323691], total_l2_loss: [0.02079312], total_loss: [0.23874815]
# Epoch: [82],step: [22500], mri_ssim_loss: [0.40757859], pet_ssim_loss: [0.16434526],  total_ssim_loss: [0.57192385], total_l2_loss: [0.03581300], total_loss: [0.46470168]
# Epoch: [83],step: [22600], mri_ssim_loss: [0.23618454], pet_ssim_loss: [0.22603106],  total_ssim_loss: [0.46221560], total_l2_loss: [0.01539079], total_loss: [0.37285066]
# Epoch: [83],step: [22700], mri_ssim_loss: [0.15378606], pet_ssim_loss: [0.09456885],  total_ssim_loss: [0.24835491], total_l2_loss: [0.01880308], total_loss: [0.20244455]
# Epoch: [83],step: [22800], mri_ssim_loss: [0.49793565], pet_ssim_loss: [0.24086529],  total_ssim_loss: [0.73880094], total_l2_loss: [0.03338710], total_loss: [0.59771824]
# Epoch: [84],step: [22900], mri_ssim_loss: [0.27331567], pet_ssim_loss: [0.18532467],  total_ssim_loss: [0.45864034], total_l2_loss: [0.01712138], total_loss: [0.37033656]
# Epoch: [84],step: [23000], mri_ssim_loss: [0.19127113], pet_ssim_loss: [0.07708764],  total_ssim_loss: [0.26835877], total_l2_loss: [0.01618556], total_loss: [0.21792413]
# Epoch: [84],step: [23100], mri_ssim_loss: [0.22410709], pet_ssim_loss: [0.13996887],  total_ssim_loss: [0.36407596], total_l2_loss: [0.02830369], total_loss: [0.29692152]
# Epoch: [85],step: [23200], mri_ssim_loss: [0.18970442], pet_ssim_loss: [0.13997179],  total_ssim_loss: [0.32967621], total_l2_loss: [0.03367922], total_loss: [0.27047682]
# Epoch: [85],step: [23300], mri_ssim_loss: [0.36872888], pet_ssim_loss: [0.10678929],  total_ssim_loss: [0.47551817], total_l2_loss: [0.03832915], total_loss: [0.38808039]
# Epoch: [86],step: [23400], mri_ssim_loss: [0.21559942], pet_ssim_loss: [0.16473913],  total_ssim_loss: [0.38033855], total_l2_loss: [0.01073123], total_loss: [0.30641708]
# Epoch: [86],step: [23500], mri_ssim_loss: [0.16055715], pet_ssim_loss: [0.10527116],  total_ssim_loss: [0.26582831], total_l2_loss: [0.01716504], total_loss: [0.21609566]
# Epoch: [86],step: [23600], mri_ssim_loss: [0.27898115], pet_ssim_loss: [0.14389431],  total_ssim_loss: [0.42287546], total_l2_loss: [0.01464267], total_loss: [0.34122890]
# Epoch: [87],step: [23700], mri_ssim_loss: [0.34973478], pet_ssim_loss: [0.27552962],  total_ssim_loss: [0.62526441], total_l2_loss: [0.01895954], total_loss: [0.50400347]
# Epoch: [87],step: [23800], mri_ssim_loss: [0.13630581], pet_ssim_loss: [0.07474887],  total_ssim_loss: [0.21105468], total_l2_loss: [0.02084873], total_loss: [0.17301349]
# Epoch: [87],step: [23900], mri_ssim_loss: [0.30969107], pet_ssim_loss: [0.12710410],  total_ssim_loss: [0.43679518], total_l2_loss: [0.01891575], total_loss: [0.35321927]
# Epoch: [88],step: [24000], mri_ssim_loss: [0.30753905], pet_ssim_loss: [0.27233672],  total_ssim_loss: [0.57987577], total_l2_loss: [0.04562007], total_loss: [0.47302464]
# Epoch: [88],step: [24100], mri_ssim_loss: [0.22235531], pet_ssim_loss: [0.16440523],  total_ssim_loss: [0.38676053], total_l2_loss: [0.01364416], total_loss: [0.31213725]
# Epoch: [88],step: [24200], mri_ssim_loss: [0.32038212], pet_ssim_loss: [0.16152436],  total_ssim_loss: [0.48190647], total_l2_loss: [0.03634063], total_loss: [0.39279333]
# Epoch: [89],step: [24300], mri_ssim_loss: [0.18724942], pet_ssim_loss: [0.12417179],  total_ssim_loss: [0.31142122], total_l2_loss: [0.02334558], total_loss: [0.25380608]
# Epoch: [89],step: [24400], mri_ssim_loss: [0.26662540], pet_ssim_loss: [0.12213308],  total_ssim_loss: [0.38875848], total_l2_loss: [0.01449526], total_loss: [0.31390584]
# Epoch: [90],step: [24500], mri_ssim_loss: [0.27924877], pet_ssim_loss: [0.24949282],  total_ssim_loss: [0.52874160], total_l2_loss: [0.02175870], total_loss: [0.42734501]
# Epoch: [90],step: [24600], mri_ssim_loss: [0.15159929], pet_ssim_loss: [0.09381163],  total_ssim_loss: [0.24541092], total_l2_loss: [0.01713574], total_loss: [0.19975589]
# Epoch: [90],step: [24700], mri_ssim_loss: [0.49829358], pet_ssim_loss: [0.21955854],  total_ssim_loss: [0.71785212], total_l2_loss: [0.01653763], total_loss: [0.57758921]
# Epoch: [91],step: [24800], mri_ssim_loss: [0.33029896], pet_ssim_loss: [0.22085094],  total_ssim_loss: [0.55114990], total_l2_loss: [0.01862100], total_loss: [0.44464412]
# Epoch: [91],step: [24900], mri_ssim_loss: [0.26254916], pet_ssim_loss: [0.14429516],  total_ssim_loss: [0.40684432], total_l2_loss: [0.01610818], total_loss: [0.32869709]
# Epoch: [91],step: [25000], mri_ssim_loss: [0.23021394], pet_ssim_loss: [0.15712041],  total_ssim_loss: [0.38733435], total_l2_loss: [0.03059078], total_loss: [0.31598562]
# Epoch: [92],step: [25100], mri_ssim_loss: [0.24235457], pet_ssim_loss: [0.20292354],  total_ssim_loss: [0.44527811], total_l2_loss: [0.03401767], total_loss: [0.36302602]
# Epoch: [92],step: [25200], mri_ssim_loss: [0.21242666], pet_ssim_loss: [0.14039940],  total_ssim_loss: [0.35282606], total_l2_loss: [0.02018693], total_loss: [0.28629825]
# Epoch: [93],step: [25300], mri_ssim_loss: [0.25832945], pet_ssim_loss: [0.14822787],  total_ssim_loss: [0.40655732], total_l2_loss: [0.02579089], total_loss: [0.33040404]
# Epoch: [93],step: [25400], mri_ssim_loss: [0.15773827], pet_ssim_loss: [0.11139441],  total_ssim_loss: [0.26913267], total_l2_loss: [0.01911186], total_loss: [0.21912852]
# Epoch: [93],step: [25500], mri_ssim_loss: [0.34265059], pet_ssim_loss: [0.18270004],  total_ssim_loss: [0.52535063], total_l2_loss: [0.02448228], total_loss: [0.42517698]
# Epoch: [94],step: [25600], mri_ssim_loss: [0.34536171], pet_ssim_loss: [0.23367184],  total_ssim_loss: [0.57903355], total_l2_loss: [0.03233831], total_loss: [0.46969453]
# Epoch: [94],step: [25700], mri_ssim_loss: [0.13706428], pet_ssim_loss: [0.09118575],  total_ssim_loss: [0.22825003], total_l2_loss: [0.02083474], total_loss: [0.18676697]
# Epoch: [94],step: [25800], mri_ssim_loss: [0.35920089], pet_ssim_loss: [0.10867471],  total_ssim_loss: [0.46787560], total_l2_loss: [0.03900233], total_loss: [0.38210094]
# Epoch: [95],step: [25900], mri_ssim_loss: [0.30870366], pet_ssim_loss: [0.26927489],  total_ssim_loss: [0.57797855], total_l2_loss: [0.04590445], total_loss: [0.47156376]
# Epoch: [95],step: [26000], mri_ssim_loss: [0.24303675], pet_ssim_loss: [0.15304661],  total_ssim_loss: [0.39608335], total_l2_loss: [0.01481309], total_loss: [0.31982931]
# Epoch: [95],step: [26100], mri_ssim_loss: [0.12098485], pet_ssim_loss: [0.03824019],  total_ssim_loss: [0.15922505], total_l2_loss: [0.00749458], total_loss: [0.12887897]
# Epoch: [96],step: [26200], mri_ssim_loss: [0.19217736], pet_ssim_loss: [0.13426167],  total_ssim_loss: [0.32643902], total_l2_loss: [0.02580736], total_loss: [0.26631269]
# Epoch: [96],step: [26300], mri_ssim_loss: [0.31583375], pet_ssim_loss: [0.13944161],  total_ssim_loss: [0.45527536], total_l2_loss: [0.02885738], total_loss: [0.36999178]
# Epoch: [97],step: [26400], mri_ssim_loss: [0.29832971], pet_ssim_loss: [0.24643034],  total_ssim_loss: [0.54476005], total_l2_loss: [0.01937786], total_loss: [0.43968362]
# Epoch: [97],step: [26500], mri_ssim_loss: [0.15557617], pet_ssim_loss: [0.09287065],  total_ssim_loss: [0.24844682], total_l2_loss: [0.01633500], total_loss: [0.20202446]
# Epoch: [97],step: [26600], mri_ssim_loss: [0.59076083], pet_ssim_loss: [0.19179720],  total_ssim_loss: [0.78255802], total_l2_loss: [0.02016476], total_loss: [0.63007939]
# Epoch: [98],step: [26700], mri_ssim_loss: [0.33693498], pet_ssim_loss: [0.22274786],  total_ssim_loss: [0.55968285], total_l2_loss: [0.01728123], total_loss: [0.45120251]
# Epoch: [98],step: [26800], mri_ssim_loss: [0.33535451], pet_ssim_loss: [0.18359214],  total_ssim_loss: [0.51894665], total_l2_loss: [0.02530486], total_loss: [0.42021829]
# Epoch: [98],step: [26900], mri_ssim_loss: [0.22200602], pet_ssim_loss: [0.11125845],  total_ssim_loss: [0.33326447], total_l2_loss: [0.01333732], total_loss: [0.26927903]
# Epoch: [99],step: [27000], mri_ssim_loss: [0.26610297], pet_ssim_loss: [0.20719606],  total_ssim_loss: [0.47329903], total_l2_loss: [0.03759708], total_loss: [0.38615865]
# Epoch: [99],step: [27100], mri_ssim_loss: [0.23205823], pet_ssim_loss: [0.14955693],  total_ssim_loss: [0.38161516], total_l2_loss: [0.03190335], total_loss: [0.31167281]
# Epoch: [99],step: [27200], mri_ssim_loss: [0.46796942], pet_ssim_loss: [0.08223933],  total_ssim_loss: [0.55020875], total_l2_loss: [0.05429484], total_loss: [0.45102596]
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\torch\serialization.py:250: UserWarning: Couldn't retrieve source code for container of type DeepPedestrian. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "

# %%
l1 = np.asarray(ep_mri_ssim_loss)
l2 = np.asarray(ep_pet_ssim_loss)
l3 = np.asarray(ep_total_l2_loss)

# %%
plt.plot(l3)

# %%
h5f = h5py.File('C:/Users/horan/Desktop/FuseVis/Loss curves/DeepPedestrian/H5 Files/Loss_L2.h5', 'w')
h5f.create_dataset('L2_dataset', data=l3)
h5f.close()

# %%
plt.plot(l3)
plt.xlabel('epoch')
plt.ylabel('L2 Loss')
plt.title('DeepPedestrian')
plt.savefig('C:/Users/horan/Desktop/FuseVis/Loss curves/DeepPedestrian/Loss curves/L2_loss.png', bbox_inches = 'tight',pad_inches = 0, dpi=100)

# %%
#load the test input MRI dataset
filenames = os.listdir('C:/Users/horan/Desktop/FuseVis/MRI/')
dataset = os.path.join(os.getcwd(), 'C:/Users/horan/Desktop/FuseVis/MRI/')
data = glob.glob(os.path.join(dataset, "*.gif"))
data = natsort.natsorted(data,reverse=False)
test_mri = np.zeros((len(data), image_width,image_length))
for i in range(len(data)):
    test_mri[i,:,:] =(imageio.imread(data[i]))
    test_mri[i,:,:] =(test_mri[i,:,:] - np.min(test_mri[i,:,:])) / (np.max(test_mri[i,:,:]) - np.min(test_mri[i,:,:]))
    test_mri[i,:,:] = np.float32(test_mri[i,:,:])

# %%
#expand dimension to add the channel
test_mri = np.expand_dims(test_mri,axis=1)
#verify the shape matches the pytorch standard
test_mri.shape
# Out:
# (1, 1, 256, 256)

# %%
#verify the test mri image
#test_mri = test_mri[0,:,:,:]
#test_mri = np.expand_dims(test_mri,axis=0)
plt.imshow(test_mri[0,0,:,:],'gray')
#plt.savefig('MRI.png', bbox_inches = 'tight',pad_inches = 0,dpi=200)

# %%
#convert the MRI Testing data to pytorch tensor
test_mri_tensor = torch.from_numpy(test_mri).float()
test_mri_tensor = test_mri_tensor.to(device)
print(test_mri_tensor.shape)
test_mri_tensor.requires_grad =True
# Out:
# torch.Size([1, 1, 256, 256])

# %%
#load the test input PET dataset
filenames = os.listdir('C:/Users/horan/Desktop/FuseVis/PET/')
dataset = os.path.join(os.getcwd(), 'C:/Users/horan/Desktop/FuseVis/PET/')
data = glob.glob(os.path.join(dataset, "*.png"))
data = natsort.natsorted(data,reverse=False)
test_pet = np.zeros((len(data), image_width,image_length))
for i in range(len(data)):
    test_pet[i,:,:] =(imageio.imread(data[i]))
    test_pet[i,:,:] =(test_pet[i,:,:] - np.min(test_pet[i,:,:])) / (np.max(test_pet[i,:,:]) - np.min(test_pet[i,:,:]))
    test_pet[i,:,:] = np.float32(test_pet[i,:,:])

# %%
#expand dimension to add the channel
test_pet = np.expand_dims(test_pet,axis=1)
#verify the shape matches the pytorch standard
test_pet.shape
# Out:
# (1, 1, 256, 256)

# %%
plt.imshow(test_pet[0,0,:,:],'gray')
#plt.savefig('PET.png', bbox_inches = 'tight',pad_inches = 0,dpi=200)

# %%
#convert the MRI Testing data to pytorch tensor
test_pet_tensor = torch.from_numpy(test_pet).float()
test_pet_tensor = test_pet_tensor.to(device)
print(test_pet_tensor.shape)
test_pet_tensor.requires_grad =True
# Out:
# torch.Size([1, 1, 256, 256])

# %%
#load the model
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
cnn =torch.load('C:/Users/horan/Desktop/FuseVis/.ipynb_checkpoints/DeepPedestrian/checkpoint.pth')
cnn.eval()
# Out:
# DeepPedestrian(
#   (conv1): Sequential(
#     (0): Conv2d(2, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU()
#     (6): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (conv2): Sequential(
#     (0): ReLU()
#     (1): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (2): ReLU()
#     (3): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU()
#     (5): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU()
#     (7): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (conv3): Sequential(
#     (0): ReLU()
#     (1): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (2): ReLU()
#     (3): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU()
#     (5): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU()
#     (7): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (conv4): Sequential(
#     (0): ReLU()
#     (1): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (2): ReLU()
#     (3): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU()
#     (5): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU()
#     (7): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (conv5): Sequential(
#     (0): ReLU()
#     (1): Conv2d(48, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
# )

# %%
#predicted the fused image
fused = cnn(test_mri_tensor.to(device), test_pet_tensor.to(device))
fused_numpy = fused.data.cpu().numpy()

# %%
fused.shape
# Out:
# torch.Size([1, 1, 256, 256])

# %%
#verify the output image
plt.imshow(fused_numpy[0,0,:,:],'gray')
#plt.savefig('Fused.png', bbox_inches = 'tight',pad_inches = 0,dpi=200)

# %%
imageio.imwrite('C:/Users/horan/Desktop/FuseVis/Fused/DeepPedestrian/Fused.png',np.uint8(cv2.normalize(fused_numpy[0,0,:,:], None, alpha=0, beta=255, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_32F)))

# %%
#calculate the guidance image for MRI and PET wrt to the fused image
time1 = time.time()
count = 0 
guide_fuse_mri = np.zeros((256,256),dtype=float)
guide_fuse_pet = np.zeros((256,256),dtype=float)

for y_coord in range(0,256):
    for x_coord in range(0,256):
        jacob_fuse_mri = torch.autograd.grad(fused[0,0,y_coord,x_coord], test_mri_tensor, retain_graph=True, create_graph=True)[0]
        jacob_numpy_mri = np.squeeze(jacob_fuse_mri.data.cpu().numpy())  
        guide_fuse_mri[y_coord,x_coord] = jacob_numpy_mri[y_coord,x_coord]
        jacob_fuse_pet = torch.autograd.grad(fused[0,0,y_coord,x_coord], test_pet_tensor, retain_graph=True, create_graph=True)[0]
        jacob_numpy_pet = np.squeeze(jacob_fuse_pet.data.cpu().numpy())  
        guide_fuse_pet[y_coord,x_coord] = jacob_numpy_pet[y_coord,x_coord]
        count += 1
        if count % 1000 == 0:
            print('Count is %d' %count)
time2 = time.time()
print('Time taken to compute is %d seconds' %(time2-time1))
# Out:
# Count is 1000
# Count is 2000
# Count is 3000
# Count is 4000
# Count is 5000
# Count is 6000
# Count is 7000
# Count is 8000
# Count is 9000
# Count is 10000
# Count is 11000
# Count is 12000
# Count is 13000
# Count is 14000
# Count is 15000
# Count is 16000
# Count is 17000
# Count is 18000
# Count is 19000
# Count is 20000
# Count is 21000
# Count is 22000
# Count is 23000
# Count is 24000
# Count is 25000
# Count is 26000
# Count is 27000
# Count is 28000
# Count is 29000
# Count is 30000
# Count is 31000
# Count is 32000
# Count is 33000
# Count is 34000
# Count is 35000
# Count is 36000
# Count is 37000
# Count is 38000
# Count is 39000
# Count is 40000
# Count is 41000
# Count is 42000
# Count is 43000
# Count is 44000
# Count is 45000
# Count is 46000
# Count is 47000
# Count is 48000
# Count is 49000
# Count is 50000
# Count is 51000
# Count is 52000
# Count is 53000
# Count is 54000
# Count is 55000
# Count is 56000
# Count is 57000
# Count is 58000
# Count is 59000
# Count is 60000
# Count is 61000
# Count is 62000
# Count is 63000
# Count is 64000
# Count is 65000
# Time taken to compute is 3613 seconds

# %%
h5f = h5py.File('C:/Users/horan/Desktop/FuseVis/Guidance images/DeepPedestrian/H5 Files/Jacobian_MRI.h5', 'w')
h5f.create_dataset('Jacob_MRI_dataset', data=guide_fuse_mri)
h5f.close()

# %%
plt.imshow(guide_fuse_mri,cmap='viridis')
plt.colorbar()
plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/DeepPedestrian/Resultant images/Guide_Fused_MRI_DPI.png', bbox_inches = 'tight',pad_inches = 0,dpi=200)

# %%
h5f = h5py.File('C:/Users/horan/Desktop/FuseVis/Guidance images/DeepPedestrian/H5 Files/Jacobian_PET.h5', 'w')
h5f.create_dataset('Jacob_PET_dataset', data=guide_fuse_pet)
h5f.close()

# %%
plt.imshow(guide_fuse_pet,cmap='viridis')
plt.colorbar()
plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/DeepPedestrian/Resultant images/Guide_Fused_PET_DPI.png', bbox_inches = 'tight',pad_inches = 0,dpi=200)

# %%
#define overlay images
fused_RGB = np.zeros((256,256,3),dtype=float)
mri_RGB   = np.zeros((256,256,3),dtype=float)
pet_RGB   = np.zeros((256,256,3),dtype=float)

# %%
fused_RGB[:,:,0]  = guide_fuse_mri 
fused_RGB[:,:,1]  = guide_fuse_pet 
fused_RGB[:,:,2]  = fused_numpy[0,0,:,:]

# %%
plt.imshow(fused_RGB)
plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/DeepPedestrian/Resultant images/Fused_RGB_DPI.png', bbox_inches = 'tight',pad_inches = 0,dpi=200)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
mri_RGB[:,:,0]  = guide_fuse_mri
mri_RGB[:,:,1]  = guide_fuse_pet 
mri_RGB[:,:,2]  = test_mri[0,0,:,:]

# %%
plt.imshow(mri_RGB)
plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/DeepPedestrian/Resultant images/MRI_RGB_DPI.png', bbox_inches = 'tight',pad_inches = 0,dpi=200)

# %%
pet_RGB[:,:,0]  = guide_fuse_mri
pet_RGB[:,:,1]  = guide_fuse_pet 
pet_RGB[:,:,2]  = test_pet[0,0,:,:]

# %%
plt.imshow(pet_RGB)
plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/DeepPedestrian/Resultant images/PET_RGB_DPI.png', bbox_inches = 'tight',pad_inches = 0,dpi=200)

# %%
#define the window
root = Tk()  
root.title('Visualisation of fusion networks')
root.configure(background='white')


#Label the images
#fontStyle = tkFont.Font(family="Lucida Grande", size=15)
#w1 = tk.Label(root, bg='white', font=fontStyle, text="Fused Image")
#w1.grid(row=0, column=1)
#w1.pack()

#define the frame
canvasframe = Frame(root)  # define Input and output frame
buttonframe = Frame(root)  # define button frame
canvasframe.pack()  # pack the Input and Output frame
buttonframe.pack()  # pack the button frame


#define the canvas
canvas = Canvas(canvasframe, width=1800, height=920, bg = 'white')
canvas.grid(row=0, column=0)

#Insert fused image to the canvas
img_fused = ImageTk.PhotoImage(file ="C:/Users/horan/Desktop/FuseVis/Fused/DeepPedestrian/Fused.png") # load the image
canvas.create_image(0, 0, image=img_fused, anchor=NW)

#Insert MRI image to the canvas
img_mri = ImageTk.PhotoImage(file ="C:/Users/horan/Desktop/FuseVis/MRI/MRI.gif") # load the image
canvas.create_image(600, 0, image=img_mri, anchor=NW)

#Insert PET image to the canvas
img_pet = ImageTk.PhotoImage(file ="C:/Users/horan/Desktop/FuseVis/PET/3.png") # load the image
canvas.create_image(1200, 0, image=img_pet, anchor=NW)

def start_mouseover():  # function called when user clicks the button 
    # link the function to the left-mouse-click event
    canvas.bind("<B1-Motion>", Coordinates)

def Coordinates(event): # function called when left-mouse-button is clicked with a mouseover
    x_coord = event.x  # save x and y coordinates selected by the user   
    y_coord = event.y
    print('mouse position is at' + '(' + str(y_coord) + ',' + str(x_coord) + ')', end='\r')
    #display the output MRI Jacobian image
    #img_MR_out = ImageTk.PhotoImage(file ='C:/Users/cgvadmin/Desktop/FuseVis/Fused_MRI/im_' + str(y_coord) + '_' + str(x_coord) + '.png') # load the image
    jacobian_fuse_mri = torch.autograd.grad(fused[0,0,y_coord,x_coord], test_mri_tensor, retain_graph=True, create_graph=True)[0]
    jacobian_fuse_pet = torch.autograd.grad(fused[0,0,y_coord,x_coord], test_pet_tensor, retain_graph=True, create_graph=True)[0]
    
    jacob_val_mri = np.squeeze(jacobian_fuse_mri.data.cpu().numpy())    
    jacob_val_pet = np.squeeze(jacobian_fuse_pet.data.cpu().numpy())
    
    x_mri = np.asarray(np.where(np.any(jacob_val_mri, axis = 0)))
    y_mri = np.asarray(np.where(np.any(jacob_val_mri, axis = 1)))
    minx_mri, maxx_mri, miny_mri, maxy_mri = np.min(x_mri), np.max(x_mri), np.min(y_mri), np.max(y_mri)  #return min and max coordinates
    zoom_im_mri = jacob_val_mri[miny_mri:maxy_mri,minx_mri:maxx_mri] 
    
    x_pet = np.asarray(np.where(np.any(jacob_val_pet, axis = 0)))
    y_pet = np.asarray(np.where(np.any(jacob_val_pet, axis = 1)))
    minx_pet, maxx_pet, miny_pet, maxy_pet = np.min(x_pet), np.max(x_pet), np.min(y_pet), np.max(y_pet)  #return min and max coordinates
    zoom_im_pet = jacob_val_pet[miny_pet:maxy_pet,minx_pet:maxx_pet] 
    
    plt.imshow(fused_numpy[0,0,miny_mri:maxy_mri,minx_mri:maxx_mri], cmap = 'gray', aspect ='equal')
    plt.title('Zoom Fused')
    plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/DeepPedestrian/Resultant images/Zoom_Fused.png', bbox_inches = 'tight',pad_inches = 0)
    plt.close()
    im_out11 = ImageTk.PhotoImage(file ='C:/Users/horan/Desktop/FuseVis/Guidance images/DeepPedestrian/Resultant images/Zoom_Fused.png')
    canvas.create_image(300,5,image=im_out11,anchor=NW)
    canvas.image11 = im_out11
    plt.tight_layout()
    
    plt.imshow(test_mri[0,0,miny_mri:maxy_mri,minx_mri:maxx_mri], cmap = 'gray', aspect ='equal')
    plt.title('Zoom MRI')
    plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/DeepPedestrian/Resultant images/Zoom_MRI.png', bbox_inches = 'tight',pad_inches = 0)
    plt.close()
    im_out12 = ImageTk.PhotoImage(file ='C:/Users/horan/Desktop/FuseVis/Guidance images/DeepPedestrian/Resultant images/Zoom_MRI.png')
    canvas.create_image(900,5,image=im_out12,anchor=NW)
    canvas.image12 = im_out12
    plt.tight_layout()
    
    plt.imshow(test_pet[0,0,miny_mri:maxy_mri,minx_mri:maxx_mri], cmap = 'gray', aspect ='equal')
    plt.title('Zoom PET')
    plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/DeepPedestrian/Resultant images/Zoom_PET.png', bbox_inches = 'tight',pad_inches = 0)
    plt.close()
    im_out13 = ImageTk.PhotoImage(file ='C:/Users/horan/Desktop/FuseVis/Guidance images/DeepPedestrian/Resultant images/Zoom_PET.png')
    canvas.create_image(1500,5,image=im_out13,anchor=NW)
    canvas.image13 = im_out13
    plt.tight_layout()
    
    plt.imshow(jacob_val_mri,cmap='viridis', aspect ='equal')
    plt.title('Jacobian (Fused wrt MRI)')
    plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/DeepPedestrian/Resultant images/Jacob_Fused_MRI.png', bbox_inches = 'tight',pad_inches = 0)
    plt.close()
    im_out1 = ImageTk.PhotoImage(file ='C:/Users/horan/Desktop/FuseVis/Guidance images/DeepPedestrian/Resultant images/Jacob_Fused_MRI.png')
    canvas.create_image(40,320,image=im_out1,anchor=NW)
    canvas.image1 = im_out1
    #plt.tight_layout()
    
    #f.add_subplot(1,5,2)
    plt.imshow(zoom_im_mri,cmap='viridis',aspect ='equal')
    plt.title('Zoom Jacobian (Fused wrt MRI)')
    plt.colorbar()
    plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/DeepPedestrian/Resultant images/Zoom_Jacob_MRI.png', bbox_inches = 'tight',pad_inches = 0)
    plt.close()
    im_out2 = ImageTk.PhotoImage(file ='C:/Users/horan/Desktop/FuseVis/Guidance images/DeepPedestrian/Resultant images/Zoom_Jacob_MRI.png')
    canvas.create_image(380,320,image=im_out2,anchor=NW)
    canvas.image2 = im_out2
    
    #f.add_subplot(1,5,3)
    plt.xlim(0,0.7)
    plt.ylim(0,0.7)
    plt.plot(jacob_val_mri[y_coord,x_coord],jacob_val_pet[y_coord,x_coord],'-ro')
    plt.xlabel('MRI pixel score (Fused wrt MRI)')
    plt.ylabel('PET pixel score (Fused wrt PET)')
    plt.title('Mouse position at: (' + str(y_coord) + ',' + str(x_coord) + ')')
    plt.gca().set_aspect('equal', adjustable='box')
    plt.draw()
    plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/DeepPedestrian/Resultant images/Pixel_intensities.png', bbox_inches = 'tight',pad_inches = 0.1)
    plt.close()
    im_out3 = ImageTk.PhotoImage(file ='C:/Users/horan/Desktop/FuseVis/Guidance images/DeepPedestrian/Resultant images/Pixel_intensities.png')
    canvas.create_image(750,320,image=im_out3,anchor=NW)
    canvas.image3 = im_out3
    
    #f.add_subplot(1,5,4)
    plt.imshow(jacob_val_pet,cmap='viridis',aspect ='equal')
    plt.title('Jacobian (Fused wrt PET)')
    plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/DeepPedestrian/Resultant images/Jacob_Fused_PET.png', bbox_inches = 'tight',pad_inches = 0)
    plt.close()
    im_out4 = ImageTk.PhotoImage(file ='C:/Users/horan/Desktop/FuseVis/Guidance images/DeepPedestrian/Resultant images/Jacob_Fused_PET.png')
    canvas.create_image(1110,320,image=im_out4,anchor=NW)
    canvas.image4 = im_out4
    #plt.tight_layout()
    
    #f.add_subplot(1,5,5)
    plt.imshow(zoom_im_pet,cmap='viridis',aspect ='equal')
    plt.title('Zoomed Jacobian (Fused wrt PET)')
    plt.colorbar()
    plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/DeepPedestrian/Resultant images/Zoom_Jacob_PET.png', bbox_inches = 'tight',pad_inches = 0)
    plt.close()
    im_out5 = ImageTk.PhotoImage(file ='C:/Users/horan/Desktop/FuseVis/Guidance images/DeepPedestrian/Resultant images/Zoom_Jacob_PET.png')
    canvas.create_image(1450,320,image=im_out5,anchor=NW)
    canvas.image5 = im_out5

    plt.imshow(guide_fuse_mri,cmap='viridis')
    plt.title('Guidance (Fused wrt MRI)')
    plt.colorbar()
    plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/DeepPedestrian/Resultant images/Guide_Fused_MRI.png', bbox_inches = 'tight',pad_inches = 0)
    plt.close()
    im_out6 = ImageTk.PhotoImage(file ='C:/Users/horan/Desktop/FuseVis/Guidance images/DeepPedestrian/Resultant images/Guide_Fused_MRI.png')
    canvas.create_image(100,650,image=im_out6,anchor=NW)
    canvas.image6 = im_out6
    
    plt.imshow(fused_RGB)
    plt.title('R=I1 G=I2 B=Fused')
    plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/DeepPedestrian/Resultant images/Fused_RGB.png', bbox_inches = 'tight',pad_inches = 0)
    plt.close()
    im_out8 = ImageTk.PhotoImage(file ='C:/Users/horan/Desktop/FuseVis/Guidance images/DeepPedestrian/Resultant images/Fused_RGB.png')
    canvas.create_image(420,650,image=im_out8,anchor=NW)
    canvas.image8 = im_out8
    
    plt.imshow(mri_RGB)
    plt.title('R=I1 G=I2 B=MRI')
    plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/DeepPedestrian/Resultant images/MRI_RGB.png', bbox_inches = 'tight',pad_inches = 0)
    plt.close()
    im_out9 = ImageTk.PhotoImage(file ='C:/Users/horan/Desktop/FuseVis/Guidance images/DeepPedestrian/Resultant images/MRI_RGB.png')
    canvas.create_image(740,650,image=im_out9,anchor=NW)
    canvas.image9 = im_out9
    
    plt.imshow(pet_RGB)
    plt.title('R=I1 G=I2 B=PET')
    plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/DeepPedestrian/Resultant images/PET_RGB.png', bbox_inches = 'tight',pad_inches = 0)
    plt.close()
    im_out10 = ImageTk.PhotoImage(file ='C:/Users/horan/Desktop/FuseVis/Guidance images/DeepPedestrian/Resultant images/PET_RGB.png')
    canvas.create_image(1100,650,image=im_out10,anchor=NW)
    canvas.image10 = im_out10
    
    plt.imshow(guide_fuse_pet,cmap='viridis')
    plt.title('Guidance (Fused wrt PET)')
    plt.colorbar()
    plt.savefig('C:/Users/horan/Desktop/FuseVis/Guidance images/DeepPedestrian/Resultant images/Guide_Fused_PET.png', bbox_inches = 'tight',pad_inches = 0)
    plt.close()
    im_out7 = ImageTk.PhotoImage(file ='C:/Users/horan/Desktop/FuseVis/Guidance images/DeepPedestrian/Resultant images/Guide_Fused_PET.png')
    canvas.create_image(1400,650,image=im_out7,anchor=NW)
    canvas.image7 = im_out7
    
    radius = 5
    i = canvas.create_oval(x_coord-radius, y_coord-radius, x_coord+radius, y_coord+radius, fill = 'red')
    canvas.after(20,canvas.delete,i)

# insert button to the middleframe and link it to "Start Mouseover"
button_start_mouseover = Button(buttonframe, text="Start Mouseover",command=start_mouseover)
button_start_mouseover.grid(row=1, column=0, pady=0)


root.mainloop()  #keep the GUI open
